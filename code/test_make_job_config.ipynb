# %%
from argparse import ArgumentParser
from pathlib import Path
import re
import functools
import operator

import datalad.api as dl
import pandas as pd
import numpy as np

# %%
def is_numeric(x):
    try:
        int(x)
        return True
    except:
        return False
    
def try_search(regex, val):
    try:
        return re.search(regex, val).group()
    except:
        return None
        

def get_random_seed():
    """
    Return a 9 digit random integer.
    """
    return np.random.randint(100_000_000, 999_999_999)

def create_command_df(variable_commands_string):
    """
    Extract the commands within each variable definition. 
    Return a dataframe where each row is a command.
    """
    
    command_value = {'drop':1, 'glob':1,'variable':1,'paste':1,'write':1,'replace':-1, 'is_in':-1, 'not_in':-1, 'grep':-1,'unique':-1,'multiply':-1, 'repeat':-1,'exists':-1}
    
    command_names = re.findall("(?<=\<!)\w+(?=\>)", variable_commands_string)
    commands =  re.sub('<!\w+>', '<!command>', variable_commands_string).split('<!command>')[1:]
    
    command_df = (pd.DataFrame({'command_name':command_names, 'command':commands})
    .assign(
        command = lambda df_: 
            df_['command'].str.strip().str.replace(r'(^\(|\)$)', '', regex=True),
        command_value = lambda df_: df_['command_name'].map(command_value)
    )
    )

    assert command_df['command_name'].isin(command_value.keys()).all(), "Used an invalid command within a variable definition."

    assert command_df['command_value'].is_monotonic_decreasing, "'drop', 'glob', 'variable', 'paste', and 'write' have to be the first action within each variable definition."

    assert command_df['command_value'].iat[0] >= 0, "Can't start variable definition with 'grep', 'unique', 'multiply', 'repeat' or 'exists'."

    assert command_df['command_value'].sum() < 2, "You can't use both 'drop', 'glob' and 'variable' within the same variable definition."
    
    if command_df['command_name'].iat[0] == 'drop':
        assert command_df['command_value'].shape[0] == 1, "You can't use commands after 'drop'."
    
    return command_df


def call_glob(cmd):
    """
    Return an ordered list of glob results relative to super dataset.
    """
    
    glob_characters = '[a-z,A-Z,0-9,\\,\/,\-,_,\.,\*,\[,\],\:,\+,\?,\!,\s]'
    assert super_dataset_path, "No known super dataset for globbing."
    
    try:
        globbing_list = re.search(f"{glob_characters}+", cmd).group().split()
    
        values = sorted(
            [str(path.relative_to(super_dataset_path)) 
            for globbing in globbing_list
            for path in Path(super_dataset_path).glob(globbing)]
            )
    except:
        raise Exception('Not a valid globbing pattern.')
    
    return values


def call_variable(cmd, variables):
    """
    Get the values from an existing variable.
    """
    variable_characters = '[a-z,A-Z,0-9,\-,_,]'
    try:
        variable_name = re.search(f"{variable_characters}+", cmd).group()
    except:
        raise Exception("Tried to call a variable with an invalid variable name.")
    
    try:
        values = variables[variable_name]
    except:
        raise Exception("Tried to call a non-existing variable.")
    
    return values


def call_paste(cmd, variables):
    """
    Paste existing variables within text.
    Returns a list of values.
    """
    
    paste_variables = list(set(re.findall('(?<=\{)[\w,_,-]+(?=\})', cmd)))
    
    assert pd.Series(paste_variables).isin(variables.keys()).all(), "Not all variables in 'paste' exist."
    
    values = []
    for row in pd.DataFrame(variables)[paste_variables].to_dict(orient='records'):
        values.append(cmd.format(**row))
    
    return values

def call_write(cmd):
    """
    Return a list of space-separeted values from a string.
    """
    return cmd.split()


def call_replace(cmd, values):
    """
    Replace a string pattern from existing values. 
    Can call existing variables within 'cmd' using double curly brackets.
    Returns a list of values.
    """
    
    
    n_spaces = len([character for character in cmd if character == ' '])
    assert n_spaces == 1, "Didn't find exactly one space within 'replace'. Command should be:('to_be_replaced' 'replacement')."
    
    string_detect = cmd.split()[0]
    string_replace = cmd.split()[1]            
    
    new_values = []
    for value in values:
        new_values.append(
            re.sub(string_detect, string_replace, value).replace('{{' , '{').replace('}}', '}')
            )
        
    values = new_values
        
    replacement_variables = re.findall("(?<={)\w+(?=})", '{subject}')
    if replacement_variables:
        if not pd.Series(replacement_variables).isin(variables.keys()).all():
            raise Exception("Not all variables inside <!replace> exist.")
        
        new_values = []
        for value, row_dict in zip(values, pd.DataFrame(variables).to_dict(orient='records')):
            new_values.append(value.format(**row_dict))
            
        values = new_values
        
    return values


def call_drop():
    """
    Returns None.
    """
    return None


def call_grep(cmd, values):
    """
    Return a string pattern from existing values using regular expressions.
    """
    values = [try_search(cmd, value) for value in values]
    assert not all(value is None for value in values), "Not a valid regex or no matches."

    return values


def call_repeat(cmd, values):
    "Repeat existing values."
    if isinstance(values, str):
        values = values.split()
    if is_numeric(cmd):
        n_elements = int(cmd)
    else:
        assert cmd in variables.keys(), "Tried to repeat by the length of a variable that doesn't exist."
        n_elements = len(variables[cmd])    
           
    values = [[value]*n_elements for value in values]
    values = functools.reduce(operator.iconcat, values, [])
    
    return values


def call_is_in(cmd, values):
    """
    Return values in common between two existing variables.
    """
    variable = cmd.strip()
    
    variable_characters = '[a-z,A-Z,0-9,\-,_,]'
    try:
        variable = re.search(f"{variable_characters}+", variable).group()
    except:
        raise Exception("Within 'is_in', tried to call a variable with an invalid variable name.")
    
    try:
        variable = pd.Series(variables[variable])
        values = pd.Series(values)
    except:
        raise Exception("Within 'is_in', tried to call a variable that doesn't exist.")
    
    return values[values.isin(variable)].to_list()


def call_not_in(cmd, values):
    """
    Return values not in common between two existing variables.
    """
    variable = cmd.strip()
    
    variable_characters = '[a-z,A-Z,0-9,\-,_,]'
    try:
        variable = re.search(f"{variable_characters}+", variable).group()
    except:
        raise Exception("Within 'not_in', tried to call a variable with an invalid variable name.")
    
    try:
        variable = pd.Series(variables[variable])
        values = pd.Series(values)
    except:
        raise Exception("Within 'not_in', tried to call a variable that doesn't exist.")
    
    return values[~values.isin(variable)].to_list()
    

def call_multiply(cmd, values):
    "Multiply existing values."
    if isinstance(values, str):
        values = values.split()
    if is_numeric(cmd):
        n_elements = int(cmd)
    else:
        assert cmd in variables.keys(), "Tried to multiply by the length of a variable that doesn't exist."
        n_elements = len(variables[cmd])    
           
    values = values*n_elements 
    
    return values

    
def call_unique(values):
    """
    Remove duplicated values, keep the first one and maintain the same order. 
    """
    return pd.Series(['pcc', 'acc', 'pcc']).drop_duplicates(keep='first').to_list()
    

def call_exists(values):
    """
    
    """
    assert super_dataset_path, "No known super dataset for globbing." 
    new_values = []
    for value in values:
        if (super_dataset_path / str(value)).is_symlink() or (super_dataset_path / str(value)).exists():
            new_values.append(value)
        else:
            new_values.append(None)
    
    values = new_values
    
    return values
    

def select_command(command_name, command, values=None, variables=None, current_variable_name=None):
    """
    Select one of the possible 9 commands and return the values.
    """
    match command_name:
        # first-postion commands
        case 'drop':
            return call_drop()
        
        case 'glob':
            return call_glob(command)

        case 'write':
            return call_write(command)
        
        case 'variable':
            assert variables, "Can't use 'variable' if no variable has been defined."
            return call_variable(command, variables)
        
        case 'paste':
            assert variables, "Can't use 'paste' if no variable has been defined."
            return call_paste(command, variables)
        
        # non-first commands    
        case 'replace':
            assert values, "Can't use 'replace' without existing values."
            return call_replace(command, values)
        
        case 'grep':
            assert values, "Can't use 'grep' without existing values."
            return call_grep(command, values)
        
        case 'is_in':
            assert values, "Can't use 'is_in' without existing values."
            return call_is_in(command, values)
        
        case 'not_in':
            assert values, "Can't use 'not_in' without existing values."
            return call_not_in(command, values)
        
        case 'multiply':
            assert values, "Can't use 'multiply' without existing values."
            return call_multiply(command, values)
        
        case 'repeat':
            assert values, "Can't use 'repeat' without existing values."
            return call_repeat(command, values)
        
        case 'unique':
            assert values, "Can't use 'unique' without existing values."
            return call_unique(values)
        
        case 'exists':
            assert values, "Can't use 'exists' without existing values."
            return call_exists(values)
            
        case _:
            raise Exception("Non-existing command selected.")

# %%
command_df
# Out:
#   command_name  command  command_value
# 0        write  acc pcc              1
# 1     multiply        5             -1

# %%
super_dataset_path = Path('/misc/geminis2/ramirezd/test_bet/')
variable_definition_string = "svs == <!glob>(inputs/mri-raw/sub-*/mrs/*acq-press*svs.nii.gz) ; subject == <!variable>(svs)<!grep>(sub-\w+); t1w == <!paste> (inputs/mri-raw/{subject}/anat/{subject}_T1w.nii.gz) ; t2w == <!variable>(t1w)<!replace>(T1w T2w)<!exists> ; ref == <!variable>(svs)<!replace>(svs(?=.nii.gz) ref)<!exists> "

variable_definition_string = "voi == <!write>(acc pcc)<!multiply>5"

# Create a tuple of variable-commands
variable_command = []

for index, variable_definition in enumerate(variable_definition_string.split(';')):
    variable_name = variable_definition.split('==')[0].strip()
    variable_commands_string = variable_definition.split('==')[1].strip()
    command_df = create_command_df(variable_commands_string)
    variable_command.append((index, variable_name, command_df))


# Create a dictionary of variable-values
variables = {}

len_dict = {}
max_len=0

for index, variable_name, command_df in variable_command:
    values = []
    for command_row in command_df.itertuples():
        values = select_command(
            command_row.command_name,
            command_row.command,
            values,
            variables
            )
    
    # Drop variable if it's None and skip next steps
    if values is None: 
        try:
            del variables[variable_name]
            del len_dict[variable_name]
        except:
            pass
        
        continue
        
    variables[variable_name] = values
    len_dict[variable_name] = len(values)


# Calculate the max length of each variable for broadcasting. 
for variable_name, len_of_values in len_dict.items():
    if len_of_values > max_len:
        max_len = len_of_values
        max_len_variable = variable_name

# Broadcast variables.
if np.all(max_len % np.array(list(len_dict.values())) == 0):
    for key, value_list in variables.items():
        if key == max_len_variable:
            continue
        variables[key] = value_list * int(max_len / len(value_list))
else:
    raise Exception("Can't broadcast variables.")

# %%
# Out:
# array([3])

# %%
len_dict
# Out:
# {'subject': 3}

# %%
for value in variables.values():
    print(len(value))
# Out:
# 863
# 863
# 863
# 863

# %%
pd.DataFrame(variables)
# Out:
#    voi
# 0  acc
# 1  pcc
# 2  acc
# 3  pcc
# 4  acc
# 5  pcc
# 6  acc
# 7  pcc
# 8  acc
# 9  pcc

# %%
dl_cmd = "bet inputs/mri_raw/{subject}/anat/{subject}_T1w.nii.gz outputs/bet/{subject}_T1w_bet.nii.gz --radom_seed <!random>"
inputs = "inputs/mri_raw/{subject}/anat/{subject}_T1w.nii.gz"
outputs = "outputs/bet/{subject}_T1w_bet.nii.gz"
job_name = "{subject}_T1w_bet"
data_dict = {'job_name':[], 'dl_cmd':[], 'inputs':[], 'outputs':[]}

if ("<!random>" in dl_cmd) and not "{random_seed}" in dl_cmd:
    random_seeds=[]
    for i in range(max_len):
        random_seeds.append(get_random_seed())
    
    dl_cmd = re.sub("<!random>", "{random_seed}", dl_cmd)
    variables['random_seed'] = random_seeds

for row_dict in pd.DataFrame(variables).dropna().to_dict(orient='records'):
    data_dict['job_name'].append(job_name.format(**row_dict))
    data_dict['dl_cmd'].append(dl_cmd.format(**row_dict))
    data_dict['inputs'].append(inputs.format(**row_dict))
    data_dict['outputs'].append(outputs.format(**row_dict))

# %%
pd.DataFrame(data_dict)
# Out:
#            job_name                                             dl_cmd
# 0  sub-178A_T1w_bet  bet inputs/mri_raw/sub-178A/anat/sub-178A_T1w....  \
# 1  sub-178B_T1w_bet  bet inputs/mri_raw/sub-178B/anat/sub-178B_T1w....
# 2  sub-217B_T1w_bet  bet inputs/mri_raw/sub-217B/anat/sub-217B_T1w....
#
#                                              inputs
# 0  inputs/mri_raw/sub-178A/anat/sub-178A_T1w.nii.gz  \
# 1  inputs/mri_raw/sub-178B/anat/sub-178B_T1w.nii.gz
# 2  inputs/mri_raw/sub-217B/anat/sub-217B_T1w.nii.gz
#
#                                outputs
# 0  outputs/bet/sub-178A_T1w_bet.nii.gz
# 1  outputs/bet/sub-178B_T1w_bet.nii.gz
# 2  outputs/bet/sub-217B_T1w_bet.nii.gz

# %%
pd.Series(['a','b','c', 'z'])[~pd.Series(['a','b','c', 'z']).isin(['c'])]
# Out:
# 0    a
# 1    b
# 3    z
# dtype: object

# %%
pd.DataFrame(data_dict)['dl_cmd'][0]
# Out:
# 'bet inputs/mri_raw/sub-031B/anat/sub-031B_T1w.nii.gz outputs/bet/sub-031B_T1w_bet.nii.gz --radom_seed 113632864'

# %%
command_row.command_name
# Out:
# 'exists'

# %%
command_row.command
# Out:
# 'inputs/mri-raw/sub-*/mrs/*acq-press*svs.nii.gz'

# %%
variable_command['subject']
# Out:
#   command_name  command  command_value
# 0     variable      svs              1
# 1         grep  sub-\w+             -1

# %%
command_df
# Out:
#   command_name             command  command_value
# 0     variable                 svs              1
# 1      replace  svs(?=.nii.gz) ref             -1
# 2       exists                                 -1

# %%
command_df
# Out:
#   command_name             command  command_value
# 0     variable                 svs              1
# 1      replace  svs(?=.nii.gz) ref              0
# 2       exists                                  0

# %%
re.search("(?<=<!command>).+(?=<!command>)", re.sub('<!\w+>', '<!command>', full_pattern))
# Out:
# <re.Match object; span=(10, 45), match='(svs)<!command>(svs(?=.nii.gz) ref)'>

# %%
re.findall("(?<=<!(variable|exists)>).+", full_pattern)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 re.findall("(?<=<!(variable|exists)>).+", full_pattern)
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/__init__.py:216, in findall(pattern, string, flags)
#     208 def findall(pattern, string, flags=0):
#     209     """Return a list of all non-overlapping matches in the string.
#     210
#     211     If one or more capturing groups are present in the pattern, return
#    (...)
#     214
#     215     Empty matches are included in the result."""
# --> 216     return _compile(pattern, flags).findall(string)
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
#     293               DeprecationWarning)
# --> 294 p = _compiler.compile(pattern, flags)
#     295 if not (flags & DEBUG):
#     296     if len(_cache) >= _MAXCACHE:
#     297         # Drop the oldest item
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/_compiler.py:747, in compile(p, flags)
#     744 else:
#     745     pattern = None
# --> 747 code = _code(p, flags)
#     749 if flags & SRE_FLAG_DEBUG:
#     750     print()
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/_compiler.py:580, in _code(p, flags)
#     577 _compile_info(code, p, flags)
#     579 # compile the pattern
# --> 580 _compile(code, p.data, flags)
#     582 code.append(SUCCESS)
#     584 return code
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/_compiler.py:153, in _compile(code, pattern, flags)
#     151     lo, hi = av[1].getwidth()
#     152     if lo != hi:
# --> 153         raise error("look-behind requires fixed-width pattern")
#     154     emit(lo) # look behind
#     155 _compile(code, av[1], flags)
#
# error: look-behind requires fixed-width pattern

# %%
pd.Series(re.findall("(?<=<!\w+>)", full_pattern))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 pd.Series(re.findall("(?<=<!\w+>)", full_pattern))
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/__init__.py:216, in findall(pattern, string, flags)
#     208 def findall(pattern, string, flags=0):
#     209     """Return a list of all non-overlapping matches in the string.
#     210
#     211     If one or more capturing groups are present in the pattern, return
#    (...)
#     214
#     215     Empty matches are included in the result."""
# --> 216     return _compile(pattern, flags).findall(string)
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
#     293               DeprecationWarning)
# --> 294 p = _compiler.compile(pattern, flags)
#     295 if not (flags & DEBUG):
#     296     if len(_cache) >= _MAXCACHE:
#     297         # Drop the oldest item
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/_compiler.py:747, in compile(p, flags)
#     744 else:
#     745     pattern = None
# --> 747 code = _code(p, flags)
#     749 if flags & SRE_FLAG_DEBUG:
#     750     print()
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/_compiler.py:580, in _code(p, flags)
#     577 _compile_info(code, p, flags)
#     579 # compile the pattern
# --> 580 _compile(code, p.data, flags)
#     582 code.append(SUCCESS)
#     584 return code
#
# File /misc/geminis/ramirezd/miniconda3/envs/py-minis/lib/python3.11/re/_compiler.py:153, in _compile(code, pattern, flags)
#     151     lo, hi = av[1].getwidth()
#     152     if lo != hi:
# --> 153         raise error("look-behind requires fixed-width pattern")
#     154     emit(lo) # look behind
#     155 _compile(code, av[1], flags)
#
# error: look-behind requires fixed-width pattern

# %%
super_dataset_path = Path('/misc/geminis2/ramirezd/test_bet/')

regex_characters = '[a-z,A-Z,0-9,\\\,\/,\-,_,\.,\*,\[,\],\:,\+,\?,\!,\(,\),\<,\>,\s]'
variable_characters = '[a-z,A-Z,0-9,\-,_,]'
path_characters = '[a-z,A-Z,0-9,\\,\/,\-,_,\},\{,\.,\+]'
patterns = "svs == <!glob>(inputs/mri-raw/sub-*/mrs/*acq-press*svs.nii.gz) ; subject == <!variable>(svs)<!grep>(sub-\w+); t1w == <!paste>(inputs/mri-raw/{subject}/anat/{subject}_T1w.nii.gz) ; t2w == <!variable>(t1w)<!replace>(T1w {{subject}}) ; ref == <!variable>(svs)<!replace>(svs(?=.nii.gz) ref)<!exists>"

variable_dict = {}

max_len = 0
max_key = ''
len_list = []

for key_pattern in patterns.split(';'):
    key_pattern = key_pattern.split('==')
    key = key_pattern[0].strip()
    if re.search('\s', key):
        raise Exception("Don't use spaces in variable names.")
    
    full_pattern = key_pattern[1].strip()
    values = full_pattern
    
    if '<!multiply>' in full_pattern:
        values = full_pattern.split('<!multiply>')[0]
        multiply = full_pattern.split('<!multiply>')[1].strip()
        full_pattern = values
    else:
        multiply = False
    
    function_order = pd.Series(re.findall("(?<=\<!)\w+(?=\>)", full_pattern))
    if not function_order.map(function_order_dict).is_monotonic_increasing:
        raise Exception("Not using the correct order of functions: 'glob':1,'paste':2,'variable':3,'grep':4,'replace':5,'unique':6,'multiply':7,'exists':8")
    if function_order.duplicated().any():
        raise Exception("Can't use the same function more than once within the same pattern.")
    
        
    if '<!glob>' in full_pattern:
        if '<!paste>' in full_pattern or '<!variable>' in full_pattern:
            raise Exception("Can't use <!glob>, <!paste> and <!variable> in the same pattern")
        
        try:
            globbing = re.search(f"(?<=\<!glob\>\(){glob_characters}+(?=\))", values).group()
            values = sorted(
                [str(path.relative_to(super_dataset_path)) 
                 for path in Path(super_dataset_path).glob(globbing)]
                )
        except:
            raise Exception('Not a valid globbing pattern.')
        
         
    if '<!paste>' in full_pattern:
        if '<!glob>' in full_pattern or '<!variable>' in full_pattern:
            raise Exception("Can't use <!glob>, <!paste> and <!variable> in the same pattern")
        
        
        glob_vars = list(set(re.findall('(?<=\{)[\w,_,-]+(?=\})', values)))
        
        if not pd.Series(glob_vars).isin(variable_dict.keys()).all():
            raise Exception("Not all variables inside the <!path> pattern exist.")
        
        values =  re.search(f"(?<=\<!paste\>\(){path_characters}+(?=\))", values).group()
        new_values = []
        for row in pd.DataFrame(variable_dict)[glob_vars].to_dict(orient='records'):
            new_values.append(values.format(**row))
        
        values=new_values
        

    if '<!variable>' in full_pattern:
        if '<!glob>' in full_pattern or '<!paste>' in full_pattern:
            raise Exception("Can't use <!glob>, <!paste> and <!variable> in the same pattern")
            
        variable = re.search(f"(?<=\<!variable\>\(){variable_characters}+(?=\))", values).group()
        values = variable_dict[variable]


    
    if '<!grep>' in full_pattern:
        
        regex = full_pattern.replace('<!unique>','').replace('<!multiply>', '').replace('<!exists>', '').strip()
        if '<!replace>' in regex:
            regex = regex.split('<!replace>')[0].strip()
        
        regex = re.search(f"(?<=\<!grep\>\(){regex_characters}+(?=\)$)", regex).group()
    
        values = [try_search(regex, value) for value in values]
        if all(value is None for value in values):
            raise Exception("Not a valid regex or no matches.")
        
        
        
    if '<!replace>' in full_pattern:
        replace_pattern = full_pattern.replace('<!unique>','').replace('<!multiply>', '').replace('<!exists>', '').strip()
        replace_pattern = re.search(f"(?<=\<!replace\>\().+(?=\)$)", replace_pattern).group()
        
        n_spaces = len([character for character in replace_pattern if character == ' '])
        if n_spaces >= 2:
            raise Exception("More than one space within <!replace>. Don't use spaces for string-detection or string-replacement.")
        
        string_detect = replace_pattern.split()[0]
        string_replace = replace_pattern.split()[1]            
        
        new_values = []
        for value in values:
            new_values.append(re.sub(string_detect, string_replace, value).replace('{{' , '{').replace('}}', '}'))
            
        values = new_values
            
        replacement_variables = re.findall("(?<={)\w+(?=})", '{subject}')
        if replacement_variables:
            if not pd.Series(replacement_variables).isin(variable_dict.keys()).all():
                raise Exception("Not all variables inside <!replace> exist.")
            
            new_values = []
            for value, row_dict in zip(values, pd.DataFrame(variable_dict).to_dict(orient='records')):
                new_values.append(value.format(**row_dict))
                
            values = new_values
        
        
        
    if '<!unique>' in full_pattern:
        values = sorted(set(values))       
        
        
    if multiply:
        if isinstance(values, str):
            values = values.split()
        
        if is_numeric(multiply):
            n_elements = int(multiply)
        else:
            n_elements = len(variable_dict[multiply])       
        values = [[value]*n_elements for value in values]
        values = functools.reduce(operator.iconcat, values, [])
    elif isinstance(values, str):
        values = values.split()
        
        
    if '<!exists>' in full_pattern:
        new_values = []
        for value in values:
            if (super_dataset_path / str(value)).is_symlink() or (super_dataset_path / str(value)).exists():
                new_values.append(value)
            else:
                new_values.append(None)
        
        values = new_values
    
    
    len_list.append(len(values))
    if len_list[-1] > max_len:
        max_len = len_list[-1]
        max_key = key

    variable_dict[key] = values
    
    
    
if np.all(max_len % np.array(len_list) == 0):
    for key, value_list in variable_dict.items():
        if key == max_key:
            continue
        variable_dict[key] = value_list * int(max_len / len(value_list))
else:
    raise Exception("Can't broadcast variables.")

# %%
dl_cmd = "bet inputs/mri_raw/{subject}/anat/{subject}_T1w.nii.gz outputs/bet/{subject}_T1w_bet.nii.gz --radom_seed <!random>"
inputs = "inputs/mri_raw/{subject}/anat/{subject}_T1w.nii.gz"
outputs = "outputs/bet/{subject}_T1w_bet.nii.gz"
job_name = "{subject}_T1w_bet"
data_dict = {'job_name':[], 'dl_cmd':[], 'inputs':[], 'outputs':[]}

if ("<!random>" in dl_cmd) and not "{random_seed}" in dl_cmd:
    random_seeds=[]
    for i in range(max_len):
        random_seeds.append(get_random_seed())
    
    dl_cmd = re.sub("<!random>", "{random_seed}", dl_cmd)
    variable_dict['random_seed'] = random_seeds

for row_dict in pd.DataFrame(variable_dict).to_dict(orient='records'):
    data_dict['job_name'].append(job_name.format(**row_dict))
    data_dict['dl_cmd'].append(dl_cmd.format(**row_dict))
    data_dict['inputs'].append(inputs.format(**row_dict))
    data_dict['outputs'].append(outputs.format(**row_dict))

# %%
pd.DataFrame(data_dict)['dl_cmd'].to_list()
# Out:
# ['bet inputs/mri_raw/sub-001A/anat/sub-001A_T1w.nii.gz outputs/bet/sub-001A_T1w_bet.nii.gz --radom_seed 881027',
#  'bet inputs/mri_raw/sub-001A/anat/sub-001A_T1w.nii.gz outputs/bet/sub-001A_T1w_bet.nii.gz --radom_seed 734137',
#  'bet inputs/mri_raw/sub-001B/anat/sub-001B_T1w.nii.gz outputs/bet/sub-001B_T1w_bet.nii.gz --radom_seed 612471',
#  'bet inputs/mri_raw/sub-001B/anat/sub-001B_T1w.nii.gz outputs/bet/sub-001B_T1w_bet.nii.gz --radom_seed 838735',
#  'bet inputs/mri_raw/sub-002A/anat/sub-002A_T1w.nii.gz outputs/bet/sub-002A_T1w_bet.nii.gz --radom_seed 800281',
#  'bet inputs/mri_raw/sub-002A/anat/sub-002A_T1w.nii.gz outputs/bet/sub-002A_T1w_bet.nii.gz --radom_seed 707830',
#  'bet inputs/mri_raw/sub-002B/anat/sub-002B_T1w.nii.gz outputs/bet/sub-002B_T1w_bet.nii.gz --radom_seed 177309',
#  'bet inputs/mri_raw/sub-002B/anat/sub-002B_T1w.nii.gz outputs/bet/sub-002B_T1w_bet.nii.gz --radom_seed 782059',
#  'bet inputs/mri_raw/sub-003A/anat/sub-003A_T1w.nii.gz outputs/bet/sub-003A_T1w_bet.nii.gz --radom_seed 230951',
#  'bet inputs/mri_raw/sub-003A/anat/sub-003A_T1w.nii.gz outputs/bet/sub-003A_T1w_bet.nii.gz --radom_seed 770579',
#  'bet inputs/mri_raw/sub-003B/anat/sub-003B_T1w.nii.gz outputs/bet/sub-003B_T1w_bet.nii.gz --radom_seed 420031',
#  'bet inputs/mri_raw/sub-003B/anat/sub-003B_T1w.nii.gz outputs/bet/sub-003B_T1w_bet.nii.gz --radom_seed 320107',
#  'bet inputs/mri_raw/sub-004A/anat/sub-004A_T1w.nii.gz outputs/bet/sub-004A_T1w_bet.nii.gz --radom_seed 788982',
#  'bet inputs/mri_raw/sub-004A/anat/sub-004A_T1w.nii.gz outputs/bet/sub-004A_T1w_bet.nii.gz --radom_seed 248582',
#  'bet inputs/mri_raw/sub-004B/anat/sub-004B_T1w.nii.gz outputs/bet/sub-004B_T1w_bet.nii.gz --radom_seed 246861',
#  'bet inputs/mri_raw/sub-004B/anat/sub-004B_T1w.nii.gz outputs/bet/sub-004B_T1w_bet.nii.gz --radom_seed 461030',
#  'bet inputs/mri_raw/sub-005A/anat/sub-005A_T1w.nii.gz outputs/bet/sub-005A_T1w_bet.nii.gz --radom_seed 106887',
#  'bet inputs/mri_raw/sub-005A/anat/sub-005A_T1w.nii.gz outputs/bet/sub-005A_T1w_bet.nii.gz --radom_seed 607388',
#  'bet inputs/mri_raw/sub-005B/anat/sub-005B_T1w.nii.gz outputs/bet/sub-005B_T1w_bet.nii.gz --radom_seed 706824',
#  'bet inputs/mri_raw/sub-005B/anat/sub-005B_T1w.nii.gz outputs/bet/sub-005B_T1w_bet.nii.gz --radom_seed 943879',
#  'bet inputs/mri_raw/sub-006A/anat/sub-006A_T1w.nii.gz outputs/bet/sub-006A_T1w_bet.nii.gz --radom_seed 502976',
#  'bet inputs/mri_raw/sub-006A/anat/sub-006A_T1w.nii.gz outputs/bet/sub-006A_T1w_bet.nii.gz --radom_seed 431679',
#  'bet inputs/mri_raw/sub-006B/anat/sub-006B_T1w.nii.gz outputs/bet/sub-006B_T1w_bet.nii.gz --radom_seed 732285',
#  'bet inputs/mri_raw/sub-006B/anat/sub-006B_T1w.nii.gz outputs/bet/sub-006B_T1w_bet.nii.gz --radom_seed 735023',
#  'bet inputs/mri_raw/sub-007A/anat/sub-007A_T1w.nii.gz outputs/bet/sub-007A_T1w_bet.nii.gz --radom_seed 255533',
#  'bet inputs/mri_raw/sub-007A/anat/sub-007A_T1w.nii.gz outputs/bet/sub-007A_T1w_bet.nii.gz --radom_seed 937280',
#  'bet inputs/mri_raw/sub-007B/anat/sub-007B_T1w.nii.gz outputs/bet/sub-007B_T1w_bet.nii.gz --radom_seed 351832',
#  'bet inputs/mri_raw/sub-007B/anat/sub-007B_T1w.nii.gz outputs/bet/sub-007B_T1w_bet.nii.gz --radom_seed 851791',
#  'bet inputs/mri_raw/sub-008A/anat/sub-008A_T1w.nii.gz outputs/bet/sub-008A_T1w_bet.nii.gz --radom_seed 263092',
#  'bet inputs/mri_raw/sub-008A/anat/sub-008A_T1w.nii.gz outputs/bet/sub-008A_T1w_bet.nii.gz --radom_seed 635856',
#  'bet inputs/mri_raw/sub-008B/anat/sub-008B_T1w.nii.gz outputs/bet/sub-008B_T1w_bet.nii.gz --radom_seed 187562',
#  'bet inputs/mri_raw/sub-008B/anat/sub-008B_T1w.nii.gz outputs/bet/sub-008B_T1w_bet.nii.gz --radom_seed 880178',
#  'bet inputs/mri_raw/sub-009A/anat/sub-009A_T1w.nii.gz outputs/bet/sub-009A_T1w_bet.nii.gz --radom_seed 700679',
#  'bet inputs/mri_raw/sub-009A/anat/sub-009A_T1w.nii.gz outputs/bet/sub-009A_T1w_bet.nii.gz --radom_seed 256516',
#  'bet inputs/mri_raw/sub-009B/anat/sub-009B_T1w.nii.gz outputs/bet/sub-009B_T1w_bet.nii.gz --radom_seed 274230',
#  'bet inputs/mri_raw/sub-009B/anat/sub-009B_T1w.nii.gz outputs/bet/sub-009B_T1w_bet.nii.gz --radom_seed 385468',
#  'bet inputs/mri_raw/sub-010A/anat/sub-010A_T1w.nii.gz outputs/bet/sub-010A_T1w_bet.nii.gz --radom_seed 990084',
#  'bet inputs/mri_raw/sub-010A/anat/sub-010A_T1w.nii.gz outputs/bet/sub-010A_T1w_bet.nii.gz --radom_seed 808178',
#  'bet inputs/mri_raw/sub-010B/anat/sub-010B_T1w.nii.gz outputs/bet/sub-010B_T1w_bet.nii.gz --radom_seed 272905',
#  'bet inputs/mri_raw/sub-010B/anat/sub-010B_T1w.nii.gz outputs/bet/sub-010B_T1w_bet.nii.gz --radom_seed 747566',
#  'bet inputs/mri_raw/sub-010C/anat/sub-010C_T1w.nii.gz outputs/bet/sub-010C_T1w_bet.nii.gz --radom_seed 297545',
#  'bet inputs/mri_raw/sub-010C/anat/sub-010C_T1w.nii.gz outputs/bet/sub-010C_T1w_bet.nii.gz --radom_seed 655646',
#  'bet inputs/mri_raw/sub-011A/anat/sub-011A_T1w.nii.gz outputs/bet/sub-011A_T1w_bet.nii.gz --radom_seed 983715',
#  'bet inputs/mri_raw/sub-011A/anat/sub-011A_T1w.nii.gz outputs/bet/sub-011A_T1w_bet.nii.gz --radom_seed 976760',
#  'bet inputs/mri_raw/sub-011B/anat/sub-011B_T1w.nii.gz outputs/bet/sub-011B_T1w_bet.nii.gz --radom_seed 550664',
#  'bet inputs/mri_raw/sub-011B/anat/sub-011B_T1w.nii.gz outputs/bet/sub-011B_T1w_bet.nii.gz --radom_seed 680629',
#  'bet inputs/mri_raw/sub-012A/anat/sub-012A_T1w.nii.gz outputs/bet/sub-012A_T1w_bet.nii.gz --radom_seed 470631',
#  'bet inputs/mri_raw/sub-012A/anat/sub-012A_T1w.nii.gz outputs/bet/sub-012A_T1w_bet.nii.gz --radom_seed 496296',
#  'bet inputs/mri_raw/sub-012B/anat/sub-012B_T1w.nii.gz outputs/bet/sub-012B_T1w_bet.nii.gz --radom_seed 331339',
#  'bet inputs/mri_raw/sub-012B/anat/sub-012B_T1w.nii.gz outputs/bet/sub-012B_T1w_bet.nii.gz --radom_seed 922878',
#  'bet inputs/mri_raw/sub-013A/anat/sub-013A_T1w.nii.gz outputs/bet/sub-013A_T1w_bet.nii.gz --radom_seed 526557',
#  'bet inputs/mri_raw/sub-013A/anat/sub-013A_T1w.nii.gz outputs/bet/sub-013A_T1w_bet.nii.gz --radom_seed 105828',
#  'bet inputs/mri_raw/sub-013B/anat/sub-013B_T1w.nii.gz outputs/bet/sub-013B_T1w_bet.nii.gz --radom_seed 728773',
#  'bet inputs/mri_raw/sub-013B/anat/sub-013B_T1w.nii.gz outputs/bet/sub-013B_T1w_bet.nii.gz --radom_seed 823179',
#  'bet inputs/mri_raw/sub-014A/anat/sub-014A_T1w.nii.gz outputs/bet/sub-014A_T1w_bet.nii.gz --radom_seed 877716',
#  'bet inputs/mri_raw/sub-014A/anat/sub-014A_T1w.nii.gz outputs/bet/sub-014A_T1w_bet.nii.gz --radom_seed 124807',
#  'bet inputs/mri_raw/sub-014B/anat/sub-014B_T1w.nii.gz outputs/bet/sub-014B_T1w_bet.nii.gz --radom_seed 395127',
#  'bet inputs/mri_raw/sub-014B/anat/sub-014B_T1w.nii.gz outputs/bet/sub-014B_T1w_bet.nii.gz --radom_seed 353486',
#  'bet inputs/mri_raw/sub-015A/anat/sub-015A_T1w.nii.gz outputs/bet/sub-015A_T1w_bet.nii.gz --radom_seed 764145',
#  'bet inputs/mri_raw/sub-015A/anat/sub-015A_T1w.nii.gz outputs/bet/sub-015A_T1w_bet.nii.gz --radom_seed 625043',
#  'bet inputs/mri_raw/sub-015B/anat/sub-015B_T1w.nii.gz outputs/bet/sub-015B_T1w_bet.nii.gz --radom_seed 397884',
#  'bet inputs/mri_raw/sub-015B/anat/sub-015B_T1w.nii.gz outputs/bet/sub-015B_T1w_bet.nii.gz --radom_seed 113866',
#  'bet inputs/mri_raw/sub-016A/anat/sub-016A_T1w.nii.gz outputs/bet/sub-016A_T1w_bet.nii.gz --radom_seed 696016',
#  'bet inputs/mri_raw/sub-016A/anat/sub-016A_T1w.nii.gz outputs/bet/sub-016A_T1w_bet.nii.gz --radom_seed 313298',
#  'bet inputs/mri_raw/sub-016B/anat/sub-016B_T1w.nii.gz outputs/bet/sub-016B_T1w_bet.nii.gz --radom_seed 242608',
#  'bet inputs/mri_raw/sub-016B/anat/sub-016B_T1w.nii.gz outputs/bet/sub-016B_T1w_bet.nii.gz --radom_seed 427966',
#  'bet inputs/mri_raw/sub-017A/anat/sub-017A_T1w.nii.gz outputs/bet/sub-017A_T1w_bet.nii.gz --radom_seed 444349',
#  'bet inputs/mri_raw/sub-017A/anat/sub-017A_T1w.nii.gz outputs/bet/sub-017A_T1w_bet.nii.gz --radom_seed 960825',
#  'bet inputs/mri_raw/sub-017B/anat/sub-017B_T1w.nii.gz outputs/bet/sub-017B_T1w_bet.nii.gz --radom_seed 992300',
#  'bet inputs/mri_raw/sub-017B/anat/sub-017B_T1w.nii.gz outputs/bet/sub-017B_T1w_bet.nii.gz --radom_seed 693784',
#  'bet inputs/mri_raw/sub-018A/anat/sub-018A_T1w.nii.gz outputs/bet/sub-018A_T1w_bet.nii.gz --radom_seed 820971',
#  'bet inputs/mri_raw/sub-018A/anat/sub-018A_T1w.nii.gz outputs/bet/sub-018A_T1w_bet.nii.gz --radom_seed 194065',
#  'bet inputs/mri_raw/sub-018B/anat/sub-018B_T1w.nii.gz outputs/bet/sub-018B_T1w_bet.nii.gz --radom_seed 491054',
#  'bet inputs/mri_raw/sub-018B/anat/sub-018B_T1w.nii.gz outputs/bet/sub-018B_T1w_bet.nii.gz --radom_seed 114132',
#  'bet inputs/mri_raw/sub-019A/anat/sub-019A_T1w.nii.gz outputs/bet/sub-019A_T1w_bet.nii.gz --radom_seed 174420',
#  'bet inputs/mri_raw/sub-019A/anat/sub-019A_T1w.nii.gz outputs/bet/sub-019A_T1w_bet.nii.gz --radom_seed 515731',
#  'bet inputs/mri_raw/sub-019B/anat/sub-019B_T1w.nii.gz outputs/bet/sub-019B_T1w_bet.nii.gz --radom_seed 390961',
#  'bet inputs/mri_raw/sub-019B/anat/sub-019B_T1w.nii.gz outputs/bet/sub-019B_T1w_bet.nii.gz --radom_seed 538941',
#  'bet inputs/mri_raw/sub-020A/anat/sub-020A_T1w.nii.gz outputs/bet/sub-020A_T1w_bet.nii.gz --radom_seed 767200',
#  'bet inputs/mri_raw/sub-020A/anat/sub-020A_T1w.nii.gz outputs/bet/sub-020A_T1w_bet.nii.gz --radom_seed 204660',
#  'bet inputs/mri_raw/sub-020B/anat/sub-020B_T1w.nii.gz outputs/bet/sub-020B_T1w_bet.nii.gz --radom_seed 734089',
#  'bet inputs/mri_raw/sub-020B/anat/sub-020B_T1w.nii.gz outputs/bet/sub-020B_T1w_bet.nii.gz --radom_seed 589961',
#  'bet inputs/mri_raw/sub-021A/anat/sub-021A_T1w.nii.gz outputs/bet/sub-021A_T1w_bet.nii.gz --radom_seed 323004',
#  'bet inputs/mri_raw/sub-021A/anat/sub-021A_T1w.nii.gz outputs/bet/sub-021A_T1w_bet.nii.gz --radom_seed 799138',
#  'bet inputs/mri_raw/sub-021B/anat/sub-021B_T1w.nii.gz outputs/bet/sub-021B_T1w_bet.nii.gz --radom_seed 454578',
#  'bet inputs/mri_raw/sub-021B/anat/sub-021B_T1w.nii.gz outputs/bet/sub-021B_T1w_bet.nii.gz --radom_seed 342388',
#  'bet inputs/mri_raw/sub-022B/anat/sub-022B_T1w.nii.gz outputs/bet/sub-022B_T1w_bet.nii.gz --radom_seed 430999',
#  'bet inputs/mri_raw/sub-022B/anat/sub-022B_T1w.nii.gz outputs/bet/sub-022B_T1w_bet.nii.gz --radom_seed 751218',
#  'bet inputs/mri_raw/sub-023A/anat/sub-023A_T1w.nii.gz outputs/bet/sub-023A_T1w_bet.nii.gz --radom_seed 248261',
#  'bet inputs/mri_raw/sub-023A/anat/sub-023A_T1w.nii.gz outputs/bet/sub-023A_T1w_bet.nii.gz --radom_seed 172917',
#  'bet inputs/mri_raw/sub-023B/anat/sub-023B_T1w.nii.gz outputs/bet/sub-023B_T1w_bet.nii.gz --radom_seed 433251',
#  'bet inputs/mri_raw/sub-023B/anat/sub-023B_T1w.nii.gz outputs/bet/sub-023B_T1w_bet.nii.gz --radom_seed 790439',
#  'bet inputs/mri_raw/sub-024A/anat/sub-024A_T1w.nii.gz outputs/bet/sub-024A_T1w_bet.nii.gz --radom_seed 188656',
#  'bet inputs/mri_raw/sub-024A/anat/sub-024A_T1w.nii.gz outputs/bet/sub-024A_T1w_bet.nii.gz --radom_seed 735676',
#  'bet inputs/mri_raw/sub-024B/anat/sub-024B_T1w.nii.gz outputs/bet/sub-024B_T1w_bet.nii.gz --radom_seed 943995',
#  'bet inputs/mri_raw/sub-024B/anat/sub-024B_T1w.nii.gz outputs/bet/sub-024B_T1w_bet.nii.gz --radom_seed 882631',
#  'bet inputs/mri_raw/sub-025A/anat/sub-025A_T1w.nii.gz outputs/bet/sub-025A_T1w_bet.nii.gz --radom_seed 616998',
#  'bet inputs/mri_raw/sub-025A/anat/sub-025A_T1w.nii.gz outputs/bet/sub-025A_T1w_bet.nii.gz --radom_seed 987104',
#  'bet inputs/mri_raw/sub-025B/anat/sub-025B_T1w.nii.gz outputs/bet/sub-025B_T1w_bet.nii.gz --radom_seed 856959',
#  'bet inputs/mri_raw/sub-025B/anat/sub-025B_T1w.nii.gz outputs/bet/sub-025B_T1w_bet.nii.gz --radom_seed 335094',
#  'bet inputs/mri_raw/sub-026A/anat/sub-026A_T1w.nii.gz outputs/bet/sub-026A_T1w_bet.nii.gz --radom_seed 122009',
#  'bet inputs/mri_raw/sub-026A/anat/sub-026A_T1w.nii.gz outputs/bet/sub-026A_T1w_bet.nii.gz --radom_seed 752320',
#  'bet inputs/mri_raw/sub-026B/anat/sub-026B_T1w.nii.gz outputs/bet/sub-026B_T1w_bet.nii.gz --radom_seed 873222',
#  'bet inputs/mri_raw/sub-026B/anat/sub-026B_T1w.nii.gz outputs/bet/sub-026B_T1w_bet.nii.gz --radom_seed 565141',
#  'bet inputs/mri_raw/sub-027A/anat/sub-027A_T1w.nii.gz outputs/bet/sub-027A_T1w_bet.nii.gz --radom_seed 297268',
#  'bet inputs/mri_raw/sub-027A/anat/sub-027A_T1w.nii.gz outputs/bet/sub-027A_T1w_bet.nii.gz --radom_seed 889304',
#  'bet inputs/mri_raw/sub-027B/anat/sub-027B_T1w.nii.gz outputs/bet/sub-027B_T1w_bet.nii.gz --radom_seed 813551',
#  'bet inputs/mri_raw/sub-027B/anat/sub-027B_T1w.nii.gz outputs/bet/sub-027B_T1w_bet.nii.gz --radom_seed 833180',
#  'bet inputs/mri_raw/sub-028A/anat/sub-028A_T1w.nii.gz outputs/bet/sub-028A_T1w_bet.nii.gz --radom_seed 515195',
#  'bet inputs/mri_raw/sub-028A/anat/sub-028A_T1w.nii.gz outputs/bet/sub-028A_T1w_bet.nii.gz --radom_seed 404314',
#  'bet inputs/mri_raw/sub-028B/anat/sub-028B_T1w.nii.gz outputs/bet/sub-028B_T1w_bet.nii.gz --radom_seed 221625',
#  'bet inputs/mri_raw/sub-028B/anat/sub-028B_T1w.nii.gz outputs/bet/sub-028B_T1w_bet.nii.gz --radom_seed 431664',
#  'bet inputs/mri_raw/sub-029A/anat/sub-029A_T1w.nii.gz outputs/bet/sub-029A_T1w_bet.nii.gz --radom_seed 471730',
#  'bet inputs/mri_raw/sub-029A/anat/sub-029A_T1w.nii.gz outputs/bet/sub-029A_T1w_bet.nii.gz --radom_seed 712430',
#  'bet inputs/mri_raw/sub-029B/anat/sub-029B_T1w.nii.gz outputs/bet/sub-029B_T1w_bet.nii.gz --radom_seed 349928',
#  'bet inputs/mri_raw/sub-029B/anat/sub-029B_T1w.nii.gz outputs/bet/sub-029B_T1w_bet.nii.gz --radom_seed 281904',
#  'bet inputs/mri_raw/sub-030A/anat/sub-030A_T1w.nii.gz outputs/bet/sub-030A_T1w_bet.nii.gz --radom_seed 632526',
#  'bet inputs/mri_raw/sub-030A/anat/sub-030A_T1w.nii.gz outputs/bet/sub-030A_T1w_bet.nii.gz --radom_seed 266698',
#  'bet inputs/mri_raw/sub-030B/anat/sub-030B_T1w.nii.gz outputs/bet/sub-030B_T1w_bet.nii.gz --radom_seed 274951',
#  'bet inputs/mri_raw/sub-030B/anat/sub-030B_T1w.nii.gz outputs/bet/sub-030B_T1w_bet.nii.gz --radom_seed 255258',
#  'bet inputs/mri_raw/sub-031A/anat/sub-031A_T1w.nii.gz outputs/bet/sub-031A_T1w_bet.nii.gz --radom_seed 491131',
#  'bet inputs/mri_raw/sub-031A/anat/sub-031A_T1w.nii.gz outputs/bet/sub-031A_T1w_bet.nii.gz --radom_seed 900386',
#  'bet inputs/mri_raw/sub-031B/anat/sub-031B_T1w.nii.gz outputs/bet/sub-031B_T1w_bet.nii.gz --radom_seed 225486',
#  'bet inputs/mri_raw/sub-031B/anat/sub-031B_T1w.nii.gz outputs/bet/sub-031B_T1w_bet.nii.gz --radom_seed 681121',
#  'bet inputs/mri_raw/sub-032A/anat/sub-032A_T1w.nii.gz outputs/bet/sub-032A_T1w_bet.nii.gz --radom_seed 998458',
#  'bet inputs/mri_raw/sub-032A/anat/sub-032A_T1w.nii.gz outputs/bet/sub-032A_T1w_bet.nii.gz --radom_seed 759199',
#  'bet inputs/mri_raw/sub-032B/anat/sub-032B_T1w.nii.gz outputs/bet/sub-032B_T1w_bet.nii.gz --radom_seed 213558',
#  'bet inputs/mri_raw/sub-032B/anat/sub-032B_T1w.nii.gz outputs/bet/sub-032B_T1w_bet.nii.gz --radom_seed 739000',
#  'bet inputs/mri_raw/sub-033A/anat/sub-033A_T1w.nii.gz outputs/bet/sub-033A_T1w_bet.nii.gz --radom_seed 373660',
#  'bet inputs/mri_raw/sub-033A/anat/sub-033A_T1w.nii.gz outputs/bet/sub-033A_T1w_bet.nii.gz --radom_seed 879319',
#  'bet inputs/mri_raw/sub-033B/anat/sub-033B_T1w.nii.gz outputs/bet/sub-033B_T1w_bet.nii.gz --radom_seed 910173',
#  'bet inputs/mri_raw/sub-033B/anat/sub-033B_T1w.nii.gz outputs/bet/sub-033B_T1w_bet.nii.gz --radom_seed 823302',
#  'bet inputs/mri_raw/sub-034A/anat/sub-034A_T1w.nii.gz outputs/bet/sub-034A_T1w_bet.nii.gz --radom_seed 890057',
#  'bet inputs/mri_raw/sub-034A/anat/sub-034A_T1w.nii.gz outputs/bet/sub-034A_T1w_bet.nii.gz --radom_seed 434922',
#  'bet inputs/mri_raw/sub-034B/anat/sub-034B_T1w.nii.gz outputs/bet/sub-034B_T1w_bet.nii.gz --radom_seed 593070',
#  'bet inputs/mri_raw/sub-034B/anat/sub-034B_T1w.nii.gz outputs/bet/sub-034B_T1w_bet.nii.gz --radom_seed 487645',
#  'bet inputs/mri_raw/sub-035A/anat/sub-035A_T1w.nii.gz outputs/bet/sub-035A_T1w_bet.nii.gz --radom_seed 399263',
#  'bet inputs/mri_raw/sub-035A/anat/sub-035A_T1w.nii.gz outputs/bet/sub-035A_T1w_bet.nii.gz --radom_seed 686441',
#  'bet inputs/mri_raw/sub-035B/anat/sub-035B_T1w.nii.gz outputs/bet/sub-035B_T1w_bet.nii.gz --radom_seed 844521',
#  'bet inputs/mri_raw/sub-035B/anat/sub-035B_T1w.nii.gz outputs/bet/sub-035B_T1w_bet.nii.gz --radom_seed 103966',
#  'bet inputs/mri_raw/sub-036A/anat/sub-036A_T1w.nii.gz outputs/bet/sub-036A_T1w_bet.nii.gz --radom_seed 507635',
#  'bet inputs/mri_raw/sub-036A/anat/sub-036A_T1w.nii.gz outputs/bet/sub-036A_T1w_bet.nii.gz --radom_seed 557897',
#  'bet inputs/mri_raw/sub-036B/anat/sub-036B_T1w.nii.gz outputs/bet/sub-036B_T1w_bet.nii.gz --radom_seed 440482',
#  'bet inputs/mri_raw/sub-036B/anat/sub-036B_T1w.nii.gz outputs/bet/sub-036B_T1w_bet.nii.gz --radom_seed 332749',
#  'bet inputs/mri_raw/sub-037A/anat/sub-037A_T1w.nii.gz outputs/bet/sub-037A_T1w_bet.nii.gz --radom_seed 776640',
#  'bet inputs/mri_raw/sub-037A/anat/sub-037A_T1w.nii.gz outputs/bet/sub-037A_T1w_bet.nii.gz --radom_seed 542936',
#  'bet inputs/mri_raw/sub-037B/anat/sub-037B_T1w.nii.gz outputs/bet/sub-037B_T1w_bet.nii.gz --radom_seed 177373',
#  'bet inputs/mri_raw/sub-037B/anat/sub-037B_T1w.nii.gz outputs/bet/sub-037B_T1w_bet.nii.gz --radom_seed 622352',
#  'bet inputs/mri_raw/sub-038A/anat/sub-038A_T1w.nii.gz outputs/bet/sub-038A_T1w_bet.nii.gz --radom_seed 869008',
#  'bet inputs/mri_raw/sub-038A/anat/sub-038A_T1w.nii.gz outputs/bet/sub-038A_T1w_bet.nii.gz --radom_seed 539520',
#  'bet inputs/mri_raw/sub-038B/anat/sub-038B_T1w.nii.gz outputs/bet/sub-038B_T1w_bet.nii.gz --radom_seed 185634',
#  'bet inputs/mri_raw/sub-038B/anat/sub-038B_T1w.nii.gz outputs/bet/sub-038B_T1w_bet.nii.gz --radom_seed 473671',
#  'bet inputs/mri_raw/sub-039A/anat/sub-039A_T1w.nii.gz outputs/bet/sub-039A_T1w_bet.nii.gz --radom_seed 574839',
#  'bet inputs/mri_raw/sub-039A/anat/sub-039A_T1w.nii.gz outputs/bet/sub-039A_T1w_bet.nii.gz --radom_seed 434196',
#  'bet inputs/mri_raw/sub-039B/anat/sub-039B_T1w.nii.gz outputs/bet/sub-039B_T1w_bet.nii.gz --radom_seed 973342',
#  'bet inputs/mri_raw/sub-039B/anat/sub-039B_T1w.nii.gz outputs/bet/sub-039B_T1w_bet.nii.gz --radom_seed 675899',
#  'bet inputs/mri_raw/sub-040A/anat/sub-040A_T1w.nii.gz outputs/bet/sub-040A_T1w_bet.nii.gz --radom_seed 435258',
#  'bet inputs/mri_raw/sub-040A/anat/sub-040A_T1w.nii.gz outputs/bet/sub-040A_T1w_bet.nii.gz --radom_seed 120275',
#  'bet inputs/mri_raw/sub-040B/anat/sub-040B_T1w.nii.gz outputs/bet/sub-040B_T1w_bet.nii.gz --radom_seed 809016',
#  'bet inputs/mri_raw/sub-040B/anat/sub-040B_T1w.nii.gz outputs/bet/sub-040B_T1w_bet.nii.gz --radom_seed 926601',
#  'bet inputs/mri_raw/sub-041A/anat/sub-041A_T1w.nii.gz outputs/bet/sub-041A_T1w_bet.nii.gz --radom_seed 757768',
#  'bet inputs/mri_raw/sub-041A/anat/sub-041A_T1w.nii.gz outputs/bet/sub-041A_T1w_bet.nii.gz --radom_seed 366984',
#  'bet inputs/mri_raw/sub-041B/anat/sub-041B_T1w.nii.gz outputs/bet/sub-041B_T1w_bet.nii.gz --radom_seed 329270',
#  'bet inputs/mri_raw/sub-041B/anat/sub-041B_T1w.nii.gz outputs/bet/sub-041B_T1w_bet.nii.gz --radom_seed 349582',
#  'bet inputs/mri_raw/sub-047A/anat/sub-047A_T1w.nii.gz outputs/bet/sub-047A_T1w_bet.nii.gz --radom_seed 323684',
#  'bet inputs/mri_raw/sub-047A/anat/sub-047A_T1w.nii.gz outputs/bet/sub-047A_T1w_bet.nii.gz --radom_seed 879915',
#  'bet inputs/mri_raw/sub-047B/anat/sub-047B_T1w.nii.gz outputs/bet/sub-047B_T1w_bet.nii.gz --radom_seed 917794',
#  'bet inputs/mri_raw/sub-047B/anat/sub-047B_T1w.nii.gz outputs/bet/sub-047B_T1w_bet.nii.gz --radom_seed 475749',
#  'bet inputs/mri_raw/sub-048A/anat/sub-048A_T1w.nii.gz outputs/bet/sub-048A_T1w_bet.nii.gz --radom_seed 138760',
#  'bet inputs/mri_raw/sub-048A/anat/sub-048A_T1w.nii.gz outputs/bet/sub-048A_T1w_bet.nii.gz --radom_seed 488384',
#  'bet inputs/mri_raw/sub-048B/anat/sub-048B_T1w.nii.gz outputs/bet/sub-048B_T1w_bet.nii.gz --radom_seed 787796',
#  'bet inputs/mri_raw/sub-048B/anat/sub-048B_T1w.nii.gz outputs/bet/sub-048B_T1w_bet.nii.gz --radom_seed 131733',
#  'bet inputs/mri_raw/sub-049A/anat/sub-049A_T1w.nii.gz outputs/bet/sub-049A_T1w_bet.nii.gz --radom_seed 699984',
#  'bet inputs/mri_raw/sub-049A/anat/sub-049A_T1w.nii.gz outputs/bet/sub-049A_T1w_bet.nii.gz --radom_seed 994633',
#  'bet inputs/mri_raw/sub-049B/anat/sub-049B_T1w.nii.gz outputs/bet/sub-049B_T1w_bet.nii.gz --radom_seed 600571',
#  'bet inputs/mri_raw/sub-049B/anat/sub-049B_T1w.nii.gz outputs/bet/sub-049B_T1w_bet.nii.gz --radom_seed 271560',
#  'bet inputs/mri_raw/sub-050A/anat/sub-050A_T1w.nii.gz outputs/bet/sub-050A_T1w_bet.nii.gz --radom_seed 479090',
#  'bet inputs/mri_raw/sub-050A/anat/sub-050A_T1w.nii.gz outputs/bet/sub-050A_T1w_bet.nii.gz --radom_seed 904911',
#  'bet inputs/mri_raw/sub-050B/anat/sub-050B_T1w.nii.gz outputs/bet/sub-050B_T1w_bet.nii.gz --radom_seed 179116',
#  'bet inputs/mri_raw/sub-050B/anat/sub-050B_T1w.nii.gz outputs/bet/sub-050B_T1w_bet.nii.gz --radom_seed 529128',
#  'bet inputs/mri_raw/sub-051A/anat/sub-051A_T1w.nii.gz outputs/bet/sub-051A_T1w_bet.nii.gz --radom_seed 611878',
#  'bet inputs/mri_raw/sub-051A/anat/sub-051A_T1w.nii.gz outputs/bet/sub-051A_T1w_bet.nii.gz --radom_seed 192433',
#  'bet inputs/mri_raw/sub-051B/anat/sub-051B_T1w.nii.gz outputs/bet/sub-051B_T1w_bet.nii.gz --radom_seed 319292',
#  'bet inputs/mri_raw/sub-051B/anat/sub-051B_T1w.nii.gz outputs/bet/sub-051B_T1w_bet.nii.gz --radom_seed 220137',
#  'bet inputs/mri_raw/sub-052A/anat/sub-052A_T1w.nii.gz outputs/bet/sub-052A_T1w_bet.nii.gz --radom_seed 216175',
#  'bet inputs/mri_raw/sub-052A/anat/sub-052A_T1w.nii.gz outputs/bet/sub-052A_T1w_bet.nii.gz --radom_seed 374158',
#  'bet inputs/mri_raw/sub-052B/anat/sub-052B_T1w.nii.gz outputs/bet/sub-052B_T1w_bet.nii.gz --radom_seed 463927',
#  'bet inputs/mri_raw/sub-052B/anat/sub-052B_T1w.nii.gz outputs/bet/sub-052B_T1w_bet.nii.gz --radom_seed 760225',
#  'bet inputs/mri_raw/sub-054A/anat/sub-054A_T1w.nii.gz outputs/bet/sub-054A_T1w_bet.nii.gz --radom_seed 330740',
#  'bet inputs/mri_raw/sub-054A/anat/sub-054A_T1w.nii.gz outputs/bet/sub-054A_T1w_bet.nii.gz --radom_seed 909034',
#  'bet inputs/mri_raw/sub-054B/anat/sub-054B_T1w.nii.gz outputs/bet/sub-054B_T1w_bet.nii.gz --radom_seed 559263',
#  'bet inputs/mri_raw/sub-054B/anat/sub-054B_T1w.nii.gz outputs/bet/sub-054B_T1w_bet.nii.gz --radom_seed 935791',
#  'bet inputs/mri_raw/sub-055A/anat/sub-055A_T1w.nii.gz outputs/bet/sub-055A_T1w_bet.nii.gz --radom_seed 488656',
#  'bet inputs/mri_raw/sub-055A/anat/sub-055A_T1w.nii.gz outputs/bet/sub-055A_T1w_bet.nii.gz --radom_seed 888693',
#  'bet inputs/mri_raw/sub-055B/anat/sub-055B_T1w.nii.gz outputs/bet/sub-055B_T1w_bet.nii.gz --radom_seed 856919',
#  'bet inputs/mri_raw/sub-055B/anat/sub-055B_T1w.nii.gz outputs/bet/sub-055B_T1w_bet.nii.gz --radom_seed 116677',
#  'bet inputs/mri_raw/sub-056A/anat/sub-056A_T1w.nii.gz outputs/bet/sub-056A_T1w_bet.nii.gz --radom_seed 738233',
#  'bet inputs/mri_raw/sub-056A/anat/sub-056A_T1w.nii.gz outputs/bet/sub-056A_T1w_bet.nii.gz --radom_seed 382892',
#  'bet inputs/mri_raw/sub-056B/anat/sub-056B_T1w.nii.gz outputs/bet/sub-056B_T1w_bet.nii.gz --radom_seed 449099',
#  'bet inputs/mri_raw/sub-056B/anat/sub-056B_T1w.nii.gz outputs/bet/sub-056B_T1w_bet.nii.gz --radom_seed 452144',
#  'bet inputs/mri_raw/sub-057A/anat/sub-057A_T1w.nii.gz outputs/bet/sub-057A_T1w_bet.nii.gz --radom_seed 521372',
#  'bet inputs/mri_raw/sub-057A/anat/sub-057A_T1w.nii.gz outputs/bet/sub-057A_T1w_bet.nii.gz --radom_seed 386738',
#  'bet inputs/mri_raw/sub-057B/anat/sub-057B_T1w.nii.gz outputs/bet/sub-057B_T1w_bet.nii.gz --radom_seed 413593',
#  'bet inputs/mri_raw/sub-057B/anat/sub-057B_T1w.nii.gz outputs/bet/sub-057B_T1w_bet.nii.gz --radom_seed 683616',
#  'bet inputs/mri_raw/sub-058A/anat/sub-058A_T1w.nii.gz outputs/bet/sub-058A_T1w_bet.nii.gz --radom_seed 338111',
#  'bet inputs/mri_raw/sub-058A/anat/sub-058A_T1w.nii.gz outputs/bet/sub-058A_T1w_bet.nii.gz --radom_seed 516361',
#  'bet inputs/mri_raw/sub-058B/anat/sub-058B_T1w.nii.gz outputs/bet/sub-058B_T1w_bet.nii.gz --radom_seed 342198',
#  'bet inputs/mri_raw/sub-058B/anat/sub-058B_T1w.nii.gz outputs/bet/sub-058B_T1w_bet.nii.gz --radom_seed 475535',
#  'bet inputs/mri_raw/sub-059A/anat/sub-059A_T1w.nii.gz outputs/bet/sub-059A_T1w_bet.nii.gz --radom_seed 700168',
#  'bet inputs/mri_raw/sub-059A/anat/sub-059A_T1w.nii.gz outputs/bet/sub-059A_T1w_bet.nii.gz --radom_seed 153200',
#  'bet inputs/mri_raw/sub-059B/anat/sub-059B_T1w.nii.gz outputs/bet/sub-059B_T1w_bet.nii.gz --radom_seed 565655',
#  'bet inputs/mri_raw/sub-059B/anat/sub-059B_T1w.nii.gz outputs/bet/sub-059B_T1w_bet.nii.gz --radom_seed 871169',
#  'bet inputs/mri_raw/sub-060A/anat/sub-060A_T1w.nii.gz outputs/bet/sub-060A_T1w_bet.nii.gz --radom_seed 709409',
#  'bet inputs/mri_raw/sub-060A/anat/sub-060A_T1w.nii.gz outputs/bet/sub-060A_T1w_bet.nii.gz --radom_seed 953721',
#  'bet inputs/mri_raw/sub-060B/anat/sub-060B_T1w.nii.gz outputs/bet/sub-060B_T1w_bet.nii.gz --radom_seed 444002',
#  'bet inputs/mri_raw/sub-060B/anat/sub-060B_T1w.nii.gz outputs/bet/sub-060B_T1w_bet.nii.gz --radom_seed 961351',
#  'bet inputs/mri_raw/sub-061A/anat/sub-061A_T1w.nii.gz outputs/bet/sub-061A_T1w_bet.nii.gz --radom_seed 480636',
#  'bet inputs/mri_raw/sub-061A/anat/sub-061A_T1w.nii.gz outputs/bet/sub-061A_T1w_bet.nii.gz --radom_seed 261159',
#  'bet inputs/mri_raw/sub-061B/anat/sub-061B_T1w.nii.gz outputs/bet/sub-061B_T1w_bet.nii.gz --radom_seed 667548',
#  'bet inputs/mri_raw/sub-061B/anat/sub-061B_T1w.nii.gz outputs/bet/sub-061B_T1w_bet.nii.gz --radom_seed 480589',
#  'bet inputs/mri_raw/sub-062A/anat/sub-062A_T1w.nii.gz outputs/bet/sub-062A_T1w_bet.nii.gz --radom_seed 345147',
#  'bet inputs/mri_raw/sub-062A/anat/sub-062A_T1w.nii.gz outputs/bet/sub-062A_T1w_bet.nii.gz --radom_seed 944495',
#  'bet inputs/mri_raw/sub-062B/anat/sub-062B_T1w.nii.gz outputs/bet/sub-062B_T1w_bet.nii.gz --radom_seed 523305',
#  'bet inputs/mri_raw/sub-062B/anat/sub-062B_T1w.nii.gz outputs/bet/sub-062B_T1w_bet.nii.gz --radom_seed 163973',
#  'bet inputs/mri_raw/sub-063A/anat/sub-063A_T1w.nii.gz outputs/bet/sub-063A_T1w_bet.nii.gz --radom_seed 348432',
#  'bet inputs/mri_raw/sub-063A/anat/sub-063A_T1w.nii.gz outputs/bet/sub-063A_T1w_bet.nii.gz --radom_seed 330066',
#  'bet inputs/mri_raw/sub-063B/anat/sub-063B_T1w.nii.gz outputs/bet/sub-063B_T1w_bet.nii.gz --radom_seed 793225',
#  'bet inputs/mri_raw/sub-063B/anat/sub-063B_T1w.nii.gz outputs/bet/sub-063B_T1w_bet.nii.gz --radom_seed 772203',
#  'bet inputs/mri_raw/sub-064A/anat/sub-064A_T1w.nii.gz outputs/bet/sub-064A_T1w_bet.nii.gz --radom_seed 113546',
#  'bet inputs/mri_raw/sub-064A/anat/sub-064A_T1w.nii.gz outputs/bet/sub-064A_T1w_bet.nii.gz --radom_seed 309235',
#  'bet inputs/mri_raw/sub-064B/anat/sub-064B_T1w.nii.gz outputs/bet/sub-064B_T1w_bet.nii.gz --radom_seed 934790',
#  'bet inputs/mri_raw/sub-064B/anat/sub-064B_T1w.nii.gz outputs/bet/sub-064B_T1w_bet.nii.gz --radom_seed 400127',
#  'bet inputs/mri_raw/sub-065A/anat/sub-065A_T1w.nii.gz outputs/bet/sub-065A_T1w_bet.nii.gz --radom_seed 227450',
#  'bet inputs/mri_raw/sub-065A/anat/sub-065A_T1w.nii.gz outputs/bet/sub-065A_T1w_bet.nii.gz --radom_seed 403157',
#  'bet inputs/mri_raw/sub-065B/anat/sub-065B_T1w.nii.gz outputs/bet/sub-065B_T1w_bet.nii.gz --radom_seed 350721',
#  'bet inputs/mri_raw/sub-065B/anat/sub-065B_T1w.nii.gz outputs/bet/sub-065B_T1w_bet.nii.gz --radom_seed 157959',
#  'bet inputs/mri_raw/sub-066A/anat/sub-066A_T1w.nii.gz outputs/bet/sub-066A_T1w_bet.nii.gz --radom_seed 258744',
#  'bet inputs/mri_raw/sub-066A/anat/sub-066A_T1w.nii.gz outputs/bet/sub-066A_T1w_bet.nii.gz --radom_seed 549321',
#  'bet inputs/mri_raw/sub-066B/anat/sub-066B_T1w.nii.gz outputs/bet/sub-066B_T1w_bet.nii.gz --radom_seed 809693',
#  'bet inputs/mri_raw/sub-066B/anat/sub-066B_T1w.nii.gz outputs/bet/sub-066B_T1w_bet.nii.gz --radom_seed 859221',
#  'bet inputs/mri_raw/sub-067A/anat/sub-067A_T1w.nii.gz outputs/bet/sub-067A_T1w_bet.nii.gz --radom_seed 724733',
#  'bet inputs/mri_raw/sub-067A/anat/sub-067A_T1w.nii.gz outputs/bet/sub-067A_T1w_bet.nii.gz --radom_seed 198801',
#  'bet inputs/mri_raw/sub-067B/anat/sub-067B_T1w.nii.gz outputs/bet/sub-067B_T1w_bet.nii.gz --radom_seed 541325',
#  'bet inputs/mri_raw/sub-067B/anat/sub-067B_T1w.nii.gz outputs/bet/sub-067B_T1w_bet.nii.gz --radom_seed 741307',
#  'bet inputs/mri_raw/sub-068A/anat/sub-068A_T1w.nii.gz outputs/bet/sub-068A_T1w_bet.nii.gz --radom_seed 709925',
#  'bet inputs/mri_raw/sub-068A/anat/sub-068A_T1w.nii.gz outputs/bet/sub-068A_T1w_bet.nii.gz --radom_seed 880136',
#  'bet inputs/mri_raw/sub-068B/anat/sub-068B_T1w.nii.gz outputs/bet/sub-068B_T1w_bet.nii.gz --radom_seed 755221',
#  'bet inputs/mri_raw/sub-068B/anat/sub-068B_T1w.nii.gz outputs/bet/sub-068B_T1w_bet.nii.gz --radom_seed 662707',
#  'bet inputs/mri_raw/sub-069A/anat/sub-069A_T1w.nii.gz outputs/bet/sub-069A_T1w_bet.nii.gz --radom_seed 252600',
#  'bet inputs/mri_raw/sub-069A/anat/sub-069A_T1w.nii.gz outputs/bet/sub-069A_T1w_bet.nii.gz --radom_seed 463749',
#  'bet inputs/mri_raw/sub-069B/anat/sub-069B_T1w.nii.gz outputs/bet/sub-069B_T1w_bet.nii.gz --radom_seed 322558',
#  'bet inputs/mri_raw/sub-069B/anat/sub-069B_T1w.nii.gz outputs/bet/sub-069B_T1w_bet.nii.gz --radom_seed 571140',
#  'bet inputs/mri_raw/sub-070A/anat/sub-070A_T1w.nii.gz outputs/bet/sub-070A_T1w_bet.nii.gz --radom_seed 769973',
#  'bet inputs/mri_raw/sub-070A/anat/sub-070A_T1w.nii.gz outputs/bet/sub-070A_T1w_bet.nii.gz --radom_seed 608256',
#  'bet inputs/mri_raw/sub-070B/anat/sub-070B_T1w.nii.gz outputs/bet/sub-070B_T1w_bet.nii.gz --radom_seed 381409',
#  'bet inputs/mri_raw/sub-070B/anat/sub-070B_T1w.nii.gz outputs/bet/sub-070B_T1w_bet.nii.gz --radom_seed 869154',
#  'bet inputs/mri_raw/sub-071A/anat/sub-071A_T1w.nii.gz outputs/bet/sub-071A_T1w_bet.nii.gz --radom_seed 856027',
#  'bet inputs/mri_raw/sub-071A/anat/sub-071A_T1w.nii.gz outputs/bet/sub-071A_T1w_bet.nii.gz --radom_seed 499545',
#  'bet inputs/mri_raw/sub-071B/anat/sub-071B_T1w.nii.gz outputs/bet/sub-071B_T1w_bet.nii.gz --radom_seed 334314',
#  'bet inputs/mri_raw/sub-071B/anat/sub-071B_T1w.nii.gz outputs/bet/sub-071B_T1w_bet.nii.gz --radom_seed 418845',
#  'bet inputs/mri_raw/sub-072A/anat/sub-072A_T1w.nii.gz outputs/bet/sub-072A_T1w_bet.nii.gz --radom_seed 575965',
#  'bet inputs/mri_raw/sub-072A/anat/sub-072A_T1w.nii.gz outputs/bet/sub-072A_T1w_bet.nii.gz --radom_seed 797144',
#  'bet inputs/mri_raw/sub-072B/anat/sub-072B_T1w.nii.gz outputs/bet/sub-072B_T1w_bet.nii.gz --radom_seed 989909',
#  'bet inputs/mri_raw/sub-072B/anat/sub-072B_T1w.nii.gz outputs/bet/sub-072B_T1w_bet.nii.gz --radom_seed 215780',
#  'bet inputs/mri_raw/sub-073A/anat/sub-073A_T1w.nii.gz outputs/bet/sub-073A_T1w_bet.nii.gz --radom_seed 527174',
#  'bet inputs/mri_raw/sub-073A/anat/sub-073A_T1w.nii.gz outputs/bet/sub-073A_T1w_bet.nii.gz --radom_seed 538160',
#  'bet inputs/mri_raw/sub-073B/anat/sub-073B_T1w.nii.gz outputs/bet/sub-073B_T1w_bet.nii.gz --radom_seed 717912',
#  'bet inputs/mri_raw/sub-073B/anat/sub-073B_T1w.nii.gz outputs/bet/sub-073B_T1w_bet.nii.gz --radom_seed 152096',
#  'bet inputs/mri_raw/sub-074A/anat/sub-074A_T1w.nii.gz outputs/bet/sub-074A_T1w_bet.nii.gz --radom_seed 657738',
#  'bet inputs/mri_raw/sub-074A/anat/sub-074A_T1w.nii.gz outputs/bet/sub-074A_T1w_bet.nii.gz --radom_seed 948170',
#  'bet inputs/mri_raw/sub-074B/anat/sub-074B_T1w.nii.gz outputs/bet/sub-074B_T1w_bet.nii.gz --radom_seed 115087',
#  'bet inputs/mri_raw/sub-074B/anat/sub-074B_T1w.nii.gz outputs/bet/sub-074B_T1w_bet.nii.gz --radom_seed 103508',
#  'bet inputs/mri_raw/sub-075A/anat/sub-075A_T1w.nii.gz outputs/bet/sub-075A_T1w_bet.nii.gz --radom_seed 942696',
#  'bet inputs/mri_raw/sub-075A/anat/sub-075A_T1w.nii.gz outputs/bet/sub-075A_T1w_bet.nii.gz --radom_seed 345488',
#  'bet inputs/mri_raw/sub-075B/anat/sub-075B_T1w.nii.gz outputs/bet/sub-075B_T1w_bet.nii.gz --radom_seed 653705',
#  'bet inputs/mri_raw/sub-075B/anat/sub-075B_T1w.nii.gz outputs/bet/sub-075B_T1w_bet.nii.gz --radom_seed 676270',
#  'bet inputs/mri_raw/sub-076A/anat/sub-076A_T1w.nii.gz outputs/bet/sub-076A_T1w_bet.nii.gz --radom_seed 235210',
#  'bet inputs/mri_raw/sub-076A/anat/sub-076A_T1w.nii.gz outputs/bet/sub-076A_T1w_bet.nii.gz --radom_seed 342477',
#  'bet inputs/mri_raw/sub-076B/anat/sub-076B_T1w.nii.gz outputs/bet/sub-076B_T1w_bet.nii.gz --radom_seed 568441',
#  'bet inputs/mri_raw/sub-076B/anat/sub-076B_T1w.nii.gz outputs/bet/sub-076B_T1w_bet.nii.gz --radom_seed 294400',
#  'bet inputs/mri_raw/sub-077A/anat/sub-077A_T1w.nii.gz outputs/bet/sub-077A_T1w_bet.nii.gz --radom_seed 893064',
#  'bet inputs/mri_raw/sub-077A/anat/sub-077A_T1w.nii.gz outputs/bet/sub-077A_T1w_bet.nii.gz --radom_seed 371418',
#  'bet inputs/mri_raw/sub-077B/anat/sub-077B_T1w.nii.gz outputs/bet/sub-077B_T1w_bet.nii.gz --radom_seed 480232',
#  'bet inputs/mri_raw/sub-077B/anat/sub-077B_T1w.nii.gz outputs/bet/sub-077B_T1w_bet.nii.gz --radom_seed 522280',
#  'bet inputs/mri_raw/sub-078A/anat/sub-078A_T1w.nii.gz outputs/bet/sub-078A_T1w_bet.nii.gz --radom_seed 477274',
#  'bet inputs/mri_raw/sub-078A/anat/sub-078A_T1w.nii.gz outputs/bet/sub-078A_T1w_bet.nii.gz --radom_seed 735933',
#  'bet inputs/mri_raw/sub-078B/anat/sub-078B_T1w.nii.gz outputs/bet/sub-078B_T1w_bet.nii.gz --radom_seed 755279',
#  'bet inputs/mri_raw/sub-078B/anat/sub-078B_T1w.nii.gz outputs/bet/sub-078B_T1w_bet.nii.gz --radom_seed 621580',
#  'bet inputs/mri_raw/sub-079A/anat/sub-079A_T1w.nii.gz outputs/bet/sub-079A_T1w_bet.nii.gz --radom_seed 424189',
#  'bet inputs/mri_raw/sub-079A/anat/sub-079A_T1w.nii.gz outputs/bet/sub-079A_T1w_bet.nii.gz --radom_seed 585284',
#  'bet inputs/mri_raw/sub-079B/anat/sub-079B_T1w.nii.gz outputs/bet/sub-079B_T1w_bet.nii.gz --radom_seed 592429',
#  'bet inputs/mri_raw/sub-079B/anat/sub-079B_T1w.nii.gz outputs/bet/sub-079B_T1w_bet.nii.gz --radom_seed 939081',
#  'bet inputs/mri_raw/sub-080A/anat/sub-080A_T1w.nii.gz outputs/bet/sub-080A_T1w_bet.nii.gz --radom_seed 112334',
#  'bet inputs/mri_raw/sub-080A/anat/sub-080A_T1w.nii.gz outputs/bet/sub-080A_T1w_bet.nii.gz --radom_seed 697802',
#  'bet inputs/mri_raw/sub-080B/anat/sub-080B_T1w.nii.gz outputs/bet/sub-080B_T1w_bet.nii.gz --radom_seed 111214',
#  'bet inputs/mri_raw/sub-080B/anat/sub-080B_T1w.nii.gz outputs/bet/sub-080B_T1w_bet.nii.gz --radom_seed 809260',
#  'bet inputs/mri_raw/sub-081A/anat/sub-081A_T1w.nii.gz outputs/bet/sub-081A_T1w_bet.nii.gz --radom_seed 442384',
#  'bet inputs/mri_raw/sub-081A/anat/sub-081A_T1w.nii.gz outputs/bet/sub-081A_T1w_bet.nii.gz --radom_seed 335553',
#  'bet inputs/mri_raw/sub-081B/anat/sub-081B_T1w.nii.gz outputs/bet/sub-081B_T1w_bet.nii.gz --radom_seed 595017',
#  'bet inputs/mri_raw/sub-081B/anat/sub-081B_T1w.nii.gz outputs/bet/sub-081B_T1w_bet.nii.gz --radom_seed 647371',
#  'bet inputs/mri_raw/sub-082A/anat/sub-082A_T1w.nii.gz outputs/bet/sub-082A_T1w_bet.nii.gz --radom_seed 802475',
#  'bet inputs/mri_raw/sub-082A/anat/sub-082A_T1w.nii.gz outputs/bet/sub-082A_T1w_bet.nii.gz --radom_seed 924954',
#  'bet inputs/mri_raw/sub-082B/anat/sub-082B_T1w.nii.gz outputs/bet/sub-082B_T1w_bet.nii.gz --radom_seed 262757',
#  'bet inputs/mri_raw/sub-082B/anat/sub-082B_T1w.nii.gz outputs/bet/sub-082B_T1w_bet.nii.gz --radom_seed 914528',
#  'bet inputs/mri_raw/sub-083A/anat/sub-083A_T1w.nii.gz outputs/bet/sub-083A_T1w_bet.nii.gz --radom_seed 379240',
#  'bet inputs/mri_raw/sub-083A/anat/sub-083A_T1w.nii.gz outputs/bet/sub-083A_T1w_bet.nii.gz --radom_seed 612178',
#  'bet inputs/mri_raw/sub-083B/anat/sub-083B_T1w.nii.gz outputs/bet/sub-083B_T1w_bet.nii.gz --radom_seed 410979',
#  'bet inputs/mri_raw/sub-083B/anat/sub-083B_T1w.nii.gz outputs/bet/sub-083B_T1w_bet.nii.gz --radom_seed 280062',
#  'bet inputs/mri_raw/sub-084A/anat/sub-084A_T1w.nii.gz outputs/bet/sub-084A_T1w_bet.nii.gz --radom_seed 804988',
#  'bet inputs/mri_raw/sub-084A/anat/sub-084A_T1w.nii.gz outputs/bet/sub-084A_T1w_bet.nii.gz --radom_seed 111789',
#  'bet inputs/mri_raw/sub-084B/anat/sub-084B_T1w.nii.gz outputs/bet/sub-084B_T1w_bet.nii.gz --radom_seed 445658',
#  'bet inputs/mri_raw/sub-084B/anat/sub-084B_T1w.nii.gz outputs/bet/sub-084B_T1w_bet.nii.gz --radom_seed 441085',
#  'bet inputs/mri_raw/sub-085A/anat/sub-085A_T1w.nii.gz outputs/bet/sub-085A_T1w_bet.nii.gz --radom_seed 142839',
#  'bet inputs/mri_raw/sub-085A/anat/sub-085A_T1w.nii.gz outputs/bet/sub-085A_T1w_bet.nii.gz --radom_seed 753666',
#  'bet inputs/mri_raw/sub-085B/anat/sub-085B_T1w.nii.gz outputs/bet/sub-085B_T1w_bet.nii.gz --radom_seed 174590',
#  'bet inputs/mri_raw/sub-085B/anat/sub-085B_T1w.nii.gz outputs/bet/sub-085B_T1w_bet.nii.gz --radom_seed 894460',
#  'bet inputs/mri_raw/sub-086A/anat/sub-086A_T1w.nii.gz outputs/bet/sub-086A_T1w_bet.nii.gz --radom_seed 482445',
#  'bet inputs/mri_raw/sub-086A/anat/sub-086A_T1w.nii.gz outputs/bet/sub-086A_T1w_bet.nii.gz --radom_seed 851957',
#  'bet inputs/mri_raw/sub-086B/anat/sub-086B_T1w.nii.gz outputs/bet/sub-086B_T1w_bet.nii.gz --radom_seed 399617',
#  'bet inputs/mri_raw/sub-086B/anat/sub-086B_T1w.nii.gz outputs/bet/sub-086B_T1w_bet.nii.gz --radom_seed 958763',
#  'bet inputs/mri_raw/sub-087A/anat/sub-087A_T1w.nii.gz outputs/bet/sub-087A_T1w_bet.nii.gz --radom_seed 380562',
#  'bet inputs/mri_raw/sub-087A/anat/sub-087A_T1w.nii.gz outputs/bet/sub-087A_T1w_bet.nii.gz --radom_seed 354578',
#  'bet inputs/mri_raw/sub-087B/anat/sub-087B_T1w.nii.gz outputs/bet/sub-087B_T1w_bet.nii.gz --radom_seed 918250',
#  'bet inputs/mri_raw/sub-087B/anat/sub-087B_T1w.nii.gz outputs/bet/sub-087B_T1w_bet.nii.gz --radom_seed 776786',
#  'bet inputs/mri_raw/sub-088A/anat/sub-088A_T1w.nii.gz outputs/bet/sub-088A_T1w_bet.nii.gz --radom_seed 928425',
#  'bet inputs/mri_raw/sub-088A/anat/sub-088A_T1w.nii.gz outputs/bet/sub-088A_T1w_bet.nii.gz --radom_seed 662456',
#  'bet inputs/mri_raw/sub-089A/anat/sub-089A_T1w.nii.gz outputs/bet/sub-089A_T1w_bet.nii.gz --radom_seed 579369',
#  'bet inputs/mri_raw/sub-089A/anat/sub-089A_T1w.nii.gz outputs/bet/sub-089A_T1w_bet.nii.gz --radom_seed 419195',
#  'bet inputs/mri_raw/sub-089B/anat/sub-089B_T1w.nii.gz outputs/bet/sub-089B_T1w_bet.nii.gz --radom_seed 294524',
#  'bet inputs/mri_raw/sub-089B/anat/sub-089B_T1w.nii.gz outputs/bet/sub-089B_T1w_bet.nii.gz --radom_seed 833911',
#  'bet inputs/mri_raw/sub-090A/anat/sub-090A_T1w.nii.gz outputs/bet/sub-090A_T1w_bet.nii.gz --radom_seed 355435',
#  'bet inputs/mri_raw/sub-090A/anat/sub-090A_T1w.nii.gz outputs/bet/sub-090A_T1w_bet.nii.gz --radom_seed 651603',
#  'bet inputs/mri_raw/sub-090B/anat/sub-090B_T1w.nii.gz outputs/bet/sub-090B_T1w_bet.nii.gz --radom_seed 757015',
#  'bet inputs/mri_raw/sub-090B/anat/sub-090B_T1w.nii.gz outputs/bet/sub-090B_T1w_bet.nii.gz --radom_seed 962823',
#  'bet inputs/mri_raw/sub-091A/anat/sub-091A_T1w.nii.gz outputs/bet/sub-091A_T1w_bet.nii.gz --radom_seed 786663',
#  'bet inputs/mri_raw/sub-091A/anat/sub-091A_T1w.nii.gz outputs/bet/sub-091A_T1w_bet.nii.gz --radom_seed 582815',
#  'bet inputs/mri_raw/sub-091B/anat/sub-091B_T1w.nii.gz outputs/bet/sub-091B_T1w_bet.nii.gz --radom_seed 651090',
#  'bet inputs/mri_raw/sub-091B/anat/sub-091B_T1w.nii.gz outputs/bet/sub-091B_T1w_bet.nii.gz --radom_seed 278525',
#  'bet inputs/mri_raw/sub-092A/anat/sub-092A_T1w.nii.gz outputs/bet/sub-092A_T1w_bet.nii.gz --radom_seed 928441',
#  'bet inputs/mri_raw/sub-092A/anat/sub-092A_T1w.nii.gz outputs/bet/sub-092A_T1w_bet.nii.gz --radom_seed 113291',
#  'bet inputs/mri_raw/sub-092B/anat/sub-092B_T1w.nii.gz outputs/bet/sub-092B_T1w_bet.nii.gz --radom_seed 256134',
#  'bet inputs/mri_raw/sub-092B/anat/sub-092B_T1w.nii.gz outputs/bet/sub-092B_T1w_bet.nii.gz --radom_seed 159643',
#  'bet inputs/mri_raw/sub-093A/anat/sub-093A_T1w.nii.gz outputs/bet/sub-093A_T1w_bet.nii.gz --radom_seed 187489',
#  'bet inputs/mri_raw/sub-093A/anat/sub-093A_T1w.nii.gz outputs/bet/sub-093A_T1w_bet.nii.gz --radom_seed 994708',
#  'bet inputs/mri_raw/sub-093B/anat/sub-093B_T1w.nii.gz outputs/bet/sub-093B_T1w_bet.nii.gz --radom_seed 632573',
#  'bet inputs/mri_raw/sub-093B/anat/sub-093B_T1w.nii.gz outputs/bet/sub-093B_T1w_bet.nii.gz --radom_seed 768520',
#  'bet inputs/mri_raw/sub-094A/anat/sub-094A_T1w.nii.gz outputs/bet/sub-094A_T1w_bet.nii.gz --radom_seed 923757',
#  'bet inputs/mri_raw/sub-094A/anat/sub-094A_T1w.nii.gz outputs/bet/sub-094A_T1w_bet.nii.gz --radom_seed 119024',
#  'bet inputs/mri_raw/sub-095A/anat/sub-095A_T1w.nii.gz outputs/bet/sub-095A_T1w_bet.nii.gz --radom_seed 630871',
#  'bet inputs/mri_raw/sub-095A/anat/sub-095A_T1w.nii.gz outputs/bet/sub-095A_T1w_bet.nii.gz --radom_seed 500002',
#  'bet inputs/mri_raw/sub-095B/anat/sub-095B_T1w.nii.gz outputs/bet/sub-095B_T1w_bet.nii.gz --radom_seed 862780',
#  'bet inputs/mri_raw/sub-095B/anat/sub-095B_T1w.nii.gz outputs/bet/sub-095B_T1w_bet.nii.gz --radom_seed 395928',
#  'bet inputs/mri_raw/sub-096A/anat/sub-096A_T1w.nii.gz outputs/bet/sub-096A_T1w_bet.nii.gz --radom_seed 842848',
#  'bet inputs/mri_raw/sub-096A/anat/sub-096A_T1w.nii.gz outputs/bet/sub-096A_T1w_bet.nii.gz --radom_seed 698572',
#  'bet inputs/mri_raw/sub-096B/anat/sub-096B_T1w.nii.gz outputs/bet/sub-096B_T1w_bet.nii.gz --radom_seed 773536',
#  'bet inputs/mri_raw/sub-096B/anat/sub-096B_T1w.nii.gz outputs/bet/sub-096B_T1w_bet.nii.gz --radom_seed 804905',
#  'bet inputs/mri_raw/sub-097A/anat/sub-097A_T1w.nii.gz outputs/bet/sub-097A_T1w_bet.nii.gz --radom_seed 137589',
#  'bet inputs/mri_raw/sub-097A/anat/sub-097A_T1w.nii.gz outputs/bet/sub-097A_T1w_bet.nii.gz --radom_seed 374425',
#  'bet inputs/mri_raw/sub-097B/anat/sub-097B_T1w.nii.gz outputs/bet/sub-097B_T1w_bet.nii.gz --radom_seed 435860',
#  'bet inputs/mri_raw/sub-097B/anat/sub-097B_T1w.nii.gz outputs/bet/sub-097B_T1w_bet.nii.gz --radom_seed 334532',
#  'bet inputs/mri_raw/sub-098A/anat/sub-098A_T1w.nii.gz outputs/bet/sub-098A_T1w_bet.nii.gz --radom_seed 216210',
#  'bet inputs/mri_raw/sub-098A/anat/sub-098A_T1w.nii.gz outputs/bet/sub-098A_T1w_bet.nii.gz --radom_seed 594131',
#  'bet inputs/mri_raw/sub-098B/anat/sub-098B_T1w.nii.gz outputs/bet/sub-098B_T1w_bet.nii.gz --radom_seed 342322',
#  'bet inputs/mri_raw/sub-098B/anat/sub-098B_T1w.nii.gz outputs/bet/sub-098B_T1w_bet.nii.gz --radom_seed 719573',
#  'bet inputs/mri_raw/sub-099A/anat/sub-099A_T1w.nii.gz outputs/bet/sub-099A_T1w_bet.nii.gz --radom_seed 500874',
#  'bet inputs/mri_raw/sub-099A/anat/sub-099A_T1w.nii.gz outputs/bet/sub-099A_T1w_bet.nii.gz --radom_seed 854055',
#  'bet inputs/mri_raw/sub-099B/anat/sub-099B_T1w.nii.gz outputs/bet/sub-099B_T1w_bet.nii.gz --radom_seed 924271',
#  'bet inputs/mri_raw/sub-100A/anat/sub-100A_T1w.nii.gz outputs/bet/sub-100A_T1w_bet.nii.gz --radom_seed 321443',
#  'bet inputs/mri_raw/sub-100A/anat/sub-100A_T1w.nii.gz outputs/bet/sub-100A_T1w_bet.nii.gz --radom_seed 379102',
#  'bet inputs/mri_raw/sub-100B/anat/sub-100B_T1w.nii.gz outputs/bet/sub-100B_T1w_bet.nii.gz --radom_seed 324869',
#  'bet inputs/mri_raw/sub-100B/anat/sub-100B_T1w.nii.gz outputs/bet/sub-100B_T1w_bet.nii.gz --radom_seed 913551',
#  'bet inputs/mri_raw/sub-101A/anat/sub-101A_T1w.nii.gz outputs/bet/sub-101A_T1w_bet.nii.gz --radom_seed 158109',
#  'bet inputs/mri_raw/sub-101A/anat/sub-101A_T1w.nii.gz outputs/bet/sub-101A_T1w_bet.nii.gz --radom_seed 371145',
#  'bet inputs/mri_raw/sub-101B/anat/sub-101B_T1w.nii.gz outputs/bet/sub-101B_T1w_bet.nii.gz --radom_seed 925988',
#  'bet inputs/mri_raw/sub-101B/anat/sub-101B_T1w.nii.gz outputs/bet/sub-101B_T1w_bet.nii.gz --radom_seed 143074',
#  'bet inputs/mri_raw/sub-102A/anat/sub-102A_T1w.nii.gz outputs/bet/sub-102A_T1w_bet.nii.gz --radom_seed 926522',
#  'bet inputs/mri_raw/sub-102A/anat/sub-102A_T1w.nii.gz outputs/bet/sub-102A_T1w_bet.nii.gz --radom_seed 838477',
#  'bet inputs/mri_raw/sub-102B/anat/sub-102B_T1w.nii.gz outputs/bet/sub-102B_T1w_bet.nii.gz --radom_seed 734923',
#  'bet inputs/mri_raw/sub-102B/anat/sub-102B_T1w.nii.gz outputs/bet/sub-102B_T1w_bet.nii.gz --radom_seed 546036',
#  'bet inputs/mri_raw/sub-103A/anat/sub-103A_T1w.nii.gz outputs/bet/sub-103A_T1w_bet.nii.gz --radom_seed 603078',
#  'bet inputs/mri_raw/sub-103A/anat/sub-103A_T1w.nii.gz outputs/bet/sub-103A_T1w_bet.nii.gz --radom_seed 635472',
#  'bet inputs/mri_raw/sub-103B/anat/sub-103B_T1w.nii.gz outputs/bet/sub-103B_T1w_bet.nii.gz --radom_seed 259665',
#  'bet inputs/mri_raw/sub-103B/anat/sub-103B_T1w.nii.gz outputs/bet/sub-103B_T1w_bet.nii.gz --radom_seed 251265',
#  'bet inputs/mri_raw/sub-104A/anat/sub-104A_T1w.nii.gz outputs/bet/sub-104A_T1w_bet.nii.gz --radom_seed 421650',
#  'bet inputs/mri_raw/sub-104A/anat/sub-104A_T1w.nii.gz outputs/bet/sub-104A_T1w_bet.nii.gz --radom_seed 918260',
#  'bet inputs/mri_raw/sub-104B/anat/sub-104B_T1w.nii.gz outputs/bet/sub-104B_T1w_bet.nii.gz --radom_seed 116836',
#  'bet inputs/mri_raw/sub-104B/anat/sub-104B_T1w.nii.gz outputs/bet/sub-104B_T1w_bet.nii.gz --radom_seed 110832',
#  'bet inputs/mri_raw/sub-105A/anat/sub-105A_T1w.nii.gz outputs/bet/sub-105A_T1w_bet.nii.gz --radom_seed 344795',
#  'bet inputs/mri_raw/sub-105A/anat/sub-105A_T1w.nii.gz outputs/bet/sub-105A_T1w_bet.nii.gz --radom_seed 290141',
#  'bet inputs/mri_raw/sub-105B/anat/sub-105B_T1w.nii.gz outputs/bet/sub-105B_T1w_bet.nii.gz --radom_seed 471984',
#  'bet inputs/mri_raw/sub-105B/anat/sub-105B_T1w.nii.gz outputs/bet/sub-105B_T1w_bet.nii.gz --radom_seed 661884',
#  'bet inputs/mri_raw/sub-106A/anat/sub-106A_T1w.nii.gz outputs/bet/sub-106A_T1w_bet.nii.gz --radom_seed 250817',
#  'bet inputs/mri_raw/sub-106A/anat/sub-106A_T1w.nii.gz outputs/bet/sub-106A_T1w_bet.nii.gz --radom_seed 183091',
#  'bet inputs/mri_raw/sub-106B/anat/sub-106B_T1w.nii.gz outputs/bet/sub-106B_T1w_bet.nii.gz --radom_seed 801000',
#  'bet inputs/mri_raw/sub-106B/anat/sub-106B_T1w.nii.gz outputs/bet/sub-106B_T1w_bet.nii.gz --radom_seed 904942',
#  'bet inputs/mri_raw/sub-107A/anat/sub-107A_T1w.nii.gz outputs/bet/sub-107A_T1w_bet.nii.gz --radom_seed 437014',
#  'bet inputs/mri_raw/sub-107A/anat/sub-107A_T1w.nii.gz outputs/bet/sub-107A_T1w_bet.nii.gz --radom_seed 756527',
#  'bet inputs/mri_raw/sub-107B/anat/sub-107B_T1w.nii.gz outputs/bet/sub-107B_T1w_bet.nii.gz --radom_seed 602792',
#  'bet inputs/mri_raw/sub-107B/anat/sub-107B_T1w.nii.gz outputs/bet/sub-107B_T1w_bet.nii.gz --radom_seed 972506',
#  'bet inputs/mri_raw/sub-108A/anat/sub-108A_T1w.nii.gz outputs/bet/sub-108A_T1w_bet.nii.gz --radom_seed 263578',
#  'bet inputs/mri_raw/sub-108A/anat/sub-108A_T1w.nii.gz outputs/bet/sub-108A_T1w_bet.nii.gz --radom_seed 692370',
#  'bet inputs/mri_raw/sub-108B/anat/sub-108B_T1w.nii.gz outputs/bet/sub-108B_T1w_bet.nii.gz --radom_seed 164378',
#  'bet inputs/mri_raw/sub-108B/anat/sub-108B_T1w.nii.gz outputs/bet/sub-108B_T1w_bet.nii.gz --radom_seed 634810',
#  'bet inputs/mri_raw/sub-109A/anat/sub-109A_T1w.nii.gz outputs/bet/sub-109A_T1w_bet.nii.gz --radom_seed 709570',
#  'bet inputs/mri_raw/sub-109A/anat/sub-109A_T1w.nii.gz outputs/bet/sub-109A_T1w_bet.nii.gz --radom_seed 928174',
#  'bet inputs/mri_raw/sub-109B/anat/sub-109B_T1w.nii.gz outputs/bet/sub-109B_T1w_bet.nii.gz --radom_seed 481384',
#  'bet inputs/mri_raw/sub-109B/anat/sub-109B_T1w.nii.gz outputs/bet/sub-109B_T1w_bet.nii.gz --radom_seed 124094',
#  'bet inputs/mri_raw/sub-110A/anat/sub-110A_T1w.nii.gz outputs/bet/sub-110A_T1w_bet.nii.gz --radom_seed 868163',
#  'bet inputs/mri_raw/sub-110A/anat/sub-110A_T1w.nii.gz outputs/bet/sub-110A_T1w_bet.nii.gz --radom_seed 649355',
#  'bet inputs/mri_raw/sub-110B/anat/sub-110B_T1w.nii.gz outputs/bet/sub-110B_T1w_bet.nii.gz --radom_seed 559381',
#  'bet inputs/mri_raw/sub-110B/anat/sub-110B_T1w.nii.gz outputs/bet/sub-110B_T1w_bet.nii.gz --radom_seed 932478',
#  'bet inputs/mri_raw/sub-111A/anat/sub-111A_T1w.nii.gz outputs/bet/sub-111A_T1w_bet.nii.gz --radom_seed 381790',
#  'bet inputs/mri_raw/sub-111A/anat/sub-111A_T1w.nii.gz outputs/bet/sub-111A_T1w_bet.nii.gz --radom_seed 469225',
#  'bet inputs/mri_raw/sub-111B/anat/sub-111B_T1w.nii.gz outputs/bet/sub-111B_T1w_bet.nii.gz --radom_seed 457154',
#  'bet inputs/mri_raw/sub-111B/anat/sub-111B_T1w.nii.gz outputs/bet/sub-111B_T1w_bet.nii.gz --radom_seed 321129',
#  'bet inputs/mri_raw/sub-112A/anat/sub-112A_T1w.nii.gz outputs/bet/sub-112A_T1w_bet.nii.gz --radom_seed 879375',
#  'bet inputs/mri_raw/sub-112A/anat/sub-112A_T1w.nii.gz outputs/bet/sub-112A_T1w_bet.nii.gz --radom_seed 552752',
#  'bet inputs/mri_raw/sub-112B/anat/sub-112B_T1w.nii.gz outputs/bet/sub-112B_T1w_bet.nii.gz --radom_seed 314691',
#  'bet inputs/mri_raw/sub-112B/anat/sub-112B_T1w.nii.gz outputs/bet/sub-112B_T1w_bet.nii.gz --radom_seed 635593',
#  'bet inputs/mri_raw/sub-113A/anat/sub-113A_T1w.nii.gz outputs/bet/sub-113A_T1w_bet.nii.gz --radom_seed 326511',
#  'bet inputs/mri_raw/sub-113A/anat/sub-113A_T1w.nii.gz outputs/bet/sub-113A_T1w_bet.nii.gz --radom_seed 787972',
#  'bet inputs/mri_raw/sub-114A/anat/sub-114A_T1w.nii.gz outputs/bet/sub-114A_T1w_bet.nii.gz --radom_seed 657652',
#  'bet inputs/mri_raw/sub-114A/anat/sub-114A_T1w.nii.gz outputs/bet/sub-114A_T1w_bet.nii.gz --radom_seed 684842',
#  'bet inputs/mri_raw/sub-114B/anat/sub-114B_T1w.nii.gz outputs/bet/sub-114B_T1w_bet.nii.gz --radom_seed 337268',
# ...
#  'bet inputs/mri_raw/sub-191A/anat/sub-191A_T1w.nii.gz outputs/bet/sub-191A_T1w_bet.nii.gz --radom_seed 485602',
#  'bet inputs/mri_raw/sub-191B/anat/sub-191B_T1w.nii.gz outputs/bet/sub-191B_T1w_bet.nii.gz --radom_seed 540730',
#  'bet inputs/mri_raw/sub-191B/anat/sub-191B_T1w.nii.gz outputs/bet/sub-191B_T1w_bet.nii.gz --radom_seed 721030',
#  'bet inputs/mri_raw/sub-192A/anat/sub-192A_T1w.nii.gz outputs/bet/sub-192A_T1w_bet.nii.gz --radom_seed 606337',
#  'bet inputs/mri_raw/sub-192A/anat/sub-192A_T1w.nii.gz outputs/bet/sub-192A_T1w_bet.nii.gz --radom_seed 845094',
#  'bet inputs/mri_raw/sub-192B/anat/sub-192B_T1w.nii.gz outputs/bet/sub-192B_T1w_bet.nii.gz --radom_seed 544247',
#  'bet inputs/mri_raw/sub-193A/anat/sub-193A_T1w.nii.gz outputs/bet/sub-193A_T1w_bet.nii.gz --radom_seed 950990',
#  'bet inputs/mri_raw/sub-193A/anat/sub-193A_T1w.nii.gz outputs/bet/sub-193A_T1w_bet.nii.gz --radom_seed 818173',
#  'bet inputs/mri_raw/sub-193B/anat/sub-193B_T1w.nii.gz outputs/bet/sub-193B_T1w_bet.nii.gz --radom_seed 350715',
#  'bet inputs/mri_raw/sub-193B/anat/sub-193B_T1w.nii.gz outputs/bet/sub-193B_T1w_bet.nii.gz --radom_seed 402192',
#  'bet inputs/mri_raw/sub-194A/anat/sub-194A_T1w.nii.gz outputs/bet/sub-194A_T1w_bet.nii.gz --radom_seed 414159',
#  'bet inputs/mri_raw/sub-194A/anat/sub-194A_T1w.nii.gz outputs/bet/sub-194A_T1w_bet.nii.gz --radom_seed 506947',
#  'bet inputs/mri_raw/sub-194B/anat/sub-194B_T1w.nii.gz outputs/bet/sub-194B_T1w_bet.nii.gz --radom_seed 659349',
#  'bet inputs/mri_raw/sub-194B/anat/sub-194B_T1w.nii.gz outputs/bet/sub-194B_T1w_bet.nii.gz --radom_seed 141662',
#  'bet inputs/mri_raw/sub-195A/anat/sub-195A_T1w.nii.gz outputs/bet/sub-195A_T1w_bet.nii.gz --radom_seed 745378',
#  'bet inputs/mri_raw/sub-195A/anat/sub-195A_T1w.nii.gz outputs/bet/sub-195A_T1w_bet.nii.gz --radom_seed 735361',
#  'bet inputs/mri_raw/sub-195B/anat/sub-195B_T1w.nii.gz outputs/bet/sub-195B_T1w_bet.nii.gz --radom_seed 389272',
#  'bet inputs/mri_raw/sub-195B/anat/sub-195B_T1w.nii.gz outputs/bet/sub-195B_T1w_bet.nii.gz --radom_seed 548032',
#  'bet inputs/mri_raw/sub-196A/anat/sub-196A_T1w.nii.gz outputs/bet/sub-196A_T1w_bet.nii.gz --radom_seed 285956',
#  'bet inputs/mri_raw/sub-196B/anat/sub-196B_T1w.nii.gz outputs/bet/sub-196B_T1w_bet.nii.gz --radom_seed 351930',
#  'bet inputs/mri_raw/sub-196B/anat/sub-196B_T1w.nii.gz outputs/bet/sub-196B_T1w_bet.nii.gz --radom_seed 646900',
#  'bet inputs/mri_raw/sub-197A/anat/sub-197A_T1w.nii.gz outputs/bet/sub-197A_T1w_bet.nii.gz --radom_seed 674423',
#  'bet inputs/mri_raw/sub-197A/anat/sub-197A_T1w.nii.gz outputs/bet/sub-197A_T1w_bet.nii.gz --radom_seed 779069',
#  'bet inputs/mri_raw/sub-197B/anat/sub-197B_T1w.nii.gz outputs/bet/sub-197B_T1w_bet.nii.gz --radom_seed 714859',
#  'bet inputs/mri_raw/sub-197B/anat/sub-197B_T1w.nii.gz outputs/bet/sub-197B_T1w_bet.nii.gz --radom_seed 852708',
#  'bet inputs/mri_raw/sub-198A/anat/sub-198A_T1w.nii.gz outputs/bet/sub-198A_T1w_bet.nii.gz --radom_seed 471223',
#  'bet inputs/mri_raw/sub-198A/anat/sub-198A_T1w.nii.gz outputs/bet/sub-198A_T1w_bet.nii.gz --radom_seed 386012',
#  'bet inputs/mri_raw/sub-198B/anat/sub-198B_T1w.nii.gz outputs/bet/sub-198B_T1w_bet.nii.gz --radom_seed 727616',
#  'bet inputs/mri_raw/sub-198B/anat/sub-198B_T1w.nii.gz outputs/bet/sub-198B_T1w_bet.nii.gz --radom_seed 197843',
#  'bet inputs/mri_raw/sub-199A/anat/sub-199A_T1w.nii.gz outputs/bet/sub-199A_T1w_bet.nii.gz --radom_seed 334094',
#  'bet inputs/mri_raw/sub-199A/anat/sub-199A_T1w.nii.gz outputs/bet/sub-199A_T1w_bet.nii.gz --radom_seed 989820',
#  'bet inputs/mri_raw/sub-199B/anat/sub-199B_T1w.nii.gz outputs/bet/sub-199B_T1w_bet.nii.gz --radom_seed 973748',
#  'bet inputs/mri_raw/sub-199B/anat/sub-199B_T1w.nii.gz outputs/bet/sub-199B_T1w_bet.nii.gz --radom_seed 573542',
#  'bet inputs/mri_raw/sub-200A/anat/sub-200A_T1w.nii.gz outputs/bet/sub-200A_T1w_bet.nii.gz --radom_seed 492289',
#  'bet inputs/mri_raw/sub-200A/anat/sub-200A_T1w.nii.gz outputs/bet/sub-200A_T1w_bet.nii.gz --radom_seed 743198',
#  'bet inputs/mri_raw/sub-200B/anat/sub-200B_T1w.nii.gz outputs/bet/sub-200B_T1w_bet.nii.gz --radom_seed 158295',
#  'bet inputs/mri_raw/sub-200B/anat/sub-200B_T1w.nii.gz outputs/bet/sub-200B_T1w_bet.nii.gz --radom_seed 977387',
#  'bet inputs/mri_raw/sub-201A/anat/sub-201A_T1w.nii.gz outputs/bet/sub-201A_T1w_bet.nii.gz --radom_seed 728669',
#  'bet inputs/mri_raw/sub-201A/anat/sub-201A_T1w.nii.gz outputs/bet/sub-201A_T1w_bet.nii.gz --radom_seed 608166',
#  'bet inputs/mri_raw/sub-201B/anat/sub-201B_T1w.nii.gz outputs/bet/sub-201B_T1w_bet.nii.gz --radom_seed 341457',
#  'bet inputs/mri_raw/sub-201B/anat/sub-201B_T1w.nii.gz outputs/bet/sub-201B_T1w_bet.nii.gz --radom_seed 952794',
#  'bet inputs/mri_raw/sub-202A/anat/sub-202A_T1w.nii.gz outputs/bet/sub-202A_T1w_bet.nii.gz --radom_seed 560166',
#  'bet inputs/mri_raw/sub-202A/anat/sub-202A_T1w.nii.gz outputs/bet/sub-202A_T1w_bet.nii.gz --radom_seed 982593',
#  'bet inputs/mri_raw/sub-202B/anat/sub-202B_T1w.nii.gz outputs/bet/sub-202B_T1w_bet.nii.gz --radom_seed 853425',
#  'bet inputs/mri_raw/sub-202B/anat/sub-202B_T1w.nii.gz outputs/bet/sub-202B_T1w_bet.nii.gz --radom_seed 991726',
#  'bet inputs/mri_raw/sub-203A/anat/sub-203A_T1w.nii.gz outputs/bet/sub-203A_T1w_bet.nii.gz --radom_seed 375913',
#  'bet inputs/mri_raw/sub-203A/anat/sub-203A_T1w.nii.gz outputs/bet/sub-203A_T1w_bet.nii.gz --radom_seed 270845',
#  'bet inputs/mri_raw/sub-203B/anat/sub-203B_T1w.nii.gz outputs/bet/sub-203B_T1w_bet.nii.gz --radom_seed 439366',
#  'bet inputs/mri_raw/sub-203B/anat/sub-203B_T1w.nii.gz outputs/bet/sub-203B_T1w_bet.nii.gz --radom_seed 548303',
#  'bet inputs/mri_raw/sub-204A/anat/sub-204A_T1w.nii.gz outputs/bet/sub-204A_T1w_bet.nii.gz --radom_seed 225530',
#  'bet inputs/mri_raw/sub-204A/anat/sub-204A_T1w.nii.gz outputs/bet/sub-204A_T1w_bet.nii.gz --radom_seed 718064',
#  'bet inputs/mri_raw/sub-204B/anat/sub-204B_T1w.nii.gz outputs/bet/sub-204B_T1w_bet.nii.gz --radom_seed 863648',
#  'bet inputs/mri_raw/sub-204B/anat/sub-204B_T1w.nii.gz outputs/bet/sub-204B_T1w_bet.nii.gz --radom_seed 934365',
#  'bet inputs/mri_raw/sub-205A/anat/sub-205A_T1w.nii.gz outputs/bet/sub-205A_T1w_bet.nii.gz --radom_seed 904814',
#  'bet inputs/mri_raw/sub-205A/anat/sub-205A_T1w.nii.gz outputs/bet/sub-205A_T1w_bet.nii.gz --radom_seed 204834',
#  'bet inputs/mri_raw/sub-205B/anat/sub-205B_T1w.nii.gz outputs/bet/sub-205B_T1w_bet.nii.gz --radom_seed 408749',
#  'bet inputs/mri_raw/sub-205B/anat/sub-205B_T1w.nii.gz outputs/bet/sub-205B_T1w_bet.nii.gz --radom_seed 648434',
#  'bet inputs/mri_raw/sub-206A/anat/sub-206A_T1w.nii.gz outputs/bet/sub-206A_T1w_bet.nii.gz --radom_seed 392353',
#  'bet inputs/mri_raw/sub-206A/anat/sub-206A_T1w.nii.gz outputs/bet/sub-206A_T1w_bet.nii.gz --radom_seed 282662',
#  'bet inputs/mri_raw/sub-206B/anat/sub-206B_T1w.nii.gz outputs/bet/sub-206B_T1w_bet.nii.gz --radom_seed 749731',
#  'bet inputs/mri_raw/sub-206B/anat/sub-206B_T1w.nii.gz outputs/bet/sub-206B_T1w_bet.nii.gz --radom_seed 661117',
#  'bet inputs/mri_raw/sub-207A/anat/sub-207A_T1w.nii.gz outputs/bet/sub-207A_T1w_bet.nii.gz --radom_seed 135709',
#  'bet inputs/mri_raw/sub-207A/anat/sub-207A_T1w.nii.gz outputs/bet/sub-207A_T1w_bet.nii.gz --radom_seed 204352',
#  'bet inputs/mri_raw/sub-208A/anat/sub-208A_T1w.nii.gz outputs/bet/sub-208A_T1w_bet.nii.gz --radom_seed 261830',
#  'bet inputs/mri_raw/sub-208A/anat/sub-208A_T1w.nii.gz outputs/bet/sub-208A_T1w_bet.nii.gz --radom_seed 800486',
#  'bet inputs/mri_raw/sub-208B/anat/sub-208B_T1w.nii.gz outputs/bet/sub-208B_T1w_bet.nii.gz --radom_seed 956944',
#  'bet inputs/mri_raw/sub-208B/anat/sub-208B_T1w.nii.gz outputs/bet/sub-208B_T1w_bet.nii.gz --radom_seed 412951',
#  'bet inputs/mri_raw/sub-209A/anat/sub-209A_T1w.nii.gz outputs/bet/sub-209A_T1w_bet.nii.gz --radom_seed 181396',
#  'bet inputs/mri_raw/sub-209A/anat/sub-209A_T1w.nii.gz outputs/bet/sub-209A_T1w_bet.nii.gz --radom_seed 729079',
#  'bet inputs/mri_raw/sub-209B/anat/sub-209B_T1w.nii.gz outputs/bet/sub-209B_T1w_bet.nii.gz --radom_seed 281786',
#  'bet inputs/mri_raw/sub-209B/anat/sub-209B_T1w.nii.gz outputs/bet/sub-209B_T1w_bet.nii.gz --radom_seed 294724',
#  'bet inputs/mri_raw/sub-210A/anat/sub-210A_T1w.nii.gz outputs/bet/sub-210A_T1w_bet.nii.gz --radom_seed 240197',
#  'bet inputs/mri_raw/sub-210A/anat/sub-210A_T1w.nii.gz outputs/bet/sub-210A_T1w_bet.nii.gz --radom_seed 676456',
#  'bet inputs/mri_raw/sub-210B/anat/sub-210B_T1w.nii.gz outputs/bet/sub-210B_T1w_bet.nii.gz --radom_seed 839425',
#  'bet inputs/mri_raw/sub-210B/anat/sub-210B_T1w.nii.gz outputs/bet/sub-210B_T1w_bet.nii.gz --radom_seed 925856',
#  'bet inputs/mri_raw/sub-211A/anat/sub-211A_T1w.nii.gz outputs/bet/sub-211A_T1w_bet.nii.gz --radom_seed 573457',
#  'bet inputs/mri_raw/sub-211A/anat/sub-211A_T1w.nii.gz outputs/bet/sub-211A_T1w_bet.nii.gz --radom_seed 418414',
#  'bet inputs/mri_raw/sub-211B/anat/sub-211B_T1w.nii.gz outputs/bet/sub-211B_T1w_bet.nii.gz --radom_seed 234857',
#  'bet inputs/mri_raw/sub-211B/anat/sub-211B_T1w.nii.gz outputs/bet/sub-211B_T1w_bet.nii.gz --radom_seed 934644',
#  'bet inputs/mri_raw/sub-212A/anat/sub-212A_T1w.nii.gz outputs/bet/sub-212A_T1w_bet.nii.gz --radom_seed 458062',
#  'bet inputs/mri_raw/sub-212A/anat/sub-212A_T1w.nii.gz outputs/bet/sub-212A_T1w_bet.nii.gz --radom_seed 939083',
#  'bet inputs/mri_raw/sub-212B/anat/sub-212B_T1w.nii.gz outputs/bet/sub-212B_T1w_bet.nii.gz --radom_seed 402311',
#  'bet inputs/mri_raw/sub-212B/anat/sub-212B_T1w.nii.gz outputs/bet/sub-212B_T1w_bet.nii.gz --radom_seed 392252',
#  'bet inputs/mri_raw/sub-213A/anat/sub-213A_T1w.nii.gz outputs/bet/sub-213A_T1w_bet.nii.gz --radom_seed 773467',
#  'bet inputs/mri_raw/sub-213A/anat/sub-213A_T1w.nii.gz outputs/bet/sub-213A_T1w_bet.nii.gz --radom_seed 502926',
#  'bet inputs/mri_raw/sub-213B/anat/sub-213B_T1w.nii.gz outputs/bet/sub-213B_T1w_bet.nii.gz --radom_seed 610764',
#  'bet inputs/mri_raw/sub-213B/anat/sub-213B_T1w.nii.gz outputs/bet/sub-213B_T1w_bet.nii.gz --radom_seed 933844',
#  'bet inputs/mri_raw/sub-214A/anat/sub-214A_T1w.nii.gz outputs/bet/sub-214A_T1w_bet.nii.gz --radom_seed 617154',
#  'bet inputs/mri_raw/sub-214A/anat/sub-214A_T1w.nii.gz outputs/bet/sub-214A_T1w_bet.nii.gz --radom_seed 643171',
#  'bet inputs/mri_raw/sub-215A/anat/sub-215A_T1w.nii.gz outputs/bet/sub-215A_T1w_bet.nii.gz --radom_seed 960170',
#  'bet inputs/mri_raw/sub-215A/anat/sub-215A_T1w.nii.gz outputs/bet/sub-215A_T1w_bet.nii.gz --radom_seed 717619',
#  'bet inputs/mri_raw/sub-216A/anat/sub-216A_T1w.nii.gz outputs/bet/sub-216A_T1w_bet.nii.gz --radom_seed 458624',
#  'bet inputs/mri_raw/sub-216A/anat/sub-216A_T1w.nii.gz outputs/bet/sub-216A_T1w_bet.nii.gz --radom_seed 216434',
#  'bet inputs/mri_raw/sub-216B/anat/sub-216B_T1w.nii.gz outputs/bet/sub-216B_T1w_bet.nii.gz --radom_seed 667714',
#  'bet inputs/mri_raw/sub-216B/anat/sub-216B_T1w.nii.gz outputs/bet/sub-216B_T1w_bet.nii.gz --radom_seed 199086',
#  'bet inputs/mri_raw/sub-217A/anat/sub-217A_T1w.nii.gz outputs/bet/sub-217A_T1w_bet.nii.gz --radom_seed 380618',
#  'bet inputs/mri_raw/sub-217A/anat/sub-217A_T1w.nii.gz outputs/bet/sub-217A_T1w_bet.nii.gz --radom_seed 479424',
#  'bet inputs/mri_raw/sub-217B/anat/sub-217B_T1w.nii.gz outputs/bet/sub-217B_T1w_bet.nii.gz --radom_seed 326387',
#  'bet inputs/mri_raw/sub-217B/anat/sub-217B_T1w.nii.gz outputs/bet/sub-217B_T1w_bet.nii.gz --radom_seed 337515',
#  'bet inputs/mri_raw/sub-218A/anat/sub-218A_T1w.nii.gz outputs/bet/sub-218A_T1w_bet.nii.gz --radom_seed 805596',
#  'bet inputs/mri_raw/sub-218A/anat/sub-218A_T1w.nii.gz outputs/bet/sub-218A_T1w_bet.nii.gz --radom_seed 201073',
#  'bet inputs/mri_raw/sub-218B/anat/sub-218B_T1w.nii.gz outputs/bet/sub-218B_T1w_bet.nii.gz --radom_seed 333140',
#  'bet inputs/mri_raw/sub-218B/anat/sub-218B_T1w.nii.gz outputs/bet/sub-218B_T1w_bet.nii.gz --radom_seed 731187',
#  'bet inputs/mri_raw/sub-219A/anat/sub-219A_T1w.nii.gz outputs/bet/sub-219A_T1w_bet.nii.gz --radom_seed 741729',
#  'bet inputs/mri_raw/sub-219A/anat/sub-219A_T1w.nii.gz outputs/bet/sub-219A_T1w_bet.nii.gz --radom_seed 678752',
#  'bet inputs/mri_raw/sub-220A/anat/sub-220A_T1w.nii.gz outputs/bet/sub-220A_T1w_bet.nii.gz --radom_seed 954430',
#  'bet inputs/mri_raw/sub-220A/anat/sub-220A_T1w.nii.gz outputs/bet/sub-220A_T1w_bet.nii.gz --radom_seed 405637',
#  'bet inputs/mri_raw/sub-220B/anat/sub-220B_T1w.nii.gz outputs/bet/sub-220B_T1w_bet.nii.gz --radom_seed 794654',
#  'bet inputs/mri_raw/sub-220B/anat/sub-220B_T1w.nii.gz outputs/bet/sub-220B_T1w_bet.nii.gz --radom_seed 864155',
#  'bet inputs/mri_raw/sub-221A/anat/sub-221A_T1w.nii.gz outputs/bet/sub-221A_T1w_bet.nii.gz --radom_seed 899213',
#  'bet inputs/mri_raw/sub-221A/anat/sub-221A_T1w.nii.gz outputs/bet/sub-221A_T1w_bet.nii.gz --radom_seed 489301',
#  'bet inputs/mri_raw/sub-221B/anat/sub-221B_T1w.nii.gz outputs/bet/sub-221B_T1w_bet.nii.gz --radom_seed 211359',
#  'bet inputs/mri_raw/sub-221B/anat/sub-221B_T1w.nii.gz outputs/bet/sub-221B_T1w_bet.nii.gz --radom_seed 799761',
#  'bet inputs/mri_raw/sub-222A/anat/sub-222A_T1w.nii.gz outputs/bet/sub-222A_T1w_bet.nii.gz --radom_seed 709226',
#  'bet inputs/mri_raw/sub-222A/anat/sub-222A_T1w.nii.gz outputs/bet/sub-222A_T1w_bet.nii.gz --radom_seed 637107',
#  'bet inputs/mri_raw/sub-222B/anat/sub-222B_T1w.nii.gz outputs/bet/sub-222B_T1w_bet.nii.gz --radom_seed 127493',
#  'bet inputs/mri_raw/sub-222B/anat/sub-222B_T1w.nii.gz outputs/bet/sub-222B_T1w_bet.nii.gz --radom_seed 351931',
#  'bet inputs/mri_raw/sub-223A/anat/sub-223A_T1w.nii.gz outputs/bet/sub-223A_T1w_bet.nii.gz --radom_seed 928975',
#  'bet inputs/mri_raw/sub-223A/anat/sub-223A_T1w.nii.gz outputs/bet/sub-223A_T1w_bet.nii.gz --radom_seed 806986',
#  'bet inputs/mri_raw/sub-223B/anat/sub-223B_T1w.nii.gz outputs/bet/sub-223B_T1w_bet.nii.gz --radom_seed 943419',
#  'bet inputs/mri_raw/sub-223B/anat/sub-223B_T1w.nii.gz outputs/bet/sub-223B_T1w_bet.nii.gz --radom_seed 441684',
#  'bet inputs/mri_raw/sub-224A/anat/sub-224A_T1w.nii.gz outputs/bet/sub-224A_T1w_bet.nii.gz --radom_seed 216770',
#  'bet inputs/mri_raw/sub-224A/anat/sub-224A_T1w.nii.gz outputs/bet/sub-224A_T1w_bet.nii.gz --radom_seed 958076',
#  'bet inputs/mri_raw/sub-224B/anat/sub-224B_T1w.nii.gz outputs/bet/sub-224B_T1w_bet.nii.gz --radom_seed 964134',
#  'bet inputs/mri_raw/sub-224B/anat/sub-224B_T1w.nii.gz outputs/bet/sub-224B_T1w_bet.nii.gz --radom_seed 284455',
#  'bet inputs/mri_raw/sub-225A/anat/sub-225A_T1w.nii.gz outputs/bet/sub-225A_T1w_bet.nii.gz --radom_seed 949812',
#  'bet inputs/mri_raw/sub-225A/anat/sub-225A_T1w.nii.gz outputs/bet/sub-225A_T1w_bet.nii.gz --radom_seed 837430',
#  'bet inputs/mri_raw/sub-225B/anat/sub-225B_T1w.nii.gz outputs/bet/sub-225B_T1w_bet.nii.gz --radom_seed 584861',
#  'bet inputs/mri_raw/sub-225B/anat/sub-225B_T1w.nii.gz outputs/bet/sub-225B_T1w_bet.nii.gz --radom_seed 474036',
#  'bet inputs/mri_raw/sub-226A/anat/sub-226A_T1w.nii.gz outputs/bet/sub-226A_T1w_bet.nii.gz --radom_seed 856250',
#  'bet inputs/mri_raw/sub-226A/anat/sub-226A_T1w.nii.gz outputs/bet/sub-226A_T1w_bet.nii.gz --radom_seed 520786',
#  'bet inputs/mri_raw/sub-226B/anat/sub-226B_T1w.nii.gz outputs/bet/sub-226B_T1w_bet.nii.gz --radom_seed 317928',
#  'bet inputs/mri_raw/sub-226B/anat/sub-226B_T1w.nii.gz outputs/bet/sub-226B_T1w_bet.nii.gz --radom_seed 536630',
#  'bet inputs/mri_raw/sub-227A/anat/sub-227A_T1w.nii.gz outputs/bet/sub-227A_T1w_bet.nii.gz --radom_seed 888939',
#  'bet inputs/mri_raw/sub-227A/anat/sub-227A_T1w.nii.gz outputs/bet/sub-227A_T1w_bet.nii.gz --radom_seed 317732',
#  'bet inputs/mri_raw/sub-227B/anat/sub-227B_T1w.nii.gz outputs/bet/sub-227B_T1w_bet.nii.gz --radom_seed 921458',
#  'bet inputs/mri_raw/sub-227B/anat/sub-227B_T1w.nii.gz outputs/bet/sub-227B_T1w_bet.nii.gz --radom_seed 104121',
#  'bet inputs/mri_raw/sub-228A/anat/sub-228A_T1w.nii.gz outputs/bet/sub-228A_T1w_bet.nii.gz --radom_seed 153000',
#  'bet inputs/mri_raw/sub-228A/anat/sub-228A_T1w.nii.gz outputs/bet/sub-228A_T1w_bet.nii.gz --radom_seed 971796',
#  'bet inputs/mri_raw/sub-228B/anat/sub-228B_T1w.nii.gz outputs/bet/sub-228B_T1w_bet.nii.gz --radom_seed 428453',
#  'bet inputs/mri_raw/sub-228B/anat/sub-228B_T1w.nii.gz outputs/bet/sub-228B_T1w_bet.nii.gz --radom_seed 876223']

# %%
variable_dict['t2w']
# Out:
# ['inputs/mri-raw/sub-001A/anat/sub-001A_sub-001A.nii.gz',
#  'inputs/mri-raw/sub-001A/anat/sub-001A_sub-001A.nii.gz',
#  'inputs/mri-raw/sub-001B/anat/sub-001B_sub-001B.nii.gz',
#  'inputs/mri-raw/sub-001B/anat/sub-001B_sub-001B.nii.gz',
#  'inputs/mri-raw/sub-002A/anat/sub-002A_sub-002A.nii.gz',
#  'inputs/mri-raw/sub-002A/anat/sub-002A_sub-002A.nii.gz',
#  'inputs/mri-raw/sub-002B/anat/sub-002B_sub-002B.nii.gz',
#  'inputs/mri-raw/sub-002B/anat/sub-002B_sub-002B.nii.gz',
#  'inputs/mri-raw/sub-003A/anat/sub-003A_sub-003A.nii.gz',
#  'inputs/mri-raw/sub-003A/anat/sub-003A_sub-003A.nii.gz',
#  'inputs/mri-raw/sub-003B/anat/sub-003B_sub-003B.nii.gz',
#  'inputs/mri-raw/sub-003B/anat/sub-003B_sub-003B.nii.gz',
#  'inputs/mri-raw/sub-004A/anat/sub-004A_sub-004A.nii.gz',
#  'inputs/mri-raw/sub-004A/anat/sub-004A_sub-004A.nii.gz',
#  'inputs/mri-raw/sub-004B/anat/sub-004B_sub-004B.nii.gz',
#  'inputs/mri-raw/sub-004B/anat/sub-004B_sub-004B.nii.gz',
#  'inputs/mri-raw/sub-005A/anat/sub-005A_sub-005A.nii.gz',
#  'inputs/mri-raw/sub-005A/anat/sub-005A_sub-005A.nii.gz',
#  'inputs/mri-raw/sub-005B/anat/sub-005B_sub-005B.nii.gz',
#  'inputs/mri-raw/sub-005B/anat/sub-005B_sub-005B.nii.gz',
#  'inputs/mri-raw/sub-006A/anat/sub-006A_sub-006A.nii.gz',
#  'inputs/mri-raw/sub-006A/anat/sub-006A_sub-006A.nii.gz',
#  'inputs/mri-raw/sub-006B/anat/sub-006B_sub-006B.nii.gz',
#  'inputs/mri-raw/sub-006B/anat/sub-006B_sub-006B.nii.gz',
#  'inputs/mri-raw/sub-007A/anat/sub-007A_sub-007A.nii.gz',
#  'inputs/mri-raw/sub-007A/anat/sub-007A_sub-007A.nii.gz',
#  'inputs/mri-raw/sub-007B/anat/sub-007B_sub-007B.nii.gz',
#  'inputs/mri-raw/sub-007B/anat/sub-007B_sub-007B.nii.gz',
#  'inputs/mri-raw/sub-008A/anat/sub-008A_sub-008A.nii.gz',
#  'inputs/mri-raw/sub-008A/anat/sub-008A_sub-008A.nii.gz',
#  'inputs/mri-raw/sub-008B/anat/sub-008B_sub-008B.nii.gz',
#  'inputs/mri-raw/sub-008B/anat/sub-008B_sub-008B.nii.gz',
#  'inputs/mri-raw/sub-009A/anat/sub-009A_sub-009A.nii.gz',
#  'inputs/mri-raw/sub-009A/anat/sub-009A_sub-009A.nii.gz',
#  'inputs/mri-raw/sub-009B/anat/sub-009B_sub-009B.nii.gz',
#  'inputs/mri-raw/sub-009B/anat/sub-009B_sub-009B.nii.gz',
#  'inputs/mri-raw/sub-010A/anat/sub-010A_sub-010A.nii.gz',
#  'inputs/mri-raw/sub-010A/anat/sub-010A_sub-010A.nii.gz',
#  'inputs/mri-raw/sub-010B/anat/sub-010B_sub-010B.nii.gz',
#  'inputs/mri-raw/sub-010B/anat/sub-010B_sub-010B.nii.gz',
#  'inputs/mri-raw/sub-010C/anat/sub-010C_sub-010C.nii.gz',
#  'inputs/mri-raw/sub-010C/anat/sub-010C_sub-010C.nii.gz',
#  'inputs/mri-raw/sub-011A/anat/sub-011A_sub-011A.nii.gz',
#  'inputs/mri-raw/sub-011A/anat/sub-011A_sub-011A.nii.gz',
#  'inputs/mri-raw/sub-011B/anat/sub-011B_sub-011B.nii.gz',
#  'inputs/mri-raw/sub-011B/anat/sub-011B_sub-011B.nii.gz',
#  'inputs/mri-raw/sub-012A/anat/sub-012A_sub-012A.nii.gz',
#  'inputs/mri-raw/sub-012A/anat/sub-012A_sub-012A.nii.gz',
#  'inputs/mri-raw/sub-012B/anat/sub-012B_sub-012B.nii.gz',
#  'inputs/mri-raw/sub-012B/anat/sub-012B_sub-012B.nii.gz',
#  'inputs/mri-raw/sub-013A/anat/sub-013A_sub-013A.nii.gz',
#  'inputs/mri-raw/sub-013A/anat/sub-013A_sub-013A.nii.gz',
#  'inputs/mri-raw/sub-013B/anat/sub-013B_sub-013B.nii.gz',
#  'inputs/mri-raw/sub-013B/anat/sub-013B_sub-013B.nii.gz',
#  'inputs/mri-raw/sub-014A/anat/sub-014A_sub-014A.nii.gz',
#  'inputs/mri-raw/sub-014A/anat/sub-014A_sub-014A.nii.gz',
#  'inputs/mri-raw/sub-014B/anat/sub-014B_sub-014B.nii.gz',
#  'inputs/mri-raw/sub-014B/anat/sub-014B_sub-014B.nii.gz',
#  'inputs/mri-raw/sub-015A/anat/sub-015A_sub-015A.nii.gz',
#  'inputs/mri-raw/sub-015A/anat/sub-015A_sub-015A.nii.gz',
#  'inputs/mri-raw/sub-015B/anat/sub-015B_sub-015B.nii.gz',
#  'inputs/mri-raw/sub-015B/anat/sub-015B_sub-015B.nii.gz',
#  'inputs/mri-raw/sub-016A/anat/sub-016A_sub-016A.nii.gz',
#  'inputs/mri-raw/sub-016A/anat/sub-016A_sub-016A.nii.gz',
#  'inputs/mri-raw/sub-016B/anat/sub-016B_sub-016B.nii.gz',
#  'inputs/mri-raw/sub-016B/anat/sub-016B_sub-016B.nii.gz',
#  'inputs/mri-raw/sub-017A/anat/sub-017A_sub-017A.nii.gz',
#  'inputs/mri-raw/sub-017A/anat/sub-017A_sub-017A.nii.gz',
#  'inputs/mri-raw/sub-017B/anat/sub-017B_sub-017B.nii.gz',
#  'inputs/mri-raw/sub-017B/anat/sub-017B_sub-017B.nii.gz',
#  'inputs/mri-raw/sub-018A/anat/sub-018A_sub-018A.nii.gz',
#  'inputs/mri-raw/sub-018A/anat/sub-018A_sub-018A.nii.gz',
#  'inputs/mri-raw/sub-018B/anat/sub-018B_sub-018B.nii.gz',
#  'inputs/mri-raw/sub-018B/anat/sub-018B_sub-018B.nii.gz',
#  'inputs/mri-raw/sub-019A/anat/sub-019A_sub-019A.nii.gz',
#  'inputs/mri-raw/sub-019A/anat/sub-019A_sub-019A.nii.gz',
#  'inputs/mri-raw/sub-019B/anat/sub-019B_sub-019B.nii.gz',
#  'inputs/mri-raw/sub-019B/anat/sub-019B_sub-019B.nii.gz',
#  'inputs/mri-raw/sub-020A/anat/sub-020A_sub-020A.nii.gz',
#  'inputs/mri-raw/sub-020A/anat/sub-020A_sub-020A.nii.gz',
#  'inputs/mri-raw/sub-020B/anat/sub-020B_sub-020B.nii.gz',
#  'inputs/mri-raw/sub-020B/anat/sub-020B_sub-020B.nii.gz',
#  'inputs/mri-raw/sub-021A/anat/sub-021A_sub-021A.nii.gz',
#  'inputs/mri-raw/sub-021A/anat/sub-021A_sub-021A.nii.gz',
#  'inputs/mri-raw/sub-021B/anat/sub-021B_sub-021B.nii.gz',
#  'inputs/mri-raw/sub-021B/anat/sub-021B_sub-021B.nii.gz',
#  'inputs/mri-raw/sub-022B/anat/sub-022B_sub-022B.nii.gz',
#  'inputs/mri-raw/sub-022B/anat/sub-022B_sub-022B.nii.gz',
#  'inputs/mri-raw/sub-023A/anat/sub-023A_sub-023A.nii.gz',
#  'inputs/mri-raw/sub-023A/anat/sub-023A_sub-023A.nii.gz',
#  'inputs/mri-raw/sub-023B/anat/sub-023B_sub-023B.nii.gz',
#  'inputs/mri-raw/sub-023B/anat/sub-023B_sub-023B.nii.gz',
#  'inputs/mri-raw/sub-024A/anat/sub-024A_sub-024A.nii.gz',
#  'inputs/mri-raw/sub-024A/anat/sub-024A_sub-024A.nii.gz',
#  'inputs/mri-raw/sub-024B/anat/sub-024B_sub-024B.nii.gz',
#  'inputs/mri-raw/sub-024B/anat/sub-024B_sub-024B.nii.gz',
#  'inputs/mri-raw/sub-025A/anat/sub-025A_sub-025A.nii.gz',
#  'inputs/mri-raw/sub-025A/anat/sub-025A_sub-025A.nii.gz',
#  'inputs/mri-raw/sub-025B/anat/sub-025B_sub-025B.nii.gz',
#  'inputs/mri-raw/sub-025B/anat/sub-025B_sub-025B.nii.gz',
#  'inputs/mri-raw/sub-026A/anat/sub-026A_sub-026A.nii.gz',
#  'inputs/mri-raw/sub-026A/anat/sub-026A_sub-026A.nii.gz',
#  'inputs/mri-raw/sub-026B/anat/sub-026B_sub-026B.nii.gz',
#  'inputs/mri-raw/sub-026B/anat/sub-026B_sub-026B.nii.gz',
#  'inputs/mri-raw/sub-027A/anat/sub-027A_sub-027A.nii.gz',
#  'inputs/mri-raw/sub-027A/anat/sub-027A_sub-027A.nii.gz',
#  'inputs/mri-raw/sub-027B/anat/sub-027B_sub-027B.nii.gz',
#  'inputs/mri-raw/sub-027B/anat/sub-027B_sub-027B.nii.gz',
#  'inputs/mri-raw/sub-028A/anat/sub-028A_sub-028A.nii.gz',
#  'inputs/mri-raw/sub-028A/anat/sub-028A_sub-028A.nii.gz',
#  'inputs/mri-raw/sub-028B/anat/sub-028B_sub-028B.nii.gz',
#  'inputs/mri-raw/sub-028B/anat/sub-028B_sub-028B.nii.gz',
#  'inputs/mri-raw/sub-029A/anat/sub-029A_sub-029A.nii.gz',
#  'inputs/mri-raw/sub-029A/anat/sub-029A_sub-029A.nii.gz',
#  'inputs/mri-raw/sub-029B/anat/sub-029B_sub-029B.nii.gz',
#  'inputs/mri-raw/sub-029B/anat/sub-029B_sub-029B.nii.gz',
#  'inputs/mri-raw/sub-030A/anat/sub-030A_sub-030A.nii.gz',
#  'inputs/mri-raw/sub-030A/anat/sub-030A_sub-030A.nii.gz',
#  'inputs/mri-raw/sub-030B/anat/sub-030B_sub-030B.nii.gz',
#  'inputs/mri-raw/sub-030B/anat/sub-030B_sub-030B.nii.gz',
#  'inputs/mri-raw/sub-031A/anat/sub-031A_sub-031A.nii.gz',
#  'inputs/mri-raw/sub-031A/anat/sub-031A_sub-031A.nii.gz',
#  'inputs/mri-raw/sub-031B/anat/sub-031B_sub-031B.nii.gz',
#  'inputs/mri-raw/sub-031B/anat/sub-031B_sub-031B.nii.gz',
#  'inputs/mri-raw/sub-032A/anat/sub-032A_sub-032A.nii.gz',
#  'inputs/mri-raw/sub-032A/anat/sub-032A_sub-032A.nii.gz',
#  'inputs/mri-raw/sub-032B/anat/sub-032B_sub-032B.nii.gz',
#  'inputs/mri-raw/sub-032B/anat/sub-032B_sub-032B.nii.gz',
#  'inputs/mri-raw/sub-033A/anat/sub-033A_sub-033A.nii.gz',
#  'inputs/mri-raw/sub-033A/anat/sub-033A_sub-033A.nii.gz',
#  'inputs/mri-raw/sub-033B/anat/sub-033B_sub-033B.nii.gz',
#  'inputs/mri-raw/sub-033B/anat/sub-033B_sub-033B.nii.gz',
#  'inputs/mri-raw/sub-034A/anat/sub-034A_sub-034A.nii.gz',
#  'inputs/mri-raw/sub-034A/anat/sub-034A_sub-034A.nii.gz',
#  'inputs/mri-raw/sub-034B/anat/sub-034B_sub-034B.nii.gz',
#  'inputs/mri-raw/sub-034B/anat/sub-034B_sub-034B.nii.gz',
#  'inputs/mri-raw/sub-035A/anat/sub-035A_sub-035A.nii.gz',
#  'inputs/mri-raw/sub-035A/anat/sub-035A_sub-035A.nii.gz',
#  'inputs/mri-raw/sub-035B/anat/sub-035B_sub-035B.nii.gz',
#  'inputs/mri-raw/sub-035B/anat/sub-035B_sub-035B.nii.gz',
#  'inputs/mri-raw/sub-036A/anat/sub-036A_sub-036A.nii.gz',
#  'inputs/mri-raw/sub-036A/anat/sub-036A_sub-036A.nii.gz',
#  'inputs/mri-raw/sub-036B/anat/sub-036B_sub-036B.nii.gz',
#  'inputs/mri-raw/sub-036B/anat/sub-036B_sub-036B.nii.gz',
#  'inputs/mri-raw/sub-037A/anat/sub-037A_sub-037A.nii.gz',
#  'inputs/mri-raw/sub-037A/anat/sub-037A_sub-037A.nii.gz',
#  'inputs/mri-raw/sub-037B/anat/sub-037B_sub-037B.nii.gz',
#  'inputs/mri-raw/sub-037B/anat/sub-037B_sub-037B.nii.gz',
#  'inputs/mri-raw/sub-038A/anat/sub-038A_sub-038A.nii.gz',
#  'inputs/mri-raw/sub-038A/anat/sub-038A_sub-038A.nii.gz',
#  'inputs/mri-raw/sub-038B/anat/sub-038B_sub-038B.nii.gz',
#  'inputs/mri-raw/sub-038B/anat/sub-038B_sub-038B.nii.gz',
#  'inputs/mri-raw/sub-039A/anat/sub-039A_sub-039A.nii.gz',
#  'inputs/mri-raw/sub-039A/anat/sub-039A_sub-039A.nii.gz',
#  'inputs/mri-raw/sub-039B/anat/sub-039B_sub-039B.nii.gz',
#  'inputs/mri-raw/sub-039B/anat/sub-039B_sub-039B.nii.gz',
#  'inputs/mri-raw/sub-040A/anat/sub-040A_sub-040A.nii.gz',
#  'inputs/mri-raw/sub-040A/anat/sub-040A_sub-040A.nii.gz',
#  'inputs/mri-raw/sub-040B/anat/sub-040B_sub-040B.nii.gz',
#  'inputs/mri-raw/sub-040B/anat/sub-040B_sub-040B.nii.gz',
#  'inputs/mri-raw/sub-041A/anat/sub-041A_sub-041A.nii.gz',
#  'inputs/mri-raw/sub-041A/anat/sub-041A_sub-041A.nii.gz',
#  'inputs/mri-raw/sub-041B/anat/sub-041B_sub-041B.nii.gz',
#  'inputs/mri-raw/sub-041B/anat/sub-041B_sub-041B.nii.gz',
#  'inputs/mri-raw/sub-047A/anat/sub-047A_sub-047A.nii.gz',
#  'inputs/mri-raw/sub-047A/anat/sub-047A_sub-047A.nii.gz',
#  'inputs/mri-raw/sub-047B/anat/sub-047B_sub-047B.nii.gz',
#  'inputs/mri-raw/sub-047B/anat/sub-047B_sub-047B.nii.gz',
#  'inputs/mri-raw/sub-048A/anat/sub-048A_sub-048A.nii.gz',
#  'inputs/mri-raw/sub-048A/anat/sub-048A_sub-048A.nii.gz',
#  'inputs/mri-raw/sub-048B/anat/sub-048B_sub-048B.nii.gz',
#  'inputs/mri-raw/sub-048B/anat/sub-048B_sub-048B.nii.gz',
#  'inputs/mri-raw/sub-049A/anat/sub-049A_sub-049A.nii.gz',
#  'inputs/mri-raw/sub-049A/anat/sub-049A_sub-049A.nii.gz',
#  'inputs/mri-raw/sub-049B/anat/sub-049B_sub-049B.nii.gz',
#  'inputs/mri-raw/sub-049B/anat/sub-049B_sub-049B.nii.gz',
#  'inputs/mri-raw/sub-050A/anat/sub-050A_sub-050A.nii.gz',
#  'inputs/mri-raw/sub-050A/anat/sub-050A_sub-050A.nii.gz',
#  'inputs/mri-raw/sub-050B/anat/sub-050B_sub-050B.nii.gz',
#  'inputs/mri-raw/sub-050B/anat/sub-050B_sub-050B.nii.gz',
#  'inputs/mri-raw/sub-051A/anat/sub-051A_sub-051A.nii.gz',
#  'inputs/mri-raw/sub-051A/anat/sub-051A_sub-051A.nii.gz',
#  'inputs/mri-raw/sub-051B/anat/sub-051B_sub-051B.nii.gz',
#  'inputs/mri-raw/sub-051B/anat/sub-051B_sub-051B.nii.gz',
#  'inputs/mri-raw/sub-052A/anat/sub-052A_sub-052A.nii.gz',
#  'inputs/mri-raw/sub-052A/anat/sub-052A_sub-052A.nii.gz',
#  'inputs/mri-raw/sub-052B/anat/sub-052B_sub-052B.nii.gz',
#  'inputs/mri-raw/sub-052B/anat/sub-052B_sub-052B.nii.gz',
#  'inputs/mri-raw/sub-054A/anat/sub-054A_sub-054A.nii.gz',
#  'inputs/mri-raw/sub-054A/anat/sub-054A_sub-054A.nii.gz',
#  'inputs/mri-raw/sub-054B/anat/sub-054B_sub-054B.nii.gz',
#  'inputs/mri-raw/sub-054B/anat/sub-054B_sub-054B.nii.gz',
#  'inputs/mri-raw/sub-055A/anat/sub-055A_sub-055A.nii.gz',
#  'inputs/mri-raw/sub-055A/anat/sub-055A_sub-055A.nii.gz',
#  'inputs/mri-raw/sub-055B/anat/sub-055B_sub-055B.nii.gz',
#  'inputs/mri-raw/sub-055B/anat/sub-055B_sub-055B.nii.gz',
#  'inputs/mri-raw/sub-056A/anat/sub-056A_sub-056A.nii.gz',
#  'inputs/mri-raw/sub-056A/anat/sub-056A_sub-056A.nii.gz',
#  'inputs/mri-raw/sub-056B/anat/sub-056B_sub-056B.nii.gz',
#  'inputs/mri-raw/sub-056B/anat/sub-056B_sub-056B.nii.gz',
#  'inputs/mri-raw/sub-057A/anat/sub-057A_sub-057A.nii.gz',
#  'inputs/mri-raw/sub-057A/anat/sub-057A_sub-057A.nii.gz',
#  'inputs/mri-raw/sub-057B/anat/sub-057B_sub-057B.nii.gz',
#  'inputs/mri-raw/sub-057B/anat/sub-057B_sub-057B.nii.gz',
#  'inputs/mri-raw/sub-058A/anat/sub-058A_sub-058A.nii.gz',
#  'inputs/mri-raw/sub-058A/anat/sub-058A_sub-058A.nii.gz',
#  'inputs/mri-raw/sub-058B/anat/sub-058B_sub-058B.nii.gz',
#  'inputs/mri-raw/sub-058B/anat/sub-058B_sub-058B.nii.gz',
#  'inputs/mri-raw/sub-059A/anat/sub-059A_sub-059A.nii.gz',
#  'inputs/mri-raw/sub-059A/anat/sub-059A_sub-059A.nii.gz',
#  'inputs/mri-raw/sub-059B/anat/sub-059B_sub-059B.nii.gz',
#  'inputs/mri-raw/sub-059B/anat/sub-059B_sub-059B.nii.gz',
#  'inputs/mri-raw/sub-060A/anat/sub-060A_sub-060A.nii.gz',
#  'inputs/mri-raw/sub-060A/anat/sub-060A_sub-060A.nii.gz',
#  'inputs/mri-raw/sub-060B/anat/sub-060B_sub-060B.nii.gz',
#  'inputs/mri-raw/sub-060B/anat/sub-060B_sub-060B.nii.gz',
#  'inputs/mri-raw/sub-061A/anat/sub-061A_sub-061A.nii.gz',
#  'inputs/mri-raw/sub-061A/anat/sub-061A_sub-061A.nii.gz',
#  'inputs/mri-raw/sub-061B/anat/sub-061B_sub-061B.nii.gz',
#  'inputs/mri-raw/sub-061B/anat/sub-061B_sub-061B.nii.gz',
#  'inputs/mri-raw/sub-062A/anat/sub-062A_sub-062A.nii.gz',
#  'inputs/mri-raw/sub-062A/anat/sub-062A_sub-062A.nii.gz',
#  'inputs/mri-raw/sub-062B/anat/sub-062B_sub-062B.nii.gz',
#  'inputs/mri-raw/sub-062B/anat/sub-062B_sub-062B.nii.gz',
#  'inputs/mri-raw/sub-063A/anat/sub-063A_sub-063A.nii.gz',
#  'inputs/mri-raw/sub-063A/anat/sub-063A_sub-063A.nii.gz',
#  'inputs/mri-raw/sub-063B/anat/sub-063B_sub-063B.nii.gz',
#  'inputs/mri-raw/sub-063B/anat/sub-063B_sub-063B.nii.gz',
#  'inputs/mri-raw/sub-064A/anat/sub-064A_sub-064A.nii.gz',
#  'inputs/mri-raw/sub-064A/anat/sub-064A_sub-064A.nii.gz',
#  'inputs/mri-raw/sub-064B/anat/sub-064B_sub-064B.nii.gz',
#  'inputs/mri-raw/sub-064B/anat/sub-064B_sub-064B.nii.gz',
#  'inputs/mri-raw/sub-065A/anat/sub-065A_sub-065A.nii.gz',
#  'inputs/mri-raw/sub-065A/anat/sub-065A_sub-065A.nii.gz',
#  'inputs/mri-raw/sub-065B/anat/sub-065B_sub-065B.nii.gz',
#  'inputs/mri-raw/sub-065B/anat/sub-065B_sub-065B.nii.gz',
#  'inputs/mri-raw/sub-066A/anat/sub-066A_sub-066A.nii.gz',
#  'inputs/mri-raw/sub-066A/anat/sub-066A_sub-066A.nii.gz',
#  'inputs/mri-raw/sub-066B/anat/sub-066B_sub-066B.nii.gz',
#  'inputs/mri-raw/sub-066B/anat/sub-066B_sub-066B.nii.gz',
#  'inputs/mri-raw/sub-067A/anat/sub-067A_sub-067A.nii.gz',
#  'inputs/mri-raw/sub-067A/anat/sub-067A_sub-067A.nii.gz',
#  'inputs/mri-raw/sub-067B/anat/sub-067B_sub-067B.nii.gz',
#  'inputs/mri-raw/sub-067B/anat/sub-067B_sub-067B.nii.gz',
#  'inputs/mri-raw/sub-068A/anat/sub-068A_sub-068A.nii.gz',
#  'inputs/mri-raw/sub-068A/anat/sub-068A_sub-068A.nii.gz',
#  'inputs/mri-raw/sub-068B/anat/sub-068B_sub-068B.nii.gz',
#  'inputs/mri-raw/sub-068B/anat/sub-068B_sub-068B.nii.gz',
#  'inputs/mri-raw/sub-069A/anat/sub-069A_sub-069A.nii.gz',
#  'inputs/mri-raw/sub-069A/anat/sub-069A_sub-069A.nii.gz',
#  'inputs/mri-raw/sub-069B/anat/sub-069B_sub-069B.nii.gz',
#  'inputs/mri-raw/sub-069B/anat/sub-069B_sub-069B.nii.gz',
#  'inputs/mri-raw/sub-070A/anat/sub-070A_sub-070A.nii.gz',
#  'inputs/mri-raw/sub-070A/anat/sub-070A_sub-070A.nii.gz',
#  'inputs/mri-raw/sub-070B/anat/sub-070B_sub-070B.nii.gz',
#  'inputs/mri-raw/sub-070B/anat/sub-070B_sub-070B.nii.gz',
#  'inputs/mri-raw/sub-071A/anat/sub-071A_sub-071A.nii.gz',
#  'inputs/mri-raw/sub-071A/anat/sub-071A_sub-071A.nii.gz',
#  'inputs/mri-raw/sub-071B/anat/sub-071B_sub-071B.nii.gz',
#  'inputs/mri-raw/sub-071B/anat/sub-071B_sub-071B.nii.gz',
#  'inputs/mri-raw/sub-072A/anat/sub-072A_sub-072A.nii.gz',
#  'inputs/mri-raw/sub-072A/anat/sub-072A_sub-072A.nii.gz',
#  'inputs/mri-raw/sub-072B/anat/sub-072B_sub-072B.nii.gz',
#  'inputs/mri-raw/sub-072B/anat/sub-072B_sub-072B.nii.gz',
#  'inputs/mri-raw/sub-073A/anat/sub-073A_sub-073A.nii.gz',
#  'inputs/mri-raw/sub-073A/anat/sub-073A_sub-073A.nii.gz',
#  'inputs/mri-raw/sub-073B/anat/sub-073B_sub-073B.nii.gz',
#  'inputs/mri-raw/sub-073B/anat/sub-073B_sub-073B.nii.gz',
#  'inputs/mri-raw/sub-074A/anat/sub-074A_sub-074A.nii.gz',
#  'inputs/mri-raw/sub-074A/anat/sub-074A_sub-074A.nii.gz',
#  'inputs/mri-raw/sub-074B/anat/sub-074B_sub-074B.nii.gz',
#  'inputs/mri-raw/sub-074B/anat/sub-074B_sub-074B.nii.gz',
#  'inputs/mri-raw/sub-075A/anat/sub-075A_sub-075A.nii.gz',
#  'inputs/mri-raw/sub-075A/anat/sub-075A_sub-075A.nii.gz',
#  'inputs/mri-raw/sub-075B/anat/sub-075B_sub-075B.nii.gz',
#  'inputs/mri-raw/sub-075B/anat/sub-075B_sub-075B.nii.gz',
#  'inputs/mri-raw/sub-076A/anat/sub-076A_sub-076A.nii.gz',
#  'inputs/mri-raw/sub-076A/anat/sub-076A_sub-076A.nii.gz',
#  'inputs/mri-raw/sub-076B/anat/sub-076B_sub-076B.nii.gz',
#  'inputs/mri-raw/sub-076B/anat/sub-076B_sub-076B.nii.gz',
#  'inputs/mri-raw/sub-077A/anat/sub-077A_sub-077A.nii.gz',
#  'inputs/mri-raw/sub-077A/anat/sub-077A_sub-077A.nii.gz',
#  'inputs/mri-raw/sub-077B/anat/sub-077B_sub-077B.nii.gz',
#  'inputs/mri-raw/sub-077B/anat/sub-077B_sub-077B.nii.gz',
#  'inputs/mri-raw/sub-078A/anat/sub-078A_sub-078A.nii.gz',
#  'inputs/mri-raw/sub-078A/anat/sub-078A_sub-078A.nii.gz',
#  'inputs/mri-raw/sub-078B/anat/sub-078B_sub-078B.nii.gz',
#  'inputs/mri-raw/sub-078B/anat/sub-078B_sub-078B.nii.gz',
#  'inputs/mri-raw/sub-079A/anat/sub-079A_sub-079A.nii.gz',
#  'inputs/mri-raw/sub-079A/anat/sub-079A_sub-079A.nii.gz',
#  'inputs/mri-raw/sub-079B/anat/sub-079B_sub-079B.nii.gz',
#  'inputs/mri-raw/sub-079B/anat/sub-079B_sub-079B.nii.gz',
#  'inputs/mri-raw/sub-080A/anat/sub-080A_sub-080A.nii.gz',
#  'inputs/mri-raw/sub-080A/anat/sub-080A_sub-080A.nii.gz',
#  'inputs/mri-raw/sub-080B/anat/sub-080B_sub-080B.nii.gz',
#  'inputs/mri-raw/sub-080B/anat/sub-080B_sub-080B.nii.gz',
#  'inputs/mri-raw/sub-081A/anat/sub-081A_sub-081A.nii.gz',
#  'inputs/mri-raw/sub-081A/anat/sub-081A_sub-081A.nii.gz',
#  'inputs/mri-raw/sub-081B/anat/sub-081B_sub-081B.nii.gz',
#  'inputs/mri-raw/sub-081B/anat/sub-081B_sub-081B.nii.gz',
#  'inputs/mri-raw/sub-082A/anat/sub-082A_sub-082A.nii.gz',
#  'inputs/mri-raw/sub-082A/anat/sub-082A_sub-082A.nii.gz',
#  'inputs/mri-raw/sub-082B/anat/sub-082B_sub-082B.nii.gz',
#  'inputs/mri-raw/sub-082B/anat/sub-082B_sub-082B.nii.gz',
#  'inputs/mri-raw/sub-083A/anat/sub-083A_sub-083A.nii.gz',
#  'inputs/mri-raw/sub-083A/anat/sub-083A_sub-083A.nii.gz',
#  'inputs/mri-raw/sub-083B/anat/sub-083B_sub-083B.nii.gz',
#  'inputs/mri-raw/sub-083B/anat/sub-083B_sub-083B.nii.gz',
#  'inputs/mri-raw/sub-084A/anat/sub-084A_sub-084A.nii.gz',
#  'inputs/mri-raw/sub-084A/anat/sub-084A_sub-084A.nii.gz',
#  'inputs/mri-raw/sub-084B/anat/sub-084B_sub-084B.nii.gz',
#  'inputs/mri-raw/sub-084B/anat/sub-084B_sub-084B.nii.gz',
#  'inputs/mri-raw/sub-085A/anat/sub-085A_sub-085A.nii.gz',
#  'inputs/mri-raw/sub-085A/anat/sub-085A_sub-085A.nii.gz',
#  'inputs/mri-raw/sub-085B/anat/sub-085B_sub-085B.nii.gz',
#  'inputs/mri-raw/sub-085B/anat/sub-085B_sub-085B.nii.gz',
#  'inputs/mri-raw/sub-086A/anat/sub-086A_sub-086A.nii.gz',
#  'inputs/mri-raw/sub-086A/anat/sub-086A_sub-086A.nii.gz',
#  'inputs/mri-raw/sub-086B/anat/sub-086B_sub-086B.nii.gz',
#  'inputs/mri-raw/sub-086B/anat/sub-086B_sub-086B.nii.gz',
#  'inputs/mri-raw/sub-087A/anat/sub-087A_sub-087A.nii.gz',
#  'inputs/mri-raw/sub-087A/anat/sub-087A_sub-087A.nii.gz',
#  'inputs/mri-raw/sub-087B/anat/sub-087B_sub-087B.nii.gz',
#  'inputs/mri-raw/sub-087B/anat/sub-087B_sub-087B.nii.gz',
#  'inputs/mri-raw/sub-088A/anat/sub-088A_sub-088A.nii.gz',
#  'inputs/mri-raw/sub-088A/anat/sub-088A_sub-088A.nii.gz',
#  'inputs/mri-raw/sub-089A/anat/sub-089A_sub-089A.nii.gz',
#  'inputs/mri-raw/sub-089A/anat/sub-089A_sub-089A.nii.gz',
#  'inputs/mri-raw/sub-089B/anat/sub-089B_sub-089B.nii.gz',
#  'inputs/mri-raw/sub-089B/anat/sub-089B_sub-089B.nii.gz',
#  'inputs/mri-raw/sub-090A/anat/sub-090A_sub-090A.nii.gz',
#  'inputs/mri-raw/sub-090A/anat/sub-090A_sub-090A.nii.gz',
#  'inputs/mri-raw/sub-090B/anat/sub-090B_sub-090B.nii.gz',
#  'inputs/mri-raw/sub-090B/anat/sub-090B_sub-090B.nii.gz',
#  'inputs/mri-raw/sub-091A/anat/sub-091A_sub-091A.nii.gz',
#  'inputs/mri-raw/sub-091A/anat/sub-091A_sub-091A.nii.gz',
#  'inputs/mri-raw/sub-091B/anat/sub-091B_sub-091B.nii.gz',
#  'inputs/mri-raw/sub-091B/anat/sub-091B_sub-091B.nii.gz',
#  'inputs/mri-raw/sub-092A/anat/sub-092A_sub-092A.nii.gz',
#  'inputs/mri-raw/sub-092A/anat/sub-092A_sub-092A.nii.gz',
#  'inputs/mri-raw/sub-092B/anat/sub-092B_sub-092B.nii.gz',
#  'inputs/mri-raw/sub-092B/anat/sub-092B_sub-092B.nii.gz',
#  'inputs/mri-raw/sub-093A/anat/sub-093A_sub-093A.nii.gz',
#  'inputs/mri-raw/sub-093A/anat/sub-093A_sub-093A.nii.gz',
#  'inputs/mri-raw/sub-093B/anat/sub-093B_sub-093B.nii.gz',
#  'inputs/mri-raw/sub-093B/anat/sub-093B_sub-093B.nii.gz',
#  'inputs/mri-raw/sub-094A/anat/sub-094A_sub-094A.nii.gz',
#  'inputs/mri-raw/sub-094A/anat/sub-094A_sub-094A.nii.gz',
#  'inputs/mri-raw/sub-095A/anat/sub-095A_sub-095A.nii.gz',
#  'inputs/mri-raw/sub-095A/anat/sub-095A_sub-095A.nii.gz',
#  'inputs/mri-raw/sub-095B/anat/sub-095B_sub-095B.nii.gz',
#  'inputs/mri-raw/sub-095B/anat/sub-095B_sub-095B.nii.gz',
#  'inputs/mri-raw/sub-096A/anat/sub-096A_sub-096A.nii.gz',
#  'inputs/mri-raw/sub-096A/anat/sub-096A_sub-096A.nii.gz',
#  'inputs/mri-raw/sub-096B/anat/sub-096B_sub-096B.nii.gz',
#  'inputs/mri-raw/sub-096B/anat/sub-096B_sub-096B.nii.gz',
#  'inputs/mri-raw/sub-097A/anat/sub-097A_sub-097A.nii.gz',
#  'inputs/mri-raw/sub-097A/anat/sub-097A_sub-097A.nii.gz',
#  'inputs/mri-raw/sub-097B/anat/sub-097B_sub-097B.nii.gz',
#  'inputs/mri-raw/sub-097B/anat/sub-097B_sub-097B.nii.gz',
#  'inputs/mri-raw/sub-098A/anat/sub-098A_sub-098A.nii.gz',
#  'inputs/mri-raw/sub-098A/anat/sub-098A_sub-098A.nii.gz',
#  'inputs/mri-raw/sub-098B/anat/sub-098B_sub-098B.nii.gz',
#  'inputs/mri-raw/sub-098B/anat/sub-098B_sub-098B.nii.gz',
#  'inputs/mri-raw/sub-099A/anat/sub-099A_sub-099A.nii.gz',
#  'inputs/mri-raw/sub-099A/anat/sub-099A_sub-099A.nii.gz',
#  'inputs/mri-raw/sub-099B/anat/sub-099B_sub-099B.nii.gz',
#  'inputs/mri-raw/sub-100A/anat/sub-100A_sub-100A.nii.gz',
#  'inputs/mri-raw/sub-100A/anat/sub-100A_sub-100A.nii.gz',
#  'inputs/mri-raw/sub-100B/anat/sub-100B_sub-100B.nii.gz',
#  'inputs/mri-raw/sub-100B/anat/sub-100B_sub-100B.nii.gz',
#  'inputs/mri-raw/sub-101A/anat/sub-101A_sub-101A.nii.gz',
#  'inputs/mri-raw/sub-101A/anat/sub-101A_sub-101A.nii.gz',
#  'inputs/mri-raw/sub-101B/anat/sub-101B_sub-101B.nii.gz',
#  'inputs/mri-raw/sub-101B/anat/sub-101B_sub-101B.nii.gz',
#  'inputs/mri-raw/sub-102A/anat/sub-102A_sub-102A.nii.gz',
#  'inputs/mri-raw/sub-102A/anat/sub-102A_sub-102A.nii.gz',
#  'inputs/mri-raw/sub-102B/anat/sub-102B_sub-102B.nii.gz',
#  'inputs/mri-raw/sub-102B/anat/sub-102B_sub-102B.nii.gz',
#  'inputs/mri-raw/sub-103A/anat/sub-103A_sub-103A.nii.gz',
#  'inputs/mri-raw/sub-103A/anat/sub-103A_sub-103A.nii.gz',
#  'inputs/mri-raw/sub-103B/anat/sub-103B_sub-103B.nii.gz',
#  'inputs/mri-raw/sub-103B/anat/sub-103B_sub-103B.nii.gz',
#  'inputs/mri-raw/sub-104A/anat/sub-104A_sub-104A.nii.gz',
#  'inputs/mri-raw/sub-104A/anat/sub-104A_sub-104A.nii.gz',
#  'inputs/mri-raw/sub-104B/anat/sub-104B_sub-104B.nii.gz',
#  'inputs/mri-raw/sub-104B/anat/sub-104B_sub-104B.nii.gz',
#  'inputs/mri-raw/sub-105A/anat/sub-105A_sub-105A.nii.gz',
#  'inputs/mri-raw/sub-105A/anat/sub-105A_sub-105A.nii.gz',
#  'inputs/mri-raw/sub-105B/anat/sub-105B_sub-105B.nii.gz',
#  'inputs/mri-raw/sub-105B/anat/sub-105B_sub-105B.nii.gz',
#  'inputs/mri-raw/sub-106A/anat/sub-106A_sub-106A.nii.gz',
#  'inputs/mri-raw/sub-106A/anat/sub-106A_sub-106A.nii.gz',
#  'inputs/mri-raw/sub-106B/anat/sub-106B_sub-106B.nii.gz',
#  'inputs/mri-raw/sub-106B/anat/sub-106B_sub-106B.nii.gz',
#  'inputs/mri-raw/sub-107A/anat/sub-107A_sub-107A.nii.gz',
#  'inputs/mri-raw/sub-107A/anat/sub-107A_sub-107A.nii.gz',
#  'inputs/mri-raw/sub-107B/anat/sub-107B_sub-107B.nii.gz',
#  'inputs/mri-raw/sub-107B/anat/sub-107B_sub-107B.nii.gz',
#  'inputs/mri-raw/sub-108A/anat/sub-108A_sub-108A.nii.gz',
#  'inputs/mri-raw/sub-108A/anat/sub-108A_sub-108A.nii.gz',
#  'inputs/mri-raw/sub-108B/anat/sub-108B_sub-108B.nii.gz',
#  'inputs/mri-raw/sub-108B/anat/sub-108B_sub-108B.nii.gz',
#  'inputs/mri-raw/sub-109A/anat/sub-109A_sub-109A.nii.gz',
#  'inputs/mri-raw/sub-109A/anat/sub-109A_sub-109A.nii.gz',
#  'inputs/mri-raw/sub-109B/anat/sub-109B_sub-109B.nii.gz',
#  'inputs/mri-raw/sub-109B/anat/sub-109B_sub-109B.nii.gz',
#  'inputs/mri-raw/sub-110A/anat/sub-110A_sub-110A.nii.gz',
#  'inputs/mri-raw/sub-110A/anat/sub-110A_sub-110A.nii.gz',
#  'inputs/mri-raw/sub-110B/anat/sub-110B_sub-110B.nii.gz',
#  'inputs/mri-raw/sub-110B/anat/sub-110B_sub-110B.nii.gz',
#  'inputs/mri-raw/sub-111A/anat/sub-111A_sub-111A.nii.gz',
#  'inputs/mri-raw/sub-111A/anat/sub-111A_sub-111A.nii.gz',
#  'inputs/mri-raw/sub-111B/anat/sub-111B_sub-111B.nii.gz',
#  'inputs/mri-raw/sub-111B/anat/sub-111B_sub-111B.nii.gz',
#  'inputs/mri-raw/sub-112A/anat/sub-112A_sub-112A.nii.gz',
#  'inputs/mri-raw/sub-112A/anat/sub-112A_sub-112A.nii.gz',
#  'inputs/mri-raw/sub-112B/anat/sub-112B_sub-112B.nii.gz',
#  'inputs/mri-raw/sub-112B/anat/sub-112B_sub-112B.nii.gz',
#  'inputs/mri-raw/sub-113A/anat/sub-113A_sub-113A.nii.gz',
#  'inputs/mri-raw/sub-113A/anat/sub-113A_sub-113A.nii.gz',
#  'inputs/mri-raw/sub-114A/anat/sub-114A_sub-114A.nii.gz',
#  'inputs/mri-raw/sub-114A/anat/sub-114A_sub-114A.nii.gz',
#  'inputs/mri-raw/sub-114B/anat/sub-114B_sub-114B.nii.gz',
#  'inputs/mri-raw/sub-114B/anat/sub-114B_sub-114B.nii.gz',
#  'inputs/mri-raw/sub-115A/anat/sub-115A_sub-115A.nii.gz',
#  'inputs/mri-raw/sub-115A/anat/sub-115A_sub-115A.nii.gz',
#  'inputs/mri-raw/sub-116A/anat/sub-116A_sub-116A.nii.gz',
#  'inputs/mri-raw/sub-116A/anat/sub-116A_sub-116A.nii.gz',
#  'inputs/mri-raw/sub-116B/anat/sub-116B_sub-116B.nii.gz',
#  'inputs/mri-raw/sub-116B/anat/sub-116B_sub-116B.nii.gz',
#  'inputs/mri-raw/sub-117A/anat/sub-117A_sub-117A.nii.gz',
#  'inputs/mri-raw/sub-117A/anat/sub-117A_sub-117A.nii.gz',
#  'inputs/mri-raw/sub-117B/anat/sub-117B_sub-117B.nii.gz',
#  'inputs/mri-raw/sub-117B/anat/sub-117B_sub-117B.nii.gz',
#  'inputs/mri-raw/sub-119A/anat/sub-119A_sub-119A.nii.gz',
#  'inputs/mri-raw/sub-119A/anat/sub-119A_sub-119A.nii.gz',
#  'inputs/mri-raw/sub-119B/anat/sub-119B_sub-119B.nii.gz',
#  'inputs/mri-raw/sub-119B/anat/sub-119B_sub-119B.nii.gz',
#  'inputs/mri-raw/sub-120A/anat/sub-120A_sub-120A.nii.gz',
#  'inputs/mri-raw/sub-120A/anat/sub-120A_sub-120A.nii.gz',
#  'inputs/mri-raw/sub-120B/anat/sub-120B_sub-120B.nii.gz',
#  'inputs/mri-raw/sub-120B/anat/sub-120B_sub-120B.nii.gz',
#  'inputs/mri-raw/sub-121A/anat/sub-121A_sub-121A.nii.gz',
#  'inputs/mri-raw/sub-121A/anat/sub-121A_sub-121A.nii.gz',
#  'inputs/mri-raw/sub-121B/anat/sub-121B_sub-121B.nii.gz',
#  'inputs/mri-raw/sub-121B/anat/sub-121B_sub-121B.nii.gz',
#  'inputs/mri-raw/sub-122A/anat/sub-122A_sub-122A.nii.gz',
#  'inputs/mri-raw/sub-122A/anat/sub-122A_sub-122A.nii.gz',
#  'inputs/mri-raw/sub-122B/anat/sub-122B_sub-122B.nii.gz',
#  'inputs/mri-raw/sub-122B/anat/sub-122B_sub-122B.nii.gz',
#  'inputs/mri-raw/sub-123A/anat/sub-123A_sub-123A.nii.gz',
#  'inputs/mri-raw/sub-123A/anat/sub-123A_sub-123A.nii.gz',
#  'inputs/mri-raw/sub-123B/anat/sub-123B_sub-123B.nii.gz',
#  'inputs/mri-raw/sub-123B/anat/sub-123B_sub-123B.nii.gz',
#  'inputs/mri-raw/sub-124A/anat/sub-124A_sub-124A.nii.gz',
#  'inputs/mri-raw/sub-124A/anat/sub-124A_sub-124A.nii.gz',
#  'inputs/mri-raw/sub-124B/anat/sub-124B_sub-124B.nii.gz',
#  'inputs/mri-raw/sub-124B/anat/sub-124B_sub-124B.nii.gz',
#  'inputs/mri-raw/sub-125A/anat/sub-125A_sub-125A.nii.gz',
#  'inputs/mri-raw/sub-125A/anat/sub-125A_sub-125A.nii.gz',
#  'inputs/mri-raw/sub-125B/anat/sub-125B_sub-125B.nii.gz',
#  'inputs/mri-raw/sub-125B/anat/sub-125B_sub-125B.nii.gz',
#  'inputs/mri-raw/sub-126A/anat/sub-126A_sub-126A.nii.gz',
#  'inputs/mri-raw/sub-126A/anat/sub-126A_sub-126A.nii.gz',
#  'inputs/mri-raw/sub-126B/anat/sub-126B_sub-126B.nii.gz',
#  'inputs/mri-raw/sub-126B/anat/sub-126B_sub-126B.nii.gz',
#  'inputs/mri-raw/sub-127A/anat/sub-127A_sub-127A.nii.gz',
#  'inputs/mri-raw/sub-127A/anat/sub-127A_sub-127A.nii.gz',
#  'inputs/mri-raw/sub-127B/anat/sub-127B_sub-127B.nii.gz',
#  'inputs/mri-raw/sub-127B/anat/sub-127B_sub-127B.nii.gz',
#  'inputs/mri-raw/sub-128A/anat/sub-128A_sub-128A.nii.gz',
#  'inputs/mri-raw/sub-128A/anat/sub-128A_sub-128A.nii.gz',
#  'inputs/mri-raw/sub-128B/anat/sub-128B_sub-128B.nii.gz',
#  'inputs/mri-raw/sub-128B/anat/sub-128B_sub-128B.nii.gz',
#  'inputs/mri-raw/sub-129A/anat/sub-129A_sub-129A.nii.gz',
#  'inputs/mri-raw/sub-129A/anat/sub-129A_sub-129A.nii.gz',
#  'inputs/mri-raw/sub-129B/anat/sub-129B_sub-129B.nii.gz',
#  'inputs/mri-raw/sub-129B/anat/sub-129B_sub-129B.nii.gz',
#  'inputs/mri-raw/sub-130A/anat/sub-130A_sub-130A.nii.gz',
#  'inputs/mri-raw/sub-130A/anat/sub-130A_sub-130A.nii.gz',
#  'inputs/mri-raw/sub-130B/anat/sub-130B_sub-130B.nii.gz',
#  'inputs/mri-raw/sub-130B/anat/sub-130B_sub-130B.nii.gz',
#  'inputs/mri-raw/sub-131A/anat/sub-131A_sub-131A.nii.gz',
#  'inputs/mri-raw/sub-131A/anat/sub-131A_sub-131A.nii.gz',
#  'inputs/mri-raw/sub-131B/anat/sub-131B_sub-131B.nii.gz',
#  'inputs/mri-raw/sub-131B/anat/sub-131B_sub-131B.nii.gz',
#  'inputs/mri-raw/sub-132A/anat/sub-132A_sub-132A.nii.gz',
#  'inputs/mri-raw/sub-132A/anat/sub-132A_sub-132A.nii.gz',
#  'inputs/mri-raw/sub-132B/anat/sub-132B_sub-132B.nii.gz',
#  'inputs/mri-raw/sub-132B/anat/sub-132B_sub-132B.nii.gz',
#  'inputs/mri-raw/sub-133A/anat/sub-133A_sub-133A.nii.gz',
#  'inputs/mri-raw/sub-133A/anat/sub-133A_sub-133A.nii.gz',
#  'inputs/mri-raw/sub-133B/anat/sub-133B_sub-133B.nii.gz',
#  'inputs/mri-raw/sub-133B/anat/sub-133B_sub-133B.nii.gz',
#  'inputs/mri-raw/sub-134A/anat/sub-134A_sub-134A.nii.gz',
#  'inputs/mri-raw/sub-134A/anat/sub-134A_sub-134A.nii.gz',
#  'inputs/mri-raw/sub-134B/anat/sub-134B_sub-134B.nii.gz',
#  'inputs/mri-raw/sub-134B/anat/sub-134B_sub-134B.nii.gz',
#  'inputs/mri-raw/sub-135A/anat/sub-135A_sub-135A.nii.gz',
#  'inputs/mri-raw/sub-135A/anat/sub-135A_sub-135A.nii.gz',
#  'inputs/mri-raw/sub-135B/anat/sub-135B_sub-135B.nii.gz',
#  'inputs/mri-raw/sub-135B/anat/sub-135B_sub-135B.nii.gz',
#  'inputs/mri-raw/sub-136A/anat/sub-136A_sub-136A.nii.gz',
#  'inputs/mri-raw/sub-136A/anat/sub-136A_sub-136A.nii.gz',
#  'inputs/mri-raw/sub-136B/anat/sub-136B_sub-136B.nii.gz',
#  'inputs/mri-raw/sub-136B/anat/sub-136B_sub-136B.nii.gz',
#  'inputs/mri-raw/sub-137A/anat/sub-137A_sub-137A.nii.gz',
#  'inputs/mri-raw/sub-137A/anat/sub-137A_sub-137A.nii.gz',
#  'inputs/mri-raw/sub-137B/anat/sub-137B_sub-137B.nii.gz',
#  'inputs/mri-raw/sub-137B/anat/sub-137B_sub-137B.nii.gz',
#  'inputs/mri-raw/sub-137C/anat/sub-137C_sub-137C.nii.gz',
#  'inputs/mri-raw/sub-137C/anat/sub-137C_sub-137C.nii.gz',
#  'inputs/mri-raw/sub-138A/anat/sub-138A_sub-138A.nii.gz',
#  'inputs/mri-raw/sub-138A/anat/sub-138A_sub-138A.nii.gz',
#  'inputs/mri-raw/sub-138B/anat/sub-138B_sub-138B.nii.gz',
#  'inputs/mri-raw/sub-138B/anat/sub-138B_sub-138B.nii.gz',
#  'inputs/mri-raw/sub-139A/anat/sub-139A_sub-139A.nii.gz',
#  'inputs/mri-raw/sub-139A/anat/sub-139A_sub-139A.nii.gz',
#  'inputs/mri-raw/sub-139B/anat/sub-139B_sub-139B.nii.gz',
#  'inputs/mri-raw/sub-139B/anat/sub-139B_sub-139B.nii.gz',
#  'inputs/mri-raw/sub-140A/anat/sub-140A_sub-140A.nii.gz',
#  'inputs/mri-raw/sub-140B/anat/sub-140B_sub-140B.nii.gz',
#  'inputs/mri-raw/sub-140B/anat/sub-140B_sub-140B.nii.gz',
#  'inputs/mri-raw/sub-141A/anat/sub-141A_sub-141A.nii.gz',
#  'inputs/mri-raw/sub-141A/anat/sub-141A_sub-141A.nii.gz',
#  'inputs/mri-raw/sub-141B/anat/sub-141B_sub-141B.nii.gz',
#  'inputs/mri-raw/sub-141B/anat/sub-141B_sub-141B.nii.gz',
#  'inputs/mri-raw/sub-142A/anat/sub-142A_sub-142A.nii.gz',
#  'inputs/mri-raw/sub-142A/anat/sub-142A_sub-142A.nii.gz',
#  'inputs/mri-raw/sub-142B/anat/sub-142B_sub-142B.nii.gz',
#  'inputs/mri-raw/sub-142B/anat/sub-142B_sub-142B.nii.gz',
#  'inputs/mri-raw/sub-143A/anat/sub-143A_sub-143A.nii.gz',
#  'inputs/mri-raw/sub-143A/anat/sub-143A_sub-143A.nii.gz',
#  'inputs/mri-raw/sub-144A/anat/sub-144A_sub-144A.nii.gz',
#  'inputs/mri-raw/sub-144A/anat/sub-144A_sub-144A.nii.gz',
#  'inputs/mri-raw/sub-144B/anat/sub-144B_sub-144B.nii.gz',
#  'inputs/mri-raw/sub-144B/anat/sub-144B_sub-144B.nii.gz',
#  'inputs/mri-raw/sub-145A/anat/sub-145A_sub-145A.nii.gz',
#  'inputs/mri-raw/sub-145A/anat/sub-145A_sub-145A.nii.gz',
#  'inputs/mri-raw/sub-145B/anat/sub-145B_sub-145B.nii.gz',
#  'inputs/mri-raw/sub-145B/anat/sub-145B_sub-145B.nii.gz',
#  'inputs/mri-raw/sub-146A/anat/sub-146A_sub-146A.nii.gz',
#  'inputs/mri-raw/sub-146A/anat/sub-146A_sub-146A.nii.gz',
#  'inputs/mri-raw/sub-146B/anat/sub-146B_sub-146B.nii.gz',
#  'inputs/mri-raw/sub-146B/anat/sub-146B_sub-146B.nii.gz',
#  'inputs/mri-raw/sub-147A/anat/sub-147A_sub-147A.nii.gz',
#  'inputs/mri-raw/sub-147A/anat/sub-147A_sub-147A.nii.gz',
#  'inputs/mri-raw/sub-147B/anat/sub-147B_sub-147B.nii.gz',
#  'inputs/mri-raw/sub-147B/anat/sub-147B_sub-147B.nii.gz',
#  'inputs/mri-raw/sub-148A/anat/sub-148A_sub-148A.nii.gz',
#  'inputs/mri-raw/sub-148A/anat/sub-148A_sub-148A.nii.gz',
#  'inputs/mri-raw/sub-148B/anat/sub-148B_sub-148B.nii.gz',
#  'inputs/mri-raw/sub-148B/anat/sub-148B_sub-148B.nii.gz',
#  'inputs/mri-raw/sub-149A/anat/sub-149A_sub-149A.nii.gz',
#  'inputs/mri-raw/sub-149A/anat/sub-149A_sub-149A.nii.gz',
#  'inputs/mri-raw/sub-149B/anat/sub-149B_sub-149B.nii.gz',
#  'inputs/mri-raw/sub-149B/anat/sub-149B_sub-149B.nii.gz',
#  'inputs/mri-raw/sub-150A/anat/sub-150A_sub-150A.nii.gz',
#  'inputs/mri-raw/sub-150A/anat/sub-150A_sub-150A.nii.gz',
#  'inputs/mri-raw/sub-150B/anat/sub-150B_sub-150B.nii.gz',
#  'inputs/mri-raw/sub-150B/anat/sub-150B_sub-150B.nii.gz',
#  'inputs/mri-raw/sub-151A/anat/sub-151A_sub-151A.nii.gz',
#  'inputs/mri-raw/sub-151A/anat/sub-151A_sub-151A.nii.gz',
#  'inputs/mri-raw/sub-151B/anat/sub-151B_sub-151B.nii.gz',
#  'inputs/mri-raw/sub-151B/anat/sub-151B_sub-151B.nii.gz',
#  'inputs/mri-raw/sub-152A/anat/sub-152A_sub-152A.nii.gz',
#  'inputs/mri-raw/sub-152A/anat/sub-152A_sub-152A.nii.gz',
#  'inputs/mri-raw/sub-152B/anat/sub-152B_sub-152B.nii.gz',
#  'inputs/mri-raw/sub-152B/anat/sub-152B_sub-152B.nii.gz',
#  'inputs/mri-raw/sub-152C/anat/sub-152C_sub-152C.nii.gz',
#  'inputs/mri-raw/sub-152C/anat/sub-152C_sub-152C.nii.gz',
#  'inputs/mri-raw/sub-153A/anat/sub-153A_sub-153A.nii.gz',
#  'inputs/mri-raw/sub-153A/anat/sub-153A_sub-153A.nii.gz',
#  'inputs/mri-raw/sub-153B/anat/sub-153B_sub-153B.nii.gz',
#  'inputs/mri-raw/sub-153B/anat/sub-153B_sub-153B.nii.gz',
#  'inputs/mri-raw/sub-154A/anat/sub-154A_sub-154A.nii.gz',
#  'inputs/mri-raw/sub-154A/anat/sub-154A_sub-154A.nii.gz',
#  'inputs/mri-raw/sub-154B/anat/sub-154B_sub-154B.nii.gz',
#  'inputs/mri-raw/sub-155A/anat/sub-155A_sub-155A.nii.gz',
#  'inputs/mri-raw/sub-155A/anat/sub-155A_sub-155A.nii.gz',
#  'inputs/mri-raw/sub-155B/anat/sub-155B_sub-155B.nii.gz',
#  'inputs/mri-raw/sub-155B/anat/sub-155B_sub-155B.nii.gz',
#  'inputs/mri-raw/sub-156A/anat/sub-156A_sub-156A.nii.gz',
#  'inputs/mri-raw/sub-156A/anat/sub-156A_sub-156A.nii.gz',
#  'inputs/mri-raw/sub-156B/anat/sub-156B_sub-156B.nii.gz',
#  'inputs/mri-raw/sub-156B/anat/sub-156B_sub-156B.nii.gz',
#  'inputs/mri-raw/sub-157A/anat/sub-157A_sub-157A.nii.gz',
#  'inputs/mri-raw/sub-157A/anat/sub-157A_sub-157A.nii.gz',
#  'inputs/mri-raw/sub-157B/anat/sub-157B_sub-157B.nii.gz',
#  'inputs/mri-raw/sub-157B/anat/sub-157B_sub-157B.nii.gz',
#  'inputs/mri-raw/sub-158A/anat/sub-158A_sub-158A.nii.gz',
#  'inputs/mri-raw/sub-158A/anat/sub-158A_sub-158A.nii.gz',
#  'inputs/mri-raw/sub-158B/anat/sub-158B_sub-158B.nii.gz',
#  'inputs/mri-raw/sub-158B/anat/sub-158B_sub-158B.nii.gz',
#  'inputs/mri-raw/sub-159A/anat/sub-159A_sub-159A.nii.gz',
#  'inputs/mri-raw/sub-159A/anat/sub-159A_sub-159A.nii.gz',
#  'inputs/mri-raw/sub-159B/anat/sub-159B_sub-159B.nii.gz',
#  'inputs/mri-raw/sub-159B/anat/sub-159B_sub-159B.nii.gz',
#  'inputs/mri-raw/sub-160A/anat/sub-160A_sub-160A.nii.gz',
#  'inputs/mri-raw/sub-160A/anat/sub-160A_sub-160A.nii.gz',
#  'inputs/mri-raw/sub-160B/anat/sub-160B_sub-160B.nii.gz',
#  'inputs/mri-raw/sub-160B/anat/sub-160B_sub-160B.nii.gz',
#  'inputs/mri-raw/sub-161A/anat/sub-161A_sub-161A.nii.gz',
#  'inputs/mri-raw/sub-161A/anat/sub-161A_sub-161A.nii.gz',
#  'inputs/mri-raw/sub-161B/anat/sub-161B_sub-161B.nii.gz',
#  'inputs/mri-raw/sub-161B/anat/sub-161B_sub-161B.nii.gz',
#  'inputs/mri-raw/sub-162A/anat/sub-162A_sub-162A.nii.gz',
#  'inputs/mri-raw/sub-162A/anat/sub-162A_sub-162A.nii.gz',
#  'inputs/mri-raw/sub-162B/anat/sub-162B_sub-162B.nii.gz',
#  'inputs/mri-raw/sub-162B/anat/sub-162B_sub-162B.nii.gz',
#  'inputs/mri-raw/sub-163A/anat/sub-163A_sub-163A.nii.gz',
#  'inputs/mri-raw/sub-163A/anat/sub-163A_sub-163A.nii.gz',
#  'inputs/mri-raw/sub-163B/anat/sub-163B_sub-163B.nii.gz',
#  'inputs/mri-raw/sub-163B/anat/sub-163B_sub-163B.nii.gz',
#  'inputs/mri-raw/sub-164A/anat/sub-164A_sub-164A.nii.gz',
#  'inputs/mri-raw/sub-164A/anat/sub-164A_sub-164A.nii.gz',
#  'inputs/mri-raw/sub-164B/anat/sub-164B_sub-164B.nii.gz',
#  'inputs/mri-raw/sub-164B/anat/sub-164B_sub-164B.nii.gz',
#  'inputs/mri-raw/sub-165A/anat/sub-165A_sub-165A.nii.gz',
#  'inputs/mri-raw/sub-165A/anat/sub-165A_sub-165A.nii.gz',
#  'inputs/mri-raw/sub-165B/anat/sub-165B_sub-165B.nii.gz',
#  'inputs/mri-raw/sub-165B/anat/sub-165B_sub-165B.nii.gz',
#  'inputs/mri-raw/sub-166A/anat/sub-166A_sub-166A.nii.gz',
#  'inputs/mri-raw/sub-166A/anat/sub-166A_sub-166A.nii.gz',
#  'inputs/mri-raw/sub-166B/anat/sub-166B_sub-166B.nii.gz',
#  'inputs/mri-raw/sub-166B/anat/sub-166B_sub-166B.nii.gz',
#  'inputs/mri-raw/sub-167A/anat/sub-167A_sub-167A.nii.gz',
#  'inputs/mri-raw/sub-167A/anat/sub-167A_sub-167A.nii.gz',
#  'inputs/mri-raw/sub-168A/anat/sub-168A_sub-168A.nii.gz',
#  'inputs/mri-raw/sub-168A/anat/sub-168A_sub-168A.nii.gz',
#  'inputs/mri-raw/sub-168B/anat/sub-168B_sub-168B.nii.gz',
#  'inputs/mri-raw/sub-168B/anat/sub-168B_sub-168B.nii.gz',
#  'inputs/mri-raw/sub-169A/anat/sub-169A_sub-169A.nii.gz',
#  'inputs/mri-raw/sub-169A/anat/sub-169A_sub-169A.nii.gz',
#  'inputs/mri-raw/sub-169B/anat/sub-169B_sub-169B.nii.gz',
#  'inputs/mri-raw/sub-169B/anat/sub-169B_sub-169B.nii.gz',
#  'inputs/mri-raw/sub-170A/anat/sub-170A_sub-170A.nii.gz',
#  'inputs/mri-raw/sub-170A/anat/sub-170A_sub-170A.nii.gz',
#  'inputs/mri-raw/sub-170B/anat/sub-170B_sub-170B.nii.gz',
#  'inputs/mri-raw/sub-170B/anat/sub-170B_sub-170B.nii.gz',
#  'inputs/mri-raw/sub-171A/anat/sub-171A_sub-171A.nii.gz',
#  'inputs/mri-raw/sub-171A/anat/sub-171A_sub-171A.nii.gz',
#  'inputs/mri-raw/sub-171B/anat/sub-171B_sub-171B.nii.gz',
#  'inputs/mri-raw/sub-171B/anat/sub-171B_sub-171B.nii.gz',
#  'inputs/mri-raw/sub-172A/anat/sub-172A_sub-172A.nii.gz',
#  'inputs/mri-raw/sub-172A/anat/sub-172A_sub-172A.nii.gz',
#  'inputs/mri-raw/sub-173A/anat/sub-173A_sub-173A.nii.gz',
#  'inputs/mri-raw/sub-173A/anat/sub-173A_sub-173A.nii.gz',
#  'inputs/mri-raw/sub-173B/anat/sub-173B_sub-173B.nii.gz',
#  'inputs/mri-raw/sub-173B/anat/sub-173B_sub-173B.nii.gz',
#  'inputs/mri-raw/sub-174A/anat/sub-174A_sub-174A.nii.gz',
#  'inputs/mri-raw/sub-174A/anat/sub-174A_sub-174A.nii.gz',
#  'inputs/mri-raw/sub-174B/anat/sub-174B_sub-174B.nii.gz',
#  'inputs/mri-raw/sub-174B/anat/sub-174B_sub-174B.nii.gz',
#  'inputs/mri-raw/sub-175A/anat/sub-175A_sub-175A.nii.gz',
#  'inputs/mri-raw/sub-175A/anat/sub-175A_sub-175A.nii.gz',
#  'inputs/mri-raw/sub-175B/anat/sub-175B_sub-175B.nii.gz',
#  'inputs/mri-raw/sub-175B/anat/sub-175B_sub-175B.nii.gz',
#  'inputs/mri-raw/sub-176A/anat/sub-176A_sub-176A.nii.gz',
#  'inputs/mri-raw/sub-176A/anat/sub-176A_sub-176A.nii.gz',
#  'inputs/mri-raw/sub-176B/anat/sub-176B_sub-176B.nii.gz',
#  'inputs/mri-raw/sub-176B/anat/sub-176B_sub-176B.nii.gz',
#  'inputs/mri-raw/sub-177A/anat/sub-177A_sub-177A.nii.gz',
#  'inputs/mri-raw/sub-177A/anat/sub-177A_sub-177A.nii.gz',
#  'inputs/mri-raw/sub-177B/anat/sub-177B_sub-177B.nii.gz',
#  'inputs/mri-raw/sub-177B/anat/sub-177B_sub-177B.nii.gz',
#  'inputs/mri-raw/sub-178A/anat/sub-178A_sub-178A.nii.gz',
#  'inputs/mri-raw/sub-178A/anat/sub-178A_sub-178A.nii.gz',
#  'inputs/mri-raw/sub-178B/anat/sub-178B_sub-178B.nii.gz',
#  'inputs/mri-raw/sub-178B/anat/sub-178B_sub-178B.nii.gz',
#  'inputs/mri-raw/sub-179A/anat/sub-179A_sub-179A.nii.gz',
#  'inputs/mri-raw/sub-179A/anat/sub-179A_sub-179A.nii.gz',
#  'inputs/mri-raw/sub-179B/anat/sub-179B_sub-179B.nii.gz',
#  'inputs/mri-raw/sub-179B/anat/sub-179B_sub-179B.nii.gz',
#  'inputs/mri-raw/sub-180A/anat/sub-180A_sub-180A.nii.gz',
#  'inputs/mri-raw/sub-180A/anat/sub-180A_sub-180A.nii.gz',
#  'inputs/mri-raw/sub-180B/anat/sub-180B_sub-180B.nii.gz',
#  'inputs/mri-raw/sub-180B/anat/sub-180B_sub-180B.nii.gz',
#  'inputs/mri-raw/sub-180C/anat/sub-180C_sub-180C.nii.gz',
#  'inputs/mri-raw/sub-180C/anat/sub-180C_sub-180C.nii.gz',
#  'inputs/mri-raw/sub-181A/anat/sub-181A_sub-181A.nii.gz',
#  'inputs/mri-raw/sub-181A/anat/sub-181A_sub-181A.nii.gz',
#  'inputs/mri-raw/sub-181B/anat/sub-181B_sub-181B.nii.gz',
#  'inputs/mri-raw/sub-181B/anat/sub-181B_sub-181B.nii.gz',
#  'inputs/mri-raw/sub-182A/anat/sub-182A_sub-182A.nii.gz',
#  'inputs/mri-raw/sub-182A/anat/sub-182A_sub-182A.nii.gz',
#  'inputs/mri-raw/sub-182B/anat/sub-182B_sub-182B.nii.gz',
#  'inputs/mri-raw/sub-182B/anat/sub-182B_sub-182B.nii.gz',
#  'inputs/mri-raw/sub-183A/anat/sub-183A_sub-183A.nii.gz',
#  'inputs/mri-raw/sub-183A/anat/sub-183A_sub-183A.nii.gz',
#  'inputs/mri-raw/sub-183B/anat/sub-183B_sub-183B.nii.gz',
#  'inputs/mri-raw/sub-183B/anat/sub-183B_sub-183B.nii.gz',
#  'inputs/mri-raw/sub-184A/anat/sub-184A_sub-184A.nii.gz',
#  'inputs/mri-raw/sub-184A/anat/sub-184A_sub-184A.nii.gz',
#  'inputs/mri-raw/sub-184B/anat/sub-184B_sub-184B.nii.gz',
#  'inputs/mri-raw/sub-184B/anat/sub-184B_sub-184B.nii.gz',
#  'inputs/mri-raw/sub-185A/anat/sub-185A_sub-185A.nii.gz',
#  'inputs/mri-raw/sub-185A/anat/sub-185A_sub-185A.nii.gz',
#  'inputs/mri-raw/sub-185B/anat/sub-185B_sub-185B.nii.gz',
#  'inputs/mri-raw/sub-185B/anat/sub-185B_sub-185B.nii.gz',
#  'inputs/mri-raw/sub-186A/anat/sub-186A_sub-186A.nii.gz',
#  'inputs/mri-raw/sub-186A/anat/sub-186A_sub-186A.nii.gz',
#  'inputs/mri-raw/sub-186B/anat/sub-186B_sub-186B.nii.gz',
#  'inputs/mri-raw/sub-186B/anat/sub-186B_sub-186B.nii.gz',
#  'inputs/mri-raw/sub-187A/anat/sub-187A_sub-187A.nii.gz',
#  'inputs/mri-raw/sub-187A/anat/sub-187A_sub-187A.nii.gz',
#  'inputs/mri-raw/sub-187B/anat/sub-187B_sub-187B.nii.gz',
#  'inputs/mri-raw/sub-187B/anat/sub-187B_sub-187B.nii.gz',
#  'inputs/mri-raw/sub-188A/anat/sub-188A_sub-188A.nii.gz',
#  'inputs/mri-raw/sub-188A/anat/sub-188A_sub-188A.nii.gz',
#  'inputs/mri-raw/sub-188B/anat/sub-188B_sub-188B.nii.gz',
#  'inputs/mri-raw/sub-188B/anat/sub-188B_sub-188B.nii.gz',
#  'inputs/mri-raw/sub-189A/anat/sub-189A_sub-189A.nii.gz',
#  'inputs/mri-raw/sub-189A/anat/sub-189A_sub-189A.nii.gz',
#  'inputs/mri-raw/sub-189B/anat/sub-189B_sub-189B.nii.gz',
#  'inputs/mri-raw/sub-189B/anat/sub-189B_sub-189B.nii.gz',
#  'inputs/mri-raw/sub-190A/anat/sub-190A_sub-190A.nii.gz',
#  'inputs/mri-raw/sub-190A/anat/sub-190A_sub-190A.nii.gz',
#  'inputs/mri-raw/sub-190B/anat/sub-190B_sub-190B.nii.gz',
#  'inputs/mri-raw/sub-190B/anat/sub-190B_sub-190B.nii.gz',
#  'inputs/mri-raw/sub-191A/anat/sub-191A_sub-191A.nii.gz',
#  'inputs/mri-raw/sub-191A/anat/sub-191A_sub-191A.nii.gz',
#  'inputs/mri-raw/sub-191B/anat/sub-191B_sub-191B.nii.gz',
#  'inputs/mri-raw/sub-191B/anat/sub-191B_sub-191B.nii.gz',
#  'inputs/mri-raw/sub-192A/anat/sub-192A_sub-192A.nii.gz',
#  'inputs/mri-raw/sub-192A/anat/sub-192A_sub-192A.nii.gz',
#  'inputs/mri-raw/sub-192B/anat/sub-192B_sub-192B.nii.gz',
#  'inputs/mri-raw/sub-193A/anat/sub-193A_sub-193A.nii.gz',
#  'inputs/mri-raw/sub-193A/anat/sub-193A_sub-193A.nii.gz',
#  'inputs/mri-raw/sub-193B/anat/sub-193B_sub-193B.nii.gz',
#  'inputs/mri-raw/sub-193B/anat/sub-193B_sub-193B.nii.gz',
#  'inputs/mri-raw/sub-194A/anat/sub-194A_sub-194A.nii.gz',
#  'inputs/mri-raw/sub-194A/anat/sub-194A_sub-194A.nii.gz',
#  'inputs/mri-raw/sub-194B/anat/sub-194B_sub-194B.nii.gz',
#  'inputs/mri-raw/sub-194B/anat/sub-194B_sub-194B.nii.gz',
#  'inputs/mri-raw/sub-195A/anat/sub-195A_sub-195A.nii.gz',
#  'inputs/mri-raw/sub-195A/anat/sub-195A_sub-195A.nii.gz',
#  'inputs/mri-raw/sub-195B/anat/sub-195B_sub-195B.nii.gz',
#  'inputs/mri-raw/sub-195B/anat/sub-195B_sub-195B.nii.gz',
#  'inputs/mri-raw/sub-196A/anat/sub-196A_sub-196A.nii.gz',
#  'inputs/mri-raw/sub-196B/anat/sub-196B_sub-196B.nii.gz',
#  'inputs/mri-raw/sub-196B/anat/sub-196B_sub-196B.nii.gz',
#  'inputs/mri-raw/sub-197A/anat/sub-197A_sub-197A.nii.gz',
#  'inputs/mri-raw/sub-197A/anat/sub-197A_sub-197A.nii.gz',
#  'inputs/mri-raw/sub-197B/anat/sub-197B_sub-197B.nii.gz',
#  'inputs/mri-raw/sub-197B/anat/sub-197B_sub-197B.nii.gz',
#  'inputs/mri-raw/sub-198A/anat/sub-198A_sub-198A.nii.gz',
#  'inputs/mri-raw/sub-198A/anat/sub-198A_sub-198A.nii.gz',
#  'inputs/mri-raw/sub-198B/anat/sub-198B_sub-198B.nii.gz',
#  'inputs/mri-raw/sub-198B/anat/sub-198B_sub-198B.nii.gz',
#  'inputs/mri-raw/sub-199A/anat/sub-199A_sub-199A.nii.gz',
#  'inputs/mri-raw/sub-199A/anat/sub-199A_sub-199A.nii.gz',
#  'inputs/mri-raw/sub-199B/anat/sub-199B_sub-199B.nii.gz',
#  'inputs/mri-raw/sub-199B/anat/sub-199B_sub-199B.nii.gz',
#  'inputs/mri-raw/sub-200A/anat/sub-200A_sub-200A.nii.gz',
#  'inputs/mri-raw/sub-200A/anat/sub-200A_sub-200A.nii.gz',
#  'inputs/mri-raw/sub-200B/anat/sub-200B_sub-200B.nii.gz',
#  'inputs/mri-raw/sub-200B/anat/sub-200B_sub-200B.nii.gz',
#  'inputs/mri-raw/sub-201A/anat/sub-201A_sub-201A.nii.gz',
#  'inputs/mri-raw/sub-201A/anat/sub-201A_sub-201A.nii.gz',
#  'inputs/mri-raw/sub-201B/anat/sub-201B_sub-201B.nii.gz',
#  'inputs/mri-raw/sub-201B/anat/sub-201B_sub-201B.nii.gz',
#  'inputs/mri-raw/sub-202A/anat/sub-202A_sub-202A.nii.gz',
#  'inputs/mri-raw/sub-202A/anat/sub-202A_sub-202A.nii.gz',
#  'inputs/mri-raw/sub-202B/anat/sub-202B_sub-202B.nii.gz',
#  'inputs/mri-raw/sub-202B/anat/sub-202B_sub-202B.nii.gz',
#  'inputs/mri-raw/sub-203A/anat/sub-203A_sub-203A.nii.gz',
#  'inputs/mri-raw/sub-203A/anat/sub-203A_sub-203A.nii.gz',
#  'inputs/mri-raw/sub-203B/anat/sub-203B_sub-203B.nii.gz',
#  'inputs/mri-raw/sub-203B/anat/sub-203B_sub-203B.nii.gz',
#  'inputs/mri-raw/sub-204A/anat/sub-204A_sub-204A.nii.gz',
#  'inputs/mri-raw/sub-204A/anat/sub-204A_sub-204A.nii.gz',
#  'inputs/mri-raw/sub-204B/anat/sub-204B_sub-204B.nii.gz',
#  'inputs/mri-raw/sub-204B/anat/sub-204B_sub-204B.nii.gz',
#  'inputs/mri-raw/sub-205A/anat/sub-205A_sub-205A.nii.gz',
#  'inputs/mri-raw/sub-205A/anat/sub-205A_sub-205A.nii.gz',
#  'inputs/mri-raw/sub-205B/anat/sub-205B_sub-205B.nii.gz',
#  'inputs/mri-raw/sub-205B/anat/sub-205B_sub-205B.nii.gz',
#  'inputs/mri-raw/sub-206A/anat/sub-206A_sub-206A.nii.gz',
#  'inputs/mri-raw/sub-206A/anat/sub-206A_sub-206A.nii.gz',
#  'inputs/mri-raw/sub-206B/anat/sub-206B_sub-206B.nii.gz',
#  'inputs/mri-raw/sub-206B/anat/sub-206B_sub-206B.nii.gz',
#  'inputs/mri-raw/sub-207A/anat/sub-207A_sub-207A.nii.gz',
#  'inputs/mri-raw/sub-207A/anat/sub-207A_sub-207A.nii.gz',
#  'inputs/mri-raw/sub-208A/anat/sub-208A_sub-208A.nii.gz',
#  'inputs/mri-raw/sub-208A/anat/sub-208A_sub-208A.nii.gz',
#  'inputs/mri-raw/sub-208B/anat/sub-208B_sub-208B.nii.gz',
#  'inputs/mri-raw/sub-208B/anat/sub-208B_sub-208B.nii.gz',
#  'inputs/mri-raw/sub-209A/anat/sub-209A_sub-209A.nii.gz',
#  'inputs/mri-raw/sub-209A/anat/sub-209A_sub-209A.nii.gz',
#  'inputs/mri-raw/sub-209B/anat/sub-209B_sub-209B.nii.gz',
#  'inputs/mri-raw/sub-209B/anat/sub-209B_sub-209B.nii.gz',
#  'inputs/mri-raw/sub-210A/anat/sub-210A_sub-210A.nii.gz',
#  'inputs/mri-raw/sub-210A/anat/sub-210A_sub-210A.nii.gz',
#  'inputs/mri-raw/sub-210B/anat/sub-210B_sub-210B.nii.gz',
#  'inputs/mri-raw/sub-210B/anat/sub-210B_sub-210B.nii.gz',
#  'inputs/mri-raw/sub-211A/anat/sub-211A_sub-211A.nii.gz',
#  'inputs/mri-raw/sub-211A/anat/sub-211A_sub-211A.nii.gz',
#  'inputs/mri-raw/sub-211B/anat/sub-211B_sub-211B.nii.gz',
#  'inputs/mri-raw/sub-211B/anat/sub-211B_sub-211B.nii.gz',
#  'inputs/mri-raw/sub-212A/anat/sub-212A_sub-212A.nii.gz',
#  'inputs/mri-raw/sub-212A/anat/sub-212A_sub-212A.nii.gz',
#  'inputs/mri-raw/sub-212B/anat/sub-212B_sub-212B.nii.gz',
#  'inputs/mri-raw/sub-212B/anat/sub-212B_sub-212B.nii.gz',
#  'inputs/mri-raw/sub-213A/anat/sub-213A_sub-213A.nii.gz',
#  'inputs/mri-raw/sub-213A/anat/sub-213A_sub-213A.nii.gz',
#  'inputs/mri-raw/sub-213B/anat/sub-213B_sub-213B.nii.gz',
#  'inputs/mri-raw/sub-213B/anat/sub-213B_sub-213B.nii.gz',
#  'inputs/mri-raw/sub-214A/anat/sub-214A_sub-214A.nii.gz',
#  'inputs/mri-raw/sub-214A/anat/sub-214A_sub-214A.nii.gz',
#  'inputs/mri-raw/sub-215A/anat/sub-215A_sub-215A.nii.gz',
#  'inputs/mri-raw/sub-215A/anat/sub-215A_sub-215A.nii.gz',
#  'inputs/mri-raw/sub-216A/anat/sub-216A_sub-216A.nii.gz',
#  'inputs/mri-raw/sub-216A/anat/sub-216A_sub-216A.nii.gz',
#  'inputs/mri-raw/sub-216B/anat/sub-216B_sub-216B.nii.gz',
#  'inputs/mri-raw/sub-216B/anat/sub-216B_sub-216B.nii.gz',
#  'inputs/mri-raw/sub-217A/anat/sub-217A_sub-217A.nii.gz',
#  'inputs/mri-raw/sub-217A/anat/sub-217A_sub-217A.nii.gz',
#  'inputs/mri-raw/sub-217B/anat/sub-217B_sub-217B.nii.gz',
#  'inputs/mri-raw/sub-217B/anat/sub-217B_sub-217B.nii.gz',
#  'inputs/mri-raw/sub-218A/anat/sub-218A_sub-218A.nii.gz',
#  'inputs/mri-raw/sub-218A/anat/sub-218A_sub-218A.nii.gz',
#  'inputs/mri-raw/sub-218B/anat/sub-218B_sub-218B.nii.gz',
#  'inputs/mri-raw/sub-218B/anat/sub-218B_sub-218B.nii.gz',
#  'inputs/mri-raw/sub-219A/anat/sub-219A_sub-219A.nii.gz',
#  'inputs/mri-raw/sub-219A/anat/sub-219A_sub-219A.nii.gz',
#  'inputs/mri-raw/sub-220A/anat/sub-220A_sub-220A.nii.gz',
#  'inputs/mri-raw/sub-220A/anat/sub-220A_sub-220A.nii.gz',
#  'inputs/mri-raw/sub-220B/anat/sub-220B_sub-220B.nii.gz',
#  'inputs/mri-raw/sub-220B/anat/sub-220B_sub-220B.nii.gz',
#  'inputs/mri-raw/sub-221A/anat/sub-221A_sub-221A.nii.gz',
#  'inputs/mri-raw/sub-221A/anat/sub-221A_sub-221A.nii.gz',
#  'inputs/mri-raw/sub-221B/anat/sub-221B_sub-221B.nii.gz',
#  'inputs/mri-raw/sub-221B/anat/sub-221B_sub-221B.nii.gz',
#  'inputs/mri-raw/sub-222A/anat/sub-222A_sub-222A.nii.gz',
#  'inputs/mri-raw/sub-222A/anat/sub-222A_sub-222A.nii.gz',
#  'inputs/mri-raw/sub-222B/anat/sub-222B_sub-222B.nii.gz',
#  'inputs/mri-raw/sub-222B/anat/sub-222B_sub-222B.nii.gz',
#  'inputs/mri-raw/sub-223A/anat/sub-223A_sub-223A.nii.gz',
#  'inputs/mri-raw/sub-223A/anat/sub-223A_sub-223A.nii.gz',
#  'inputs/mri-raw/sub-223B/anat/sub-223B_sub-223B.nii.gz',
#  'inputs/mri-raw/sub-223B/anat/sub-223B_sub-223B.nii.gz',
#  'inputs/mri-raw/sub-224A/anat/sub-224A_sub-224A.nii.gz',
#  'inputs/mri-raw/sub-224A/anat/sub-224A_sub-224A.nii.gz',
#  'inputs/mri-raw/sub-224B/anat/sub-224B_sub-224B.nii.gz',
#  'inputs/mri-raw/sub-224B/anat/sub-224B_sub-224B.nii.gz',
#  'inputs/mri-raw/sub-225A/anat/sub-225A_sub-225A.nii.gz',
#  'inputs/mri-raw/sub-225A/anat/sub-225A_sub-225A.nii.gz',
#  'inputs/mri-raw/sub-225B/anat/sub-225B_sub-225B.nii.gz',
#  'inputs/mri-raw/sub-225B/anat/sub-225B_sub-225B.nii.gz',
#  'inputs/mri-raw/sub-226A/anat/sub-226A_sub-226A.nii.gz',
#  'inputs/mri-raw/sub-226A/anat/sub-226A_sub-226A.nii.gz',
#  'inputs/mri-raw/sub-226B/anat/sub-226B_sub-226B.nii.gz',
#  'inputs/mri-raw/sub-226B/anat/sub-226B_sub-226B.nii.gz',
#  'inputs/mri-raw/sub-227A/anat/sub-227A_sub-227A.nii.gz',
#  'inputs/mri-raw/sub-227A/anat/sub-227A_sub-227A.nii.gz',
#  'inputs/mri-raw/sub-227B/anat/sub-227B_sub-227B.nii.gz',
#  'inputs/mri-raw/sub-227B/anat/sub-227B_sub-227B.nii.gz',
#  'inputs/mri-raw/sub-228A/anat/sub-228A_sub-228A.nii.gz',
#  'inputs/mri-raw/sub-228A/anat/sub-228A_sub-228A.nii.gz',
#  'inputs/mri-raw/sub-228B/anat/sub-228B_sub-228B.nii.gz',
#  'inputs/mri-raw/sub-228B/anat/sub-228B_sub-228B.nii.gz']

# %%
pd.DataFrame(data_dict)
# Out:
#            job_name                                             dl_cmd
# 0  sub-001A_T1w_bet  bet inputs/mri_raw/sub-001A/anat/sub-001A_T1w....  \
# 1  sub-001A_T1w_bet  bet inputs/mri_raw/sub-001A/anat/sub-001A_T1w....
# 2  sub-001B_T1w_bet  bet inputs/mri_raw/sub-001B/anat/sub-001B_T1w....
#
#                                              inputs
# 0  inputs/mri_raw/sub-001A/anat/sub-001A_T1w.nii.gz  \
# 1  inputs/mri_raw/sub-001A/anat/sub-001A_T1w.nii.gz
# 2  inputs/mri_raw/sub-001B/anat/sub-001B_T1w.nii.gz
#
#                                outputs
# 0  outputs/bet/sub-001A_T1w_bet.nii.gz
# 1  outputs/bet/sub-001A_T1w_bet.nii.gz
# 2  outputs/bet/sub-001B_T1w_bet.nii.gz

# %%
def get_glob_var_text(string_list):
    combined_string = ''
    for string in string_list:
        combined_string+=string+','
    return '['+combined_string[:-1]+']'

# %%
variable_dict.keys()
# Out:
# dict_keys(['svs', 'subject', 't1w', 't2w', 'ref'])

# %%
dl_cmd = "python code/process_svg.py -a {t1w} -s {svs}"
inputs = "{t1w} {svs}"
outputs = "outputs/bet/{subject}_T1w_bet.nii.gz"
job_name = "{subject}_T1w_bet"
data_dict = {'job_name':[], 'dl_cmd':[], 'inputs':[], 'outputs':[]}

for row_dict in pd.DataFrame(variable_dict).to_dict(orient='records'):
    data_dict['job_name'].append(job_name.format(**row_dict))
    data_dict['dl_cmd'].append(dl_cmd.format(**row_dict))
    data_dict['inputs'].append(inputs.format(**row_dict))
    data_dict['outputs'].append(outputs.format(**row_dict))
    
(pd.DataFrame(data_dict)
 .assign(
     container,
     is_explicit,
     output_datasets,
     prereq_get,
     message,
     super_id,
     clone_target,
     push_target,
     ephemeral_location,
     req_disk_gb,
     queue,
     slots,
     vmem,
     h_rt,
     env_vars,
     batch
 )
 )
